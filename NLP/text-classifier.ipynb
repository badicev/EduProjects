# %% [markdown]
# <h1>Markov Model Classifier / Poetry Generator<h/1>

# %% [markdown]
# <h3>Tips<h/3>

# %% [markdown]
# <h6>1. Use smoothing (add-one smoothing) to avoid zero probabilities <br>
# 2. Consider whether you need A and pi or log(A) and log(pi)<br>
# 3. For Bayes' rule, compute the priors: p(class = k) <h/6>

# %% [markdown]
# * Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import string
from sklearn.model_selection import train_test_split

# %% [markdown]
# * Load the data

# %%
from urllib.request import urlopen
eap_data_link ="https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/edgar_allan_poe.txt"
rf_data_link = "https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt"
eap_data = urlopen(eap_data_link).read().decode('utf-8')
rf_data = urlopen(rf_data_link).read().decode('utf-8')

# %%
type(eap_data)
# Out:
# str

# %% [markdown]
# * Loop through each file, save each line to a list (one line == one sample)

# %%
eap_list = eap_data.split('\n')
eap_list
# Out:
# ["LO! Death hath rear'd himself a throne",
#  'In a strange city, all alone,',
#  'Far down within the dim west',
#  'Where the good, and the bad, and the worst, and the best,',
#  'Have gone to their eternal rest.',
#  '\u2009',
#  'There shrines, and palaces, and towers',
#  'Are not like any thing of ours',
#  'Oh no! O no! ours never loom',
#  'To heaven with that ungodly gloom!',
#  'Time-eaten towers that tremble not!',
#  'Resemble nothing that is ours.',
#  'Around, by lifting winds forgot,',
#  'Resignedly beneath the sky',
#  'The melancholy waters lie.',
#  '\u2009',
#  'No holy rays from heaven come down',
#  'On the long night-time of that town,',
#  'But light from out the lurid sea',
#  'Streams up the turrets silently',
#  'Up thrones up long-forgotten bowers',
#  "Of scultur'd ivy and stone flowers",
#  'Up domes up spires up kingly halls',
#  'Up fanes up Babylon-like walls',
#  'Up many a melancholy shrine',
#  'Whose entablatures intertwine',
#  'The mask the viol and the vine.',
#  '\u2009',
#  'There open temples open graves',
#  'Are on a level with the waves',
#  'But not the riches there that lie',
#  "In each idol's diamond eye,",
#  "Not the gaily-jewell'd dead",
#  'Tempt the waters from their bed:',
#  'For no ripples curl, alas!',
#  'Along that wilderness of glass',
#  'No swellings hint that winds may be',
#  'Upon a far-off happier sea:',
#  'So blend the turrets and shadows there',
#  'That all seem pendulous in air,',
#  'While from the high towers of the town',
#  'Death looks gigantically down.',
#  '\u2009',
#  'But lo! a stir is in the air!',
#  'The wave there is a ripple there!',
#  'As if the towers had thrown aside,',
#  'In slightly sinking, the dull tide',
#  'As if the turret-tops had given',
#  'A vacuum in the filmy heaven.',
#  'The waves have now a redder glow',
#  'The very hours are breathing low',
#  'And when, amid no earthly moans,',
#  'Down, down, that town shall settle hence,',
#  'All Hades, from a thousand thrones,',
#  'Shall do it reverence,',
#  'And Death to some more happy clime',
#  'Shall give his undivided time.',
#  '',
#  'The skies they were ashen and sober;',
#  'The leaves they were crisped and sere -',
#  'The leaves they were withering and sere;',
#  'It was night in the lonesome October',
#  'Of my most immemorial year;',
#  'It was hard by the dim lake of Auber,',
#  'In the misty mid region of Weir -',
#  'It was down by the dank tarn of Auber,',
#  'In the ghoul-haunted woodland of Weir.',
#  '',
#  'Here once, through an alley Titanic,',
#  'Of cypress, I roamed with my Soul -',
#  'Of cypress, with Psyche, my Soul.',
#  'These were days when my heart was volcanic',
#  'As the scoriac rivers that roll -',
#  'As the lavas that restlessly roll',
#  'Their sulphurous currents down Yaanek',
#  'In the ultimate climes of the pole -',
#  'That groan as they roll down Mount Yaanek',
#  'In the realms of the boreal pole.',
#  '',
#  'Our talk had been serious and sober,',
#  'But our thoughts they were palsied and sere -',
#  'Our memories were treacherous and sere, -',
#  'For we knew not the month was October,',
#  'And we marked not the night of the year -',
#  '(Ah, night of all nights in the year!)',
#  'We noted not the dim lake of Auber -',
#  '(Though once we had journey down here),',
#  'Remembered not the dank tarn of Auber,',
#  'Nor the ghoul-haunted woodland of Weir.',
#  '',
#  'And now, as the night was senescent,',
#  'And star-dials pointed to morn -',
#  'As the star-dials hinted of morn -',
#  'At the end of our path a liquescent',
#  'And nebulous lustre was born,',
#  'Out of which a miraculous crescent',
#  'Arose with a duplicate horn -',
#  "Astarte's bediamonded crescent",
#  'Distinct with its duplicate horn.',
#  '',
#  'And I said - "She is warmer than Dian:',
#  'She rolls through an ether of sighs -',
#  'She revels in a region of sighs:',
#  'She has seen that the tears are not dry on',
#  'These cheeks, where the worm never dies,',
#  'And has come past the stars of the Lion',
#  'To point us the path to the skies -',
#  'To the Lethean peace of the skies -',
#  'Come up, in despite of the Lion,',
#  'To shine on us with her bright eyes -',
#  'Come up through the lair of the Lion,',
#  'With love in her luminous eyes."',
#  '',
#  'But Psyche, uplifting her finger,',
#  'Said - "Sadly this star I mistrust -',
#  'Her pallor I strangely mistrust: -',
#  'Oh, hasten! - oh, let us not linger!',
#  'Oh, fly! - let us fly! - for we must."',
#  'In terror she spoke, letting sink her',
#  'Wings until they trailed in the dust -',
#  'In agony sobbed, letting sink her',
#  'Plumes till they trailed in the dust -',
#  'Till they sorrowfully trailed in the dust.',
#  '',
#  'I replied - "This is nothing but dreaming:',
#  'Let us on by this tremulous light!',
#  'Let us bathe in this crystalline light!',
#  'Its Sybilic splendor is beaming',
#  'With Hope and in Beauty to-night! -',
#  'See! - it flickers up the sky through the night!',
#  'Ah, we safely may trust to its gleaming,',
#  'And be sure it will lead us aright -',
#  'We safely may trust to a gleaming,',
#  'That cannot but guide us aright,',
#  'Since it flickers up to Heaven through the night."',
#  '',
#  'Thus I pacified Psyche and kissed her,',
#  'And tempted her out of her gloom -',
#  'And conquered her scruples and gloom;',
#  'And we passed to the end of the vista,',
#  'But were stopped by the door of a tomb -',
#  'By the door of a legended tomb;',
#  'And I said - "What is written, sweet sister,',
#  'On the door of this legended tomb?"',
#  'She replied - "Ulalume - Ulalume -',
#  '‘Tis the vault of thy lost Ulalume!"',
#  '',
#  'Then my heart it grew ashen and sober',
#  'As the leaves that were crisped and sere -',
#  'As the leaves that were withering and sere,',
#  'And I cried - "It was surely October',
#  'On this very night of last year',
#  'That I journeyed - I journeyed down here -',
#  'That I brought a dread burden down here!',
#  'On this night of all nights in the year,',
#  'Ah, what demon has tempted me here?',
#  'Well I know, now, this dim lake of Auber -',
#  'This misty mid region of Weir -',
#  'Well I know, now, this dank tarn of Auber, -',
#  'This ghoul-haunted woodland of Weir."',
#  '',
#  "Wreathed in myrtle, my sword I'll conceal",
#  'Like those champions devoted and brave,',
#  'When they plunged in the tyrant their steel,',
#  'And to Athens deliverance gave. ',
#  '',
#  'Beloved heroes! your deathless souls roam',
#  'In the joy breathing isles of the blest;',
#  'Where the mighty of old have their home -',
#  'Where Achilles and Diomed rest. ',
#  '',
#  "In fresh myrtle my blade I'll entwine,",
#  'Like Harmodious, the gallant and good,',
#  'When he made at the tutelar shrine',
#  "A libation of Tyranny's blood. ",
#  '',
#  'Ye deliverers of Athens from shame!',
#  "Ye avengers of Liberty's wrongs!",
#  'Endless ages shall cherish your fame',
#  'Embalmed in their echoing songs!',
#  '',
#  'Of all who hail thy presence as the morning-',
#  'Of all to whom thine absence is the night-',
#  'The blotting utterly from out high heaven',
#  'The sacred sun- of all who, weeping, bless thee',
#  'Hourly for hope- for life- ah! above all,',
#  'For the resurrection of deep-buried faith',
#  'In Truth- in Virtue- in Humanity-',
#  "Of all who, on Despair's unhallowed bed",
#  'Lying down to die, have suddenly arisen',
#  "At thy soft-murmured words, 'Let there be light!'",
#  'At the soft-murmured words that were fulfilled',
#  'In the seraphic glancing of thine eyes-',
#  'Of all who owe thee most- whose gratitude',
#  'Nearest resembles worship- oh, remember',
#  'The truest- the most fervently devoted,',
#  'And think that these weak lines are written by him-',
#  'By him who, as he pens them, thrills to think',
#  "His spirit is communing with an angel's. ",
#  '',
#  'Thou wouldst be loved?- then let thy heart',
#  'From its present pathway part not!',
#  'Being everything which now thou art,',
#  'Be nothing which thou art not.',
#  'So with the world thy gentle ways,',
#  'Thy grace, thy more than beauty,',
#  'Shall be an endless theme of praise,',
#  'And love- a simple duty. ',
#  '',
#  'When from your gems of thought I turn ',
#  'To those pure orbs, your heart to learn, ',
#  'I scarce know which to prize most high ',
#  'The bright i-dea, or the bright dear-eye.',
#  '',
#  'Of all who hail thy presence as the morning-',
#  'Of all to whom thine absence is the night-',
#  'The blotting utterly from out high heaven',
#  'The sacred sun- of all who, weeping, bless thee',
#  'Hourly for hope- for life- ah! above all,',
#  'For the resurrection of deep-buried faith',
#  'In Truth- in Virtue- in Humanity-',
#  "Of all who, on Despair's unhallowed bed",
#  'Lying down to die, have suddenly arisen',
#  'At thy soft-murmured words, "Let there be light!"',
#  'At the soft-murmured words that were fulfilled',
#  'In the seraphic glancing of thine eyes-',
#  'Of all who owe thee most- whose gratitude',
#  'Nearest resembles worship- oh, remember',
#  'The truest- the most fervently devoted,',
#  'And think that these weak lines are written by him-',
#  'By him who, as he pens them, thrills to think',
#  "His spirit is communing with an angel's.",
#  '',
#  'Fair isle, that from the fairest of all flowers,',
#  'Thy gentlest of all gentle names dost take!',
#  'How many memories of what radiant hours',
#  'At sight of thee and thine at once awake!',
#  'How many scenes of what departed bliss!',
#  'How many thoughts of what entombed hopes!',
#  'How many visions of a maiden that is',
#  'No more- no more upon thy verdant slopes!',
#  'No more! alas, that magical sad sound',
#  'Transforming all! Thy charms shall please no more-',
#  'Thy memory no more! Accursed ground',
#  'Henceforth I hold thy flower-enameled shore,',
#  'O hyacinthine isle! O purple Zante!',
#  '"Isola d\'oro! Fior di Levante!"',
#  '',
#  'O! I care not that my earthly lot',
#  'Hath little of Earth in it,',
#  'That years of love have been forgot',
#  'In the fever of a minute:',
#  '',
#  'I heed not that the desolate',
#  'Are happier, sweet, than I,',
#  'But that you meddle with my fate',
#  'Who am a passer by.',
#  '',
#  'It is not that my founts of bliss',
#  'Are gushing- strange! with tears-',
#  'Or that the thrill of a single kiss',
#  'Hath palsied many years-',
#  '',
#  "'Tis not that the flowers of twenty springs",
#  "Which have wither'd as they rose",
#  'Lie dead on my heart-strings',
#  'With the weight of an age of snows.',
#  '',
#  'Not that the grass- O! may it thrive!',
#  'On my grave is growing or grown-',
#  'But that, while I am dead yet alive',
#  'I cannot be, lady, alone.',
#  '',
#  'Sancta Maria! turn thine eyes -',
#  "Upon the sinner's sacrifice,",
#  'Of fervent prayer and humble love,',
#  'From thy holy throne above. ',
#  'At morn - at noon - at twilight dim -',
#  'Maria! thou hast heard my hymn!',
#  'In joy and wo - in good and ill -',
#  'Mother of God, be with me still! ',
#  '',
#  'When the Hours flew brightly by,',
#  'And not a cloud obscured the sky,',
#  'My soul, lest it should truant be,',
#  'Thy grace did guide to thine and thee; ',
#  '',
#  "Now, when storms of Fate o'ercast",
#  'Darkly my Present and my Past,',
#  'Let my Future radiant shine',
#  'With sweet hopes of thee and thine!',
#  '',
#  'The bells! ah, the bells! ',
#  'The little silver bells! ',
#  'How fairy-like a melody there floats ',
#  'From their throats. ',
#  'From their merry little throats ',
#  'From the silver, tinkling throats ',
#  'Of the bells, bells, bells ',
#  'Of the bells! ',
#  '',
#  'The bells! ah, the bells! ',
#  'The heavy iron bells! ',
#  'How horrible a monody there floats ',
#  'From their throats ',
#  'From their deep-toned throats ',
#  'From their melancholy throats! ',
#  'How I shudder at the notes ',
#  'Of the bells, bells, bells ',
#  'Of the bells!',
#  '',
#  'How often we forget all time, when lone',
#  "Admiring Nature's universal throne;",
#  'Her woods- her wilds- her mountains- the intense',
#  'Reply of HERS to OUR intelligence!',
#  '',
#  'In youth have I known one with whom the Earth',
#  'In secret communing held- as he with it,',
#  'In daylight, and in beauty from his birth:',
#  'Whose fervid, flickering torch of life was lit',
#  'From the sun and stars, whence he had drawn forth',
#  'A passionate light- such for his spirit was fit-',
#  'And yet that spirit knew not, in the hour',
#  "Of its own fervor what had o'er it power.",
#  '',
#  'Perhaps it may be that my mind is wrought',
#  "To a fever by the moonbeam that hangs o'er,",
#  'But I will half believe that wild light fraught',
#  'With more of sovereignty than ancient lore',
#  'Hath ever told- or is it of a thought',
#  'The unembodied essence, and no more,',
#  "That with a quickening spell doth o'er us pass",
#  "As dew of the night-time o'er the summer grass?",
#  '',
#  "Doth o'er us pass, when, as th' expanding eye",
#  'To the loved object- so the tear to the lid',
#  'Will start, which lately slept in apathy?',
#  'And yet it need not be- (that object) hid',
#  'From us in life- but common- which doth lie',
#  'Each hour before us- but then only, bid',
#  'With a strange sound, as of a harp-string broken,',
#  "To awake us- 'Tis a symbol and a token",
#  '',
#  'Of what in other worlds shall be- and given',
#  'In beauty by our God, to those alone',
#  'Who otherwise would fall from life and Heaven',
#  "Drawn by their heart's passion, and that tone,",
#  'That high tone of the spirit which hath striven,',
#  "Tho' not with Faith- with godliness- whose throne",
#  "With desperate energy 't hath beaten down;",
#  'Wearing its own deep feeling as a crown.',
#  '',
#  'Not long ago, the writer of these lines,',
#  'In the mad pride of intellectuality,',
#  'Maintained "the power of words"- denied that ever',
#  'A thought arose within the human brain',
#  'Beyond the utterance of the human tongue:',
#  'And now, as if in mockery of that boast,',
#  'Two words- two foreign soft dissyllables-',
#  'Italian tones, made only to be murmured',
#  'By angels dreaming in the moonlit "dew',
#  'That hangs like chains of pearl on Hermon hill,"',
#  'Have stirred from out the abysses of his heart,',
#  'Unthought-like thoughts that are the souls of thought,',
#  'Richer, far wilder, far diviner visions',
#  'Than even seraph harper, Israfel,',
#  '(Who has "the sweetest voice of all God\'s creatures,")',
#  'Could hope to utter. And I! my spells are broken.',
#  'The pen falls powerless from my shivering hand.',
#  'With thy dear name as text, though bidden by thee,',
#  'I cannot write- I cannot speak or think-',
#  "Alas, I cannot feel; for 'tis not feeling,",
#  'This standing motionless upon the golden',
#  'Threshold of the wide-open gate of dreams.',
#  'Gazing, entranced, adown the gorgeous vista,',
#  'And thrilling as I see, upon the right,',
#  'Upon the left, and all the way along,',
#  'Amid empurpled vapors, far away',
#  'To where the prospect terminates- thee only.',
#  '',
#  'Beloved! amid the earnest woes',
#  'That crowd around my earthly path-',
#  '(Drear path, alas! where grows',
#  'Not even one lonely rose)-',
#  'My soul at least a solace hath',
#  'In dreams of thee, and therein knows',
#  'An Eden of bland repose.',
#  '',
#  'And thus thy memory is to me',
#  'Like some enchanted far-off isle',
#  'In some tumultuous sea-',
#  'Some ocean throbbing far and free',
#  'With storms- but where meanwhile',
#  'Serenest skies continually',
#  "Just o'er that one bright island smile.",
#  '',
#  'I saw thee once- once only- years ago: ',
#  'I must not say how many- but not many. ',
#  'It was a July midnight; and from out ',
#  'A full-orbed moon, that, like thine own soul, soaring, ',
#  'Sought a precipitate pathway up through heaven, ',
#  'There fell a silvery-silken veil of light, ',
#  'With quietude, and sultriness, and slumber, ',
#  'Upon the upturned faces of a thousand ',
#  'Roses that grew in an enchanted garden, ',
#  'Where no wind dared to stir, unless on tiptoe- ',
#  "Fell on the upturn'd faces of these roses ",
#  'That gave out, in return for the love-light, ',
#  'Their odorous souls in an ecstatic death- ',
#  "Fell on the upturn'd faces of these roses ",
#  'That smiled and died in this parterre, enchanted ',
#  'By thee, and by the poetry of thy presence. ',
#  'Clad all in white, upon a violet bank ',
#  'I saw thee half reclining; while the moon ',
#  "Fell on the upturn'd faces of the roses, ",
#  "And on thine own, upturn'd- alas, in sorrow! ",
#  '',
#  'Was it not Fate, that, on this July midnight- ',
#  'Was it not Fate, (whose name is also Sorrow,) ',
#  'That bade me pause before that garden-gate, ',
#  'To breathe the incense of those slumbering roses? ',
#  'No footstep stirred: the hated world an slept, ',
#  'Save only thee and me. (Oh, Heaven!- oh, God! ',
#  'How my heart beats in coupling those two words!) ',
#  'Save only thee and me. I paused- I looked- ',
#  'And in an instant all things disappeared. ',
#  '(Ah, bear in mind this garden was enchanted!) ',
#  '',
#  'The pearly lustre of the moon went out: ',
#  'The mossy banks and the meandering paths, ',
#  'The happy flowers and the repining trees, ',
#  "Were seen no more: the very roses' odors ",
#  'Died in the arms of the adoring airs. ',
#  'All- all expired save thee- save less than thou: ',
#  'Save only the divine light in thine eyes- ',
#  'Save but the soul in thine uplifted eyes. ',
#  'I saw but them- they were the world to me! ',
#  'I saw but them- saw only them for hours, ',
#  'Saw only them until the moon went down. ',
#  'What wild heart-histories seemed to he enwritten ',
#  'Upon those crystalline, celestial spheres! ',
#  'How dark a woe, yet how sublime a hope! ',
#  'How silently serene a sea of pride! ',
#  'How daring an ambition; yet how deep- ',
#  'How fathomless a capacity for love! ',
#  '',
#  'But now, at length, dear Dian sank from sight, ',
#  'Into a western couch of thunder-cloud; ',
#  'And thou, a ghost, amid the entombing trees ',
#  'Didst glide away. Only thine eyes remained; ',
#  'They would not go- they never yet have gone; ',
#  'Lighting my lonely pathway home that night, ',
#  'They have not left me (as my hopes have) since; ',
#  'They follow me- they lead me through the years. ',
#  'They are my ministers- yet I their slave. ',
#  'Their office is to illumine and enkindle- ',
#  'My duty, to be saved by their bright light, ',
#  'And purified in their electric fire, ',
#  'And sanctified in their elysian fire. ',
#  'They fill my soul with Beauty (which is Hope), ',
#  'And are far up in Heaven- the stars I kneel to ',
#  'In the sad, silent watches of my night; ',
#  'While even in the meridian glare of day ',
#  'I see them still- two sweetly scintillant ',
#  'Venuses, unextinguished by the sun!',
#  '',
#  'The bowers whereat, in dreams, I see',
#  'The wantonest singing birds,',
#  'Are lips- and all thy melody',
#  'Of lip-begotten words-',
#  '',
#  'Thine eyes, in Heaven of heart enshrined,',
#  'Then desolately fall,',
#  'O God! on my funereal mind',
#  'Like starlight on a pall-',
#  '',
#  'Thy heart- thy heart!- I wake and sigh,',
#  'And sleep to dream till day',
#  'Of the truth that gold can never buy-',
#  'Of the baubles that it may.',
#  '',
#  'In Heaven a spirit doth dwell',
#  '"Whose heart-strings are a lute";',
#  'None sing so wildly well',
#  'As the angel Israfel,',
#  'And the giddy stars (so legends tell),',
#  'Ceasing their hymns, attend the spell',
#  'Of his voice, all mute.',
#  '',
#  'Tottering above',
#  'In her highest noon,',
#  'The enamored moon',
#  'Blushes with love,',
#  'While, to listen, the red levin',
#  '(With the rapid Pleiads, even,',
#  'Which were seven,)',
#  'Pauses in Heaven.',
#  '',
#  'And they say (the starry choir',
#  'And the other listening things)',
#  "That Israfeli's fire",
#  'Is owing to that lyre',
#  'By which he sits and sings-',
#  'The trembling living wire',
#  'Of those unusual strings.',
#  '',
#  'But the skies that angel trod,',
#  'Where deep thoughts are a duty-',
#  "Where Love's a grown-up God-",
#  'Where the Houri glances are',
#  'Imbued with all the beauty',
#  'Which we worship in a star.',
#  '',
#  'Therefore thou art not wrong,',
#  'Israfeli, who despisest',
#  'An unimpassioned song;',
#  'To thee the laurels belong,',
#  'Best bard, because the wisest!',
#  'Merrily live, and long!',
#  '',
#  'The ecstasies above',
#  'With thy burning measures suit-',
#  'Thy grief, thy joy, thy hate, thy love,',
#  'With the fervor of thy lute-',
#  'Well may the stars be mute!',
#  '',
#  'Yes, Heaven is thine; but this',
#  'Is a world of sweets and sours;',
#  'Our flowers are merely- flowers,',
#  'And the shadow of thy perfect bliss',
#  'Is the sunshine of ours.',
#  '',
#  'If I could dwell',
#  'Where Israfel',
#  'Hath dwelt, and he where I,',
#  'He might not sing so wildly well',
#  'A mortal melody,',
#  'While a bolder note than this might swell',
#  'From my lyre within the sky.',
#  '',
#  'Science! true daughter of Old Time thou art!',
#  'Who alterest all things with thy peering eyes.',
#  "Why preyest thou thus upon the poet's heart,",
#  'Vulture, whose wings are dull realities?',
#  'How should he love thee? or how deem thee wise,',
#  'Who wouldst not leave him in his wandering',
#  'To seek for treasure in the jewelled skies,',
#  'Albeit he soared with an undaunted wing?',
#  'Hast thou not dragged Diana from her car?',
#  'And driven the Hamadryad from the wood',
#  'To seek a shelter in some happier star?',
#  'Hast thou not torn the Naiad from her flood,',
#  'The Elfin from the green grass, and from me',
#  'The summer dream beneath the tamarind tree?',
#  '',
#  "I'll tell you a plan for gaining wealth,",
#  'Better than banking, trade or leases ',
#  'Take a bank note and fold it up, ',
#  'And then you will find your money in creases! ',
#  'This wonderful plan, without danger or loss, ',
#  'Keeps your cash in your hands, where nothing can trouble it; ',
#  'And every time that you fold it across, ',
#  "'Tis as plain as the light of the day that you double it!",
#  '',
#  'The skies they were ashen and sober;',
#  'The leaves they were crisped and sere-',
#  'The leaves they were withering and sere;',
#  'It was night in the lonesome October',
#  'Of my most immemorial year;',
#  'It was hard by the dim lake of Auber,',
#  'In the misty mid region of Weir-',
#  'It was down by the dank tarn of Auber,',
#  'In the ghoul-haunted woodland of Weir.',
#  '',
#  'Here once, through an alley Titanic,',
#  'Of cypress, I roamed with my Soul-',
#  'Of cypress, with Psyche, my Soul.',
#  'There were days when my heart was volcanic',
#  'As the scoriac rivers that roll-',
#  'As the lavas that restlessly roll',
#  'Their sulphurous currents down Yaanek',
#  'In the ultimate climes of the pole-',
#  'That groan as they roll down Mount Yaanek',
#  'In the realms of the boreal pole.',
#  '',
#  'Our talk had been serious and sober,',
#  'But our thoughts they were palsied and sere-',
#  'Our memories were treacherous and sere-',
#  'For we knew not the month was October,',
#  'And we marked not the night of the year-',
#  '(Ah, night of all nights in the year!)',
#  'We noted not the dim lake of Auber-',
#  '(Though once we had journeyed down here),',
#  'Remembered not the dank tarn of Auber,',
#  'Nor the ghoul-haunted woodland of Weir.',
#  '',
#  'And now, as the night was senescent,',
#  'And star-dials pointed to morn-',
#  'As the star-dials hinted of morn-',
#  'At the end of our path a liquescent',
#  'And nebulous lustre was born,',
#  'Out of which a miraculous crescent',
#  'Arose with a duplicate horn-',
#  "Astarte's bediamonded crescent",
#  'Distinct with its duplicate horn.',
#  '',
#  "And I said- 'She is warmer than Dian:",
#  'She rolls through an ether of sighs-',
#  'She revels in a region of sighs:',
#  'She has seen that the tears are not dry on',
#  'These cheeks, where the worm never dies,',
#  'And has come past the stars of the Lion,',
#  'To point us the path to the skies-',
#  'To the Lethean peace of the skies-',
#  'Come up, in despite of the Lion,',
#  'To shine on us with her bright eyes-',
#  'Come up through the lair of the Lion,',
#  "With love in her luminous eyes.'",
#  '',
#  'But Psyche, uplifting her finger,',
#  "Said- 'Sadly this star I mistrust-",
#  'Her pallor I strangely mistrust:-',
#  'Oh, hasten!- oh, let us not linger!',
#  "Oh, fly!- let us fly!- for we must.'",
#  'In terror she spoke, letting sink her',
#  'Wings until they trailed in the dust-',
#  'In agony sobbed, letting sink her',
#  'Plumes till they trailed in the dust-',
#  'Till they sorrowfully trailed in the dust.',
#  '',
#  "I replied- 'This is nothing but dreaming:",
#  'Let us on by this tremulous light!',
#  'Let us bathe in this crystalline light!',
#  'Its Sybilic splendor is beaming',
#  'With Hope and in Beauty to-night:-',
#  'See!- it flickers up the sky through the night!',
#  'Ah, we safely may trust to its gleaming,',
#  'And be sure it will lead us aright-',
#  'We safely may trust to a gleaming',
#  'That cannot but guide us aright,',
#  "Since it flickers up to Heaven through the night.'",
#  '',
#  'Thus I pacified Psyche and kissed her,',
#  'And tempted her out of her gloom-',
#  'And conquered her scruples and gloom;',
#  'And we passed to the end of the vista,',
#  'But were stopped by the door of a tomb-',
#  'By the door of a legended tomb;',
#  "And I said- 'What is written, sweet sister,",
#  "On the door of this legended tomb?'",
#  "She replied- 'Ulalume- Ulalume-",
#  "'Tis the vault of thy lost Ulalume!'",
#  '',
#  'Then my heart it grew ashen and sober',
#  'As the leaves that were crisped and sere-',
#  'As the leaves that were withering and sere-',
#  "And I cried- 'It was surely October",
#  'On this very night of last year',
#  'That I journeyed- I journeyed down here-',
#  'That I brought a dread burden down here-',
#  'On this night of all nights in the year,',
#  'Ah, what demon has tempted me here?',
#  'Well I know, now, this dim lake of Auber-',
#  'This misty mid region of Weir-',
#  'Well I know, now, this dank tarn of Auber,',
#  "This ghoul-haunted woodland of Weir.' ",
#  '',
#  'How often we forget all time, when lone ',
#  "Admiring Nature's universal throne; ",
#  'Her woods - her winds - her mountains - the intense ',
#  'Reply of Hers to Our intelligence! ',
#  '',
#  'In youth I have known one with whom the Earth ',
#  'In secret communing held - as he with it, ',
#  'In daylight, and in beauty, from his birth: ',
#  'Whose fervid, flickering torch of life was lit ',
#  'From the sun and stars, whence he had drawn forth ',
#  'A passionate light - such for his spirit was fit - ',
#  'And yet that spirit knew - not in the hour ',
#  "Of its own fervour - what had o'er it power. ",
#  '',
#  'Perhaps it may be that my mind is wrought ',
#  "To a fever by the moonbeam that hangs o'er, ",
#  'But I will half believe that wild light fraught ',
#  'With more of sovereignty than ancient lore ',
#  'Hath ever told - or is it of a thought ',
#  'The unembodied essence, and no more ',
#  "That with a quickening spell doth o'er us pass ",
#  "As dew of the night time, o'er the summer grass? ",
#  '',
#  "Doth o'er us pass, when as th' expanding eye ",
#  'To the loved object - so the tear to the lid ',
#  'Will start, which lately slept in apathy? ',
#  'And yet it need not be - (that object) hid ',
#  'From us in life - but common - which doth lie ',
#  'Each hour before us - but then only bid ',
#  'With a strange sound, as of a harpstring broken ',
#  "T' awake us - 'Tis a symbol and a token - ",
#  '',
#  'Of what in other worlds shall be - and given ',
#  'In beauty by our God, to those alone ',
#  'Who otherwise would fall from life and Heaven ',
#  "Drawn by their heart's passion, and that tone, ",
#  'That high tone of the spirit which hath striven ',
#  'Though not with Faith - with godliness - whose throne ',
#  "With desperate energy 't hath beaten down; ",
#  'Wearing its own deep feeling as a crown.',
#  '',
#  "'Tis said that when ",
#  'The hands of men ',
#  'Tamed this primeval wood, ',
#  'And hoary trees with groans of woe, ',
#  'Like warriors by an unknown foe, ',
#  'Were in their strength subdued, ',
#  'The virgin Earth Gave instant birth ',
#  "To springs that ne'er did flow ",
#  'That in the sun Did rivulets run, ',
#  'And all around rare flowers did blow ',
#  'The wild rose pale Perfumed the gale ',
#  'And the queenly lily adown the dale ',
#  '(Whom the sun and the dew ',
#  'And the winds did woo), ',
#  'With the gourd and the grape luxuriant grew. ',
#  '',
#  'So when in tears ',
#  'The love of years ',
#  'Is wasted like the snow, ',
#  'And the fine fibrils of its life ',
#  'By the rude wrong of instant strife ',
#  'Are broken at a blow ',
#  'Within the heart ',
#  'Do springs upstart ',
#  'Of which it doth now know, ',
#  'And strange, sweet dreams, ',
#  'Like silent streams ',
#  'That from new fountains overflow, ',
#  'With the earlier tide ',
#  'Of rivers glide ',
#  'Deep in the heart whose hope has died-- ',
#  'Quenching the fires its ashes hide,-- ',
#  'Its ashes, whence will spring and grow ',
#  'Sweet flowers, ere long, ',
#  'The rare and radiant flowers of song!',
#  '',
#  'In the greenest of our valleys,',
#  'By good angels tenanted,',
#  'Once fair and stately palace --',
#  'Radiant palace --reared its head.',
#  "In the monarch Thought's dominion --",
#  'It stood there!',
#  'Never seraph spread a pinion',
#  'Over fabric half so fair.',
#  '',
#  'Banners yellow, glorious, golden,',
#  'On its roof did float and flow;',
#  '(This --all this --was in the olden',
#  'Time long ago)',
#  'And every gentle air that dallied,',
#  'In that sweet day,',
#  'Along the ramparts plumed and pallid,',
#  'A winged odour went away.',
#  '',
#  'Wanderers in that happy valley',
#  'Through two luminous windows saw',
#  'Spirits moving musically',
#  "To a lute's well-tuned law,",
#  'Round about a throne, where sitting',
#  '(Porphyrogene!)',
#  'In state his glory well befitting,',
#  'The ruler of the realm was seen.',
#  '',
#  'And all with pearl and ruby glowing',
#  'Was the fair palace door,',
#  'Through which came flowing, flowing, flowing',
#  'And sparkling evermore,',
#  'A troop of Echoes whose sweet duty',
#  'Was but to sing,',
#  'In voices of surpassing beauty,',
#  'The wit and wisdom of their king.',
#  '',
#  'But evil things, in robes of sorrow,',
#  "Assailed the monarch's high estate;",
#  '(Ah, let us mourn, for never morrow',
#  'Shall dawn upon him, desolate!)',
#  'And, round about his home, the glory',
#  'That blushed and bloomed',
#  'Is but a dim-remembered story',
#  'Of the old time entombed.',
#  '',
#  'And travellers now within that valley,',
#  'Through the red-litten windows, see',
#  'Vast forms that move fantastically',
#  'To a discordant melody;',
#  'While, like a rapid ghastly river,',
#  'Through the pale door,',
#  'A hideous throng rush out forever,',
#  'And laugh --but smile no more.']

# %%
rf_list = rf_data.split('\n')
rf_list
# Out:
# ['Two roads diverged in a yellow wood,',
#  'And sorry I could not travel both',
#  'And be one traveler, long I stood',
#  'And looked down one as far as I could',
#  'To where it bent in the undergrowth; ',
#  '',
#  'Then took the other, as just as fair,',
#  'And having perhaps the better claim',
#  'Because it was grassy and wanted wear,',
#  'Though as for that the passing there',
#  'Had worn them really about the same,',
#  '',
#  'And both that morning equally lay',
#  'In leaves no step had trodden black.',
#  'Oh, I kept the first for another day! ',
#  'Yet knowing how way leads on to way',
#  'I doubted if I should ever come back.',
#  '',
#  'I shall be telling this with a sigh',
#  'Somewhere ages and ages hence:',
#  'Two roads diverged in a wood, and I,',
#  'I took the one less traveled by,',
#  'And that has made all the difference.',
#  '',
#  'Whose woods these are I think I know.',
#  'His house is in the village, though; ',
#  'He will not see me stopping here',
#  'To watch his woods fill up with snow.',
#  '',
#  'My little horse must think it queer',
#  'To stop without a farmhouse near',
#  'Between the woods and frozen lake',
#  'The darkest evening of the year.',
#  '',
#  'He gives his harness bells a shake',
#  'To ask if there is some mistake.',
#  "The only other sound's the sweep",
#  'Of easy wind and downy flake.',
#  '',
#  'The woods are lovely, dark and deep,',
#  'But I have promises to keep,',
#  'And miles to go before I sleep,',
#  'And miles to go before I sleep. ',
#  '',
#  'Some say the world will end in fire,',
#  'Some say in ice.',
#  "From what I've tasted of desire",
#  'I hold with those who favor fire.',
#  'But if it had to perish twice,',
#  'I think I know enough of hate',
#  'To say that for destruction ice',
#  'Is also great',
#  'And would suffice.',
#  '',
#  "Nature's first green is gold,",
#  'Her hardest hue to hold.',
#  "Her early leaf's a flower; ",
#  'But only so an hour.',
#  'Then leaf subsides to leaf,',
#  'So Eden sank to grief,',
#  'So dawn goes down to day',
#  'Nothing gold can stay.',
#  '',
#  'I have been one acquainted with the night.',
#  'I have walked out in rain - and back in rain.',
#  'I have outwalked the furthest city light.',
#  '',
#  'I have looked down the saddest city lane.',
#  'I have passed by the watchman on his beat',
#  'And dropped my eyes, unwilling to explain.',
#  '',
#  'I have stood still and stopped the sound of feet',
#  'When far away an interrupted cry',
#  'Came over houses from another street,',
#  '',
#  'But not to call me back or say good-bye; ',
#  'And further still at an unearthly height,',
#  'One luminary clock against the sky',
#  '',
#  'Proclaimed the time was neither wrong nor right.',
#  'I have been one acquainted with the night.',
#  '',
#  'When I go up through the mowing field,',
#  'The headless aftermath,',
#  'Smooth-laid like thatch with the heavy dew,',
#  'Half closes the garden path.',
#  '',
#  'And when I come to the garden ground,',
#  'The whir of sober birds',
#  'Up from the tangle of withered weeds',
#  'Is sadder than any words',
#  '',
#  'A tree beside the wall stands bare,',
#  'But a leaf that lingered brown,',
#  'Disturbed, I doubt not, by my thought,',
#  'Comes softly rattling down.',
#  '',
#  'I end not far from my going forth',
#  'By picking the faded blue',
#  'Of the last remaining aster flower',
#  'To carry again to you.',
#  '',
#  'A voice said, Look me in the stars',
#  'And tell me truly, men of earth,',
#  'If all the soul-and-body scars',
#  'Were not too much to pay for birth.',
#  '',
#  'To think to know the country and now know',
#  'The hillside on the day the sun lets go',
#  'Ten million silver lizards out of snow!',
#  "As often as I've seen it done before",
#  "I can't pretend to tell the way it's done.",
#  'It looks as if some magic of the sun',
#  'Lifted the rug that bred them on the floor',
#  'And the light breaking on them made them run.',
#  'But if I though to stop the wet stampede,',
#  'And caught one silver lizard by the tail,',
#  'And put my foot on one without avail,',
#  'And threw myself wet-elbowed and wet-kneed',
#  "In front of twenty others' wriggling speed,- ",
#  'In the confusion of them all aglitter,',
#  'And birds that joined in the excited fun',
#  'By doubling and redoubling song and twitter,',
#  "I have no doubt I'd end by holding none.",
#  '',
#  "It takes the moon for this. The sun's a wizard",
#  "By all I tell; but so's the moon a witch.",
#  'From the high west she makes a gentle cast',
#  'And suddenly, without a jerk or twitch,',
#  'She has her speel on every single lizard.',
#  "I fancied when I looked at six o'clock",
#  'The swarm still ran and scuttled just as fast.',
#  'The moon was waiting for her chill effect.',
#  'I looked at nine: the swarm was turned to rock',
#  'In every lifelike posture of the swarm,',
#  'Transfixed on mountain slopes almost erect.',
#  'Across each other and side by side they lay.',
#  'The spell that so could hold them as they were',
#  'Was wrought through trees without a breath of storm',
#  'To make a leaf, if there had been one, stir.',
#  'One lizard at the end of every ray.',
#  'The thought of my attempting such a stray! ',
#  '',
#  'ONCE on the kind of day called "weather breeder,"',
#  'When the heat slowly hazes and the sun',
#  'By its own power seems to be undone,',
#  'I was half boring through, half climbing through',
#  'A swamp of cedar. Choked with oil of cedar',
#  'And scurf of plants, and weary and over-heated,',
#  'And sorry I ever left the road I knew,',
#  'I paused and rested on a sort of hook',
#  'That had me by the coat as good as seated,',
#  'And since there was no other way to look,',
#  'Looked up toward heaven, and there against the blue,',
#  'Stood over me a resurrected tree,',
#  'A tree that had been down and raised again—',
#  'A barkless spectre. He had halted too,',
#  'As if for fear of treading upon me.',
#  'I saw the strange position of his hands—',
#  'Up at his shoulders, dragging yellow strands',
#  'Of wire with something in it from men to men.',
#  '"You here?" I said. "Where aren\'t you nowadays',
#  "And what's the news you carry—if you know?",
#  "And tell me where you're off for—Montreal?",
#  "Me? I'm not off for anywhere at all.",
#  'Sometimes I wander out of beaten ways',
#  'Half looking for the orchid Calypso."',
#  '',
#  'Brown lived at such a lofty farm',
#  'That everyone for miles could see',
#  'His lantern when he did his chores',
#  'In winter after half-past three.',
#  '',
#  'And many must have seen him make',
#  'His wild descent from there one night,',
#  "'Cross lots, 'cross walls, 'cross everything,",
#  'Describing rings of lantern light.',
#  '',
#  'Between the house and barn the gale',
#  'Got him by something he had on',
#  'And blew him out on the icy crust',
#  'That cased the world, and he was gone!',
#  '',
#  'Walls were all buried, trees were few:',
#  'He saw no stay unless he stove',
#  'A hole in somewhere with his heel.',
#  'But though repeatedly he strove',
#  '',
#  'And stamped and said things to himself,',
#  'And sometimes something seemed to yield,',
#  'He gained no foothold, but pursued',
#  'His journey down from field to field.',
#  '',
#  'Sometimes he came with arms outspread',
#  'Like wings, revolving in the scene',
#  'Upon his longer axis, and',
#  'With no small dignity of mien.',
#  '',
#  'Faster or slower as he chanced,',
#  'Sitting or standing as he chose,',
#  'According as he feared to risk',
#  'His neck, or thought to spare his clothes,',
#  '',
#  'He never let the lantern drop.',
#  'And some exclaimed who saw afar',
#  'The figures he described with it,',
#  '"I wonder what those signals are',
#  '',
#  'Brown makes at such an hour of night!',
#  "He's celebrating something strange.",
#  "I wonder if he's sold his farm,",
#  'Or been made Master of the Grange."',
#  '',
#  'He reeled, he lurched, he bobbed, he checked;',
#  'He fell and made the lantern rattle',
#  '(But saved the light from going out.)',
#  'So half-way down he fought the battle',
#  '',
#  'Incredulous of his own bad luck.',
#  'And then becoming reconciled',
#  'To everything, he gave it up',
#  'And came down like a coasting child.',
#  '',
#  '"Well—I—be—" that was all he said,',
#  'As standing in the river road,',
#  'He looked back up the slippery slope',
#  '(Two miles it was) to his abode.',
#  '',
#  'Sometimes as an authority',
#  "On motor-cars, I'm asked if I",
#  'Should say our stock was petered out,',
#  'And this is my sincere reply:',
#  '',
#  'Yankees are what they always were.',
#  "Don't think Brown ever gave up hope",
#  'Of getting home again because',
#  "He couldn't climb that slippery slope;",
#  '',
#  'Or even thought of standing there',
#  'Until the January thaw',
#  'Should take the polish off the crust.',
#  'He bowed with grace to natural law,',
#  '',
#  'And then went round it on his feet,',
#  'After the manner of our stock;',
#  'Not much concerned for those to whom,',
#  "At that particular time o'clock,",
#  '',
#  'It must have looked as if the course',
#  'He steered was really straight away',
#  'From that which he was headed for—',
#  'Not much concerned for them, I say:',
#  '',
#  'No more so than became a man—',
#  'And politician at odd seasons.',
#  "I've kept Brown standing in the cold",
#  'While I invested him with reasons;',
#  '',
#  'But now he snapped his eyes three times;',
#  'Then shook his lantern, saying, "Ile\'s',
#  '\'Bout out!" and took the long way home',
#  'By road, a matter of several miles.',
#  '',
#  "NOW that they've got it settled whose I be,",
#  "I'm going to tell them something they won't like:",
#  "They've got it settled wrong, and I can prove it.",
#  'Flattered I must be to have two towns fighting',
#  'To make a present of me to each other.',
#  "They don't dispose me, either one of them,",
#  "To spare them any trouble. Double trouble's",
#  "Always the witch's motto anyway.",
#  "I'll double theirs for both of them- you watch me.",
#  "They'll find they've got the whole thing to do over,",
#  'That is, if facts is what they want to go by.',
#  "They set a lot (now don't they?) by a record",
#  "Of Arthur Amy's having once been up",
#  'For Hog Reeve in March Meeting here in Warren.',
#  'I could have told them any time this twelvemonth',
#  'The Arthur Amy I was married to',
#  "Couldn't have been the one they say was up",
#  'In Warren at March Meeting for the reason',
#  "He wa'n't but fifteen at the time they say.",
#  'The Arthur Amy I was married to',
#  'voted the only times he ever voted,',
#  "Which wasn't many, in the town of Wentworth.",
#  "One of the times was when 'twas in the warrant",
#  'To see if the town wanted to take over',
#  'The tote road to our clearing where we lived.',
#  "I'll tell you who'd remember- Heman Lapish.",
#  'Their Arthur Amy was the father of mine.',
#  "So now they've dragged it through the law courts once",
#  "I guess they'd better drag it through again.",
#  "Wentworth and Warren's both good towns to live in,",
#  'Only I happen to prefer to live',
#  "In Wentworth from now on; and when all's said,",
#  "Right's right, and the temptation to do right",
#  'When I can hurt someone by doing it',
#  'Has always been too much for me, it has.',
#  "I know of some folks that'd be set up",
#  'At having in their town a noted witch:',
#  'But most would have to think of the expense',
#  'That even I would be. They ought to know',
#  "That as a witch I'd often milk a bat",
#  "And that'd be enough to last for days.",
#  "It'd make my position stronger, I think,",
#  'If I was to consent to give some sign',
#  'To make it surer that I was a witch?',
#  "It wa'n't no sign, I s'pose, when Mallice Huse",
#  'Said that I took him out in his old age',
#  'And rode all over everything on him',
#  "Until I'd had him worn to skin and bones,",
#  "And if I'd left him hitched unblanketed",
#  "In front of one Town Hall, I'd left him hitched",
#  'In front of every one in Grafton County.',
#  'Some cried shame on me not to blanket him,',
#  'The poor old man. It would have been all right',
#  "If some one hadn't said to gnaw the posts",
#  'He stood beside and leave his trade mark on them,',
#  'So they could recognize them. Not a post',
#  'That they could hear tell of was scarified.',
#  'They made him keep on gnawing till he whined.',
#  'Then that same smarty someone said to look- ',
#  "He'd bet Huse was a cribber and had gnawed",
#  "The crib he slept in- and as sure's you're born",
#  "They found he'd gnawed the four posts of his bed,",
#  'All four of them to splinters. What did that prove?',
#  "Not that he hadn't gnawed the hitching posts",
#  'He said he had besides. Because a horse',
#  "Gnaws in the stable ain't no proof to me",
#  "He don't gnaw trees and posts and fences too.",
#  'But everybody took it for proof.',
#  'I was a strapping girl of twenty then.',
#  'The smarty someone who spoiled everything',
#  'Was Arthur Amy. You know who he was.',
#  'That was the way he started courting me.',
#  'He never said much after we were married,',
#  'But I mistrusted he was none too proud',
#  'Of having interfered in the Huse business.',
#  'I guess he found he got more out of me',
#  'By having me a witch. Or something happened',
#  'To turn him round. He got to saying things',
#  "To undo what he'd done and make it right,",
#  "Like, 'No, she ain't come back from kiting yet.",
#  "Last night was one of her nights out. She's kiting.",
#  'She thinks when the wind makes a night of it',
#  "She might as well herself.' But he liked best",
#  'To let on he was plagued to death with me:',
#  'If anyone had seen me coming home',
#  "Over the ridgepole, 'stride of a broomstick,",
#  'As often as he had in the tail of the night,',
#  "He guessed they'd know what he had to put up with.",
#  'Well, I showed Arthur Amy signs enough',
#  'Off from the house as far as we could keep',
#  "And from barn smells you can't wash out of ploughed ground",
#  'With all the rain and snow of seven years;',
#  "And I don't mean just skulls of Roger's Rangers",
#  'On Moosilauke, but woman signs to man,',
#  'Only bewitched so I would last him longer.',
#  'Up where the trees grow short, the mosses tall,',
#  'I made him gather me wet snow berries',
#  'On slippery rocks beside a waterfall.',
#  'I made him do it for me in the dark.',
#  'And he liked everything I made him do.',
#  'I hope if he is where he sees me now',
#  "He's so far off he can't see what I've come to.",
#  'You _can_ come down from everything to nothing.',
#  "All is, if I'd a-known when I was young",
#  'And full of it, that this would be the end,',
#  "It doesn't seem as if I'd had the courage",
#  "To make so free and kick up in folks' faces.",
#  "I might have, but it doesn't seem as if.",
#  '',
#  'Old Davis owned a solid mica mountain',
#  'In Dalton that would someday make his fortune.',
#  "There'd been some Boston people out to see it:",
#  'And experts said that deep down in the mountain',
#  'The mica sheets were big as plate-glass windows.',
#  "He'd like to take me there and show it to me.",
#  '',
#  "'I'll tell you what you show me. You remember",
#  'You said you knew the place where once, on Kinsman,',
#  'The early Mormons made a settlement',
#  'And built a stone baptismal font outdoors-',
#  'But Smith, or someone, called them off the mountain',
#  'To go West to a worse fight with the desert.',
#  "You said you'd seen the stone baptismal font.",
#  "Well, take me there.'",
#  '',
#  "Someday I will.'",
#  '',
#  "'Today.'",
#  '',
#  "'Huh, that old bathtub, what is that to see?",
#  "Let's talk about it.'",
#  '',
#  "'Let's go see the place.'",
#  '',
#  "'To shut you up I'll tell you what I'll do:",
#  "I'll find that fountain if it takes all summer,",
#  "And both of our united strengths, to do it.'",
#  '',
#  "'You've lost it, then?'",
#  '',
#  "'Not so but I can find it.",
#  "No doubt it's grown up some to woods around it.",
#  'The mountain may have shifted since I saw it',
#  "In eighty-five.'",
#  '',
#  "'As long ago as that?'",
#  '',
#  "'If I remember rightly, it had sprung",
#  'A leak and emptied then. And forty years',
#  'Can do a good deal to bad masonry.',
#  "You won't see any Mormon swimming in it.",
#  "But you have said it, and we're off to find it.",
#  "Old as I am, I'm going to let myself",
#  "Be dragged by you all over everywhere- '",
#  "'I thought you were a guide.'",
#  '',
#  "'I am a guide,",
#  "And that's why I can't decently refuse you.'",
#  '',
#  'We made a day of it out of the world,',
#  'Ascending to descend to reascend.',
#  'The old man seriously took his bearings,',
#  'And spoke his doubts in every open place.',
#  '',
#  'We came out on a look-off where we faced',
#  'A cliff, and on the cliff a bottle painted,',
#  'Or stained by vegetation from above,',
#  'A likeness to surprise the thrilly tourist.',
#  '',
#  "'Well, if I haven't brought you to the fountain,",
#  "At least I've brought you to the famous Bottle.'",
#  '',
#  "'I won't accept the substitute. It's empty.'",
#  '',
#  "'So's everything.'",
#  '',
#  "'I want my fountain.'",
#  '',
#  "'I guess you'd find the fountain just as empty.",
#  "And anyway this tells me where I am.'",
#  '',
#  "'Hadn't you long suspected where you were?'",
#  '',
#  "'You mean miles from that Mormon settlement?",
#  'Look here, you treat your guide with due respect',
#  "If you don't want to spend the night outdoors.",
#  'I vow we must be near the place from where',
#  'The two converging slides, the avalanches,',
#  "On Marshall, look like donkey's ears.",
#  "We may as well see that and save the day.'",
#  '',
#  "'Don't donkey's ears suggest we shake our own?'",
#  '',
#  "'For God's sake, aren't you fond of viewing nature?",
#  "You don't like nature. All you like is books.",
#  "What signify a donkey's cars and bottle,",
#  'However natural? Give you your books!',
#  'Well then, right here is where I show you books.',
#  'Come straight down off this mountain just as fast',
#  'As we can fall and keep a-bouncing on our feet.',
#  "It's hell for knees unless done hell-for-leather.'",
#  '',
#  'Be ready, I thought, for almost anything.',
#  '',
#  "We struck a road I didn't recognize,",
#  'But welcomed for the chance to lave my shoes',
#  'In dust once more. We followed this a mile,',
#  'Perhaps, to where it ended at a house',
#  "I didn't know was there. It was the kind",
#  'To bring me to for broad-board paneling.',
#  'I never saw so good a house deserted.',
#  '',
#  "'Excuse me if I ask you in a window",
#  'That happens to be broken, Davis said.',
#  "'The outside doors as yet have held against us.",
#  'I want to introduce you to the people',
#  'Who used to live here. They were Robinsons.',
#  'You must have heard of Clara Robinson,',
#  'The poetess who wrote the book of verses',
#  'And had it published. It was all about',
#  'The posies on her inner windowsill,',
#  'And the birds on her outer windowsill,',
#  'And how she tended both, or had them tended:',
#  'She never tended anything herself.',
#  "She was 'shut in' for life. She lived her whole",
#  'Life long in bed, and wrote her things in bed.',
#  "I'll show You how she had her sills extended",
#  'To entertain the birds and hold the flowers.',
#  "Our business first's up attic with her books.'",
#  '',
#  'We trod uncomfortably on crunching glass',
#  'Through a house stripped of everything',
#  "Except, it seemed, the poetess's poems.",
#  'Books, I should say!- if books are what is needed.',
#  'A whole edition in a packing case',
#  'That, overflowing like a horn of plenty,',
#  "Or like the poetess's heart of love,",
#  'Had spilled them near the window, toward the light',
#  'Where driven rain had wet and swollen them.',
#  'Enough to stock a village library-',
#  'Unfortunately all of one kind, though.',
#  'They bad been brought home from some publisher',
#  'And taken thus into the family.',
#  'Boys and bad hunters had known what to do',
#  'With stone and lead to unprotected glass:',
#  'Shatter it inward on the unswept floors.',
#  'How had the tender verse escaped their outrage?',
#  'By being invisible for what it was,',
#  'Or else by some remoteness that defied them',
#  'To find out what to do to hurt a poem.',
#  'Yet oh! the tempting flatness of a book,',
#  'To send it sailing out the attic window',
#  'Till it caught wind and, opening out its covers,',
#  'Tried to improve on sailing like a tile',
#  'By flying like a bird (silent in flight,',
#  'But all the burden of its body song),',
#  'Only to tumble like a stricken bird,',
#  'And lie in stones and bushes unretrieved.',
#  'Books were not thrown irreverently about.',
#  'They simply lay where someone now and then,',
#  'Having tried one, had dropped it at his feet',
#  'And left it lying where it fell rejected.',
#  "Here were all those the poetess's life",
#  'Had been too short to sell or give away.',
#  '',
#  "'Take one,' Old Davis bade me graciously.",
#  '',
#  "'Why not take two or three?'",
#  '',
#  "'Take all you want.'",
#  "Good-looking books like that.' He picked one fresh",
#  'In virgin wrapper from deep in the box,',
#  'And stroked it with a horny-handed kindness.',
#  'He read in one and I read in another,',
#  'Both either looking for or finding something.',
#  '',
#  'The attic wasps went missing by like bullets.',
#  '',
#  'I was soon satisfied for the time being.',
#  '',
#  'All the way home I kept remembering',
#  'The small book in my pocket. It was there.',
#  'The poetess had sighed, I knew, in heaven',
#  'At having eased her heart of one more copy-',
#  'Legitimately. My demand upon her,',
#  'Though slight, was a demand. She felt the tug.',
#  'In time she would be rid of all her books.',
#  '',
#  'I stay;',
#  "But it isn't as if",
#  "There wasn't always Hudson's Bay",
#  'And the fur trade,',
#  'A small skiff',
#  'And a paddle blade.',
#  '',
#  'I can just see my tent pegged,',
#  'And me on the floor,',
#  'Cross-legged,',
#  'And a trapper looking in at the door',
#  'With furs to sell.',
#  '',
#  "His name's Joe,",
#  'Alias John,',
#  "And between what he doesn't know",
#  "And won't tell",
#  "About where Henry Hudson's gone,",
#  "I can't say he's much help;",
#  'But we get on.',
#  '',
#  'The seal yelp',
#  'On an ice cake.',
#  "It's not men by some mistake?",
#  'No,',
#  "There's not a soul",
#  'For a windbreak',
#  'Between me and the North Pole—',
#  '',
#  'Except always John-Joe,',
#  'My French Indian Esquimaux,',
#  "And he's off setting traps",
#  'In one himself perhaps.',
#  '',
#  'Give a headshake',
#  'Over so much bay',
#  'Thrown away',
#  'In snow and mist',
#  "That doesn't exist,",
#  '',
#  'I was going to say,',
#  "For God, man, or beast's sake,",
#  'Yet does perhaps for all three.',
#  '',
#  "Don't ask Joe",
#  'What it is to him.',
#  "It's sometimes dim",
#  'What it is to me,',
#  'Unless it be',
#  "It's the old captain's dark fate",
#  'Who failed to find or force a strait',
#  'In its two-thousand-mile coast;',
#  'And his crew left him where be failed,',
#  'And nothing came of all be sailed.',
#  '',
#  "It's to say, 'You and I—'",
#  'To such a ghost—',
#  'You and I',
#  'Off here',
#  "With the dead race of the Great Auk!'",
#  "And, 'Better defeat almost,",
#  'If seen clear,',
#  "Than life's victories of doubt",
#  'That need endless talk-talk',
#  "To make them out.' ",
#  '',
#  'I staid the night for shelter at a farm',
#  'Behind the mountains, with a mother and son,',
#  'Two old-believers. They did all the talking.',
#  '',
#  'MOTHER Folks think a witch who has familiar spirits',
#  'She could call up to pass a winter evening,',
#  "But won't, should be burned at the stake or something.",
#  "Summoning spirits isn't 'Button, button,",
#  "Who's got the button,' I would have them know.",
#  '',
#  'SON: Mother can make a common table rear',
#  'And kick with two legs like an army mule.',
#  '',
#  "MOTHER: And when I've done it, what good have I",
#  'done?',
#  'Rather than tip a table for you, let me',
#  'Tell you what Ralle the Sioux Control once told me.',
#  'He said the dead had souls, but when I asked him',
#  'How could that be - I thought the dead were souls,',
#  "He broke my trance. Don't that make you suspicious",
#  "That there's something the dead are keeping back?",
#  "Yes, there's something the dead are keeping back.",
#  '',
#  "SON: You wouldn't want to tell him what we have",
#  'Up attic, mother?',
#  '',
#  'MOTHER: Bones - a skeleton.',
#  '',
#  "SON: But the headboard of mother's bed is pushed",
#  "Against the' attic door: the door is nailed.",
#  "It's harmless. Mother hears it in the night",
#  'Halting perplexed behind the barrier',
#  'Of door and headboard. Where it wants to get',
#  'Is back into the cellar where it came from.',
#  '',
#  "MOTHER: We'll never let them, will we, son! We'll",
#  'never !',
#  '',
#  'SON: It left the cellar forty years ago',
#  'And carried itself like a pile of dishes',
#  'Up one flight from the cellar to the kitchen,',
#  'Another from the kitchen to the bedroom,',
#  'Another from the bedroom to the attic,',
#  'Right past both father and mother, and neither stopped',
#  'it.',
#  'Father had gone upstairs; mother was downstairs.',
#  "I was a baby: I don't know where I was.",
#  '',
#  'MOTHER: The only fault my husband found with me - ',
#  'I went to sleep before I went to bed,',
#  'Especially in winter when the bed',
#  'Might just as well be ice and the clothes snow.',
#  'The night the bones came up the cellar-stairs',
#  'Toffile had gone to bed alone and left me,',
#  'But left an open door to cool the room off',
#  'So as to sort of turn me out of it.',
#  'I was just coming to myself enough',
#  'To wonder where the cold was coming from,',
#  'When I heard Toffile upstairs in the bedroom',
#  'And thought I heard him downstairs in the cellar.',
#  'The board we had laid down to walk dry-shod on',
#  'When there was water in the cellar in spring',
#  'Struck the hard cellar bottom. And then someone',
#  'Began the stairs, two footsteps for each step,',
#  'The way a man with one leg and a crutch,',
#  "Or a little child, comes up. It wasn't Toffile:",
#  "It wasn't anyone who could be there.",
#  'The bulkhead double-doors were double-locked',
#  'And swollen tight and buried under snow.',
#  'The cellar windows were banked up with sawdust',
#  'And swollen tight and buried under snow.',
#  'It was the bones. I knew them - and good reason.',
#  'My first impulse was to get to the knob',
#  "And hold the door. But the bones didn't try",
#  'The door; they halted helpless on the landing,',
#  "Waiting for things to happen in their favour.'",
#  'The faintest restless rustling ran all through them.',
#  'I never could have done the thing I did',
#  "If the wish hadn't been too strong in me",
#  'To see how they were mounted for this walk.',
#  'I had a vision of them put together',
#  'Not like a man, but like a chandelier.',
#  'So suddenly I flung the door wide on him.',
#  'A moment he stood balancing with emotion,',
#  'And all but lost himself. (A tongue of fire',
#  'Flashed out and licked along his upper teeth.',
#  'Smoke rolled inside the sockets of his eyes.)',
#  'Then he came at me with one hand outstretched,',
#  'The way he did in life once; but this time',
#  'I struck the hand off brittle on the floor,',
#  'And fell back from him on the floor myself.',
#  'The finger-pieces slid in all directions.',
#  '(Where did I see one of those pieces lately?',
#  'Hand me my button-box- it must be there.)',
#  "I sat up on the floor and shouted, 'Toffile,",
#  "It's coming up to you.' It had its choice",
#  'Of the door to the cellar or the hall.',
#  'It took the hall door for the novelty,',
#  'And set off briskly for so slow a thing,',
#  'Stillgoing every which way in the joints, though,',
#  'So that it looked like lightning or a scribble,',
#  '>From the slap I had just now given its hand.',
#  'I listened till it almost climbed the stairs',
#  '>From the hall to the only finished bedroom,',
#  'Before I got up to do anything;',
#  "Then ran and shouted, 'Shut the bedroom door,",
#  "Toffile, for my sake!' 'Company?' he said,",
#  "'Don't make me get up; I'm too warm in bed.'",
#  'So lying forward weakly on the handrail',
#  'I pushed myself upstairs, and in the light',
#  '(The kitchen had been dark) I had to own',
#  "I could see nothing. 'Toffile, I don't see it.",
#  "It's with us in the room though. It's the bones.'",
#  "'What bones?' 'The cellar bones- out of the grave.'",
#  'That made him throw his bare legs out of bed',
#  'And sit up by me and take hold of me.',
#  'I wanted to put out the light and see',
#  'If I could see it, or else mow the room,',
#  'With our arms at the level of our knees,',
#  "And bring the chalk-pile down. 'I'll tell you what-",
#  "It's looking for another door to try.",
#  'The uncommonly deep snow has made him think',
#  'Of his old song, The Wild Colonial Boy,',
#  'He always used to sing along the tote-road.',
#  "He's after an open door to get out-doors.",
#  "Let's trap him with an open door up attic.'",
#  'Toffile agreed to that, and sure enough,',
#  'Almost the moment he was given an opening,',
#  'The steps began to climb the attic stairs.',
#  "I heard them. Toffile didn't seem to hear them.",
#  "'Quick !' I slammed to the door and held the knob.",
#  "'Toffile, get nails.' I made him nail the door shut,",
#  'And push the headboard of the bed against it.',
#  'Then we asked was there anything',
#  "Up attic that we'd ever want again.",
#  'The attic was less to us than the cellar.',
#  'If the bones liked the attic, let them have it.',
#  'Let them stay in the attic. When they sometimes',
#  'Come down the stairs at night and stand perplexed',
#  'Behind the door and headboard of the bed,',
#  'Brushing their chalky skull with chalky fingers,',
#  'With sounds like the dry rattling of a shutter,',
#  "That's what I sit up in the dark to say-",
#  'To no one any more since Toffile died.',
#  '2o3 Let them stay in the attic since they went there.',
#  'I promised Toffile to be cruel to them',
#  'For helping them be cruel once to him.',
#  '',
#  'SON: We think they had a grave down in the cellar.',
#  '',
#  'MOTHER: We know they had a grave down in the cellar.',
#  '',
#  'SON: We never could find out whose bones they were.',
#  '',
#  'MOTHER: Yes, we could too, son. Tell the truth for once.',
#  "They were a man's his father killed for me.",
#  'I mean a man he killed instead of me.',
#  'The least I could do was to help dig their grave.',
#  'We were about it one night in the cellar.',
#  "Son knows the story: but 'twas not for him",
#  'To tell the truth, suppose the time had come.',
#  'Son looks surprised to see me end a lie',
#  "We'd kept all these years between ourselves",
#  'So as to have it ready for outsiders.',
#  "But to-night I don't care enough to lie-",
#  "I don't remember why I ever cared.",
#  "Toffile, if he were here, I don't believe",
#  'Could tell you why he ever cared himself-',
#  '',
#  "She hadn't found the finger-bone she wanted",
#  'Among the buttons poured out in her lap.',
#  'I verified the name next morning: Toffile.',
#  'The rural letter-box said Toffile Lajway.',
#  '',
#  'The west was getting out of gold,',
#  'The breath of air had died of cold,',
#  'When shoeing home across the white,',
#  'I thought I saw a bird alight.',
#  '',
#  'In summer when I passed the place',
#  'I had to stop and lift my face;',
#  'A bird with an angelic gift',
#  'Was singing in it sweet and swift.',
#  '',
#  'No bird was singing in it now.',
#  'A single leaf was on a bough,',
#  'And that was all there was to see',
#  'In going twice around the tree.',
#  '',
#  'From my advantage on a hill',
#  'I judged that such a crystal chill',
#  'Was only adding frost to snow',
#  "As gilt to gold that wouldn't show.",
#  '',
#  'A brush had left a crooked stroke',
#  'Of what was either cloud or smoke',
#  'From north to south across the blue;',
#  'A piercing little star was through.',
#  '',
#  'A governor it was proclaimed this time, ',
#  'When all who would come seeking in New Hampshire ',
#  'Ancestral memories might come together. ',
#  'And those of the name Stark gathered in Bow, ',
#  'A rock-strewn town where farming has fallen off, ',
#  'And sprout-lands flourish where the axe has gone. ',
#  'Someone had literally run to earth ',
#  'In an old cellar hole in a by-road ',
#  'The origin of all the family there. ',
#  'Thence they were sprung, so numerous a tribe ',
#  'That now not all the houses left in town ',
#  'Made shift to shelter them without the help ',
#  'Of here and there a tent in grove and orchard. ',
#  'They were at Bow, but that was not enough: ',
#  'Nothing would do but they must fix a day ',
#  "To stand together on the crater's verge ",
#  'That turned them on the world, and try to fathom ',
#  'The past and get some strangeness out of it. ',
#  'But rain spoiled all. The day began uncertain, ',
#  'With clouds low trailing and moments of rain that misted. ',
#  'The young folk held some hope out to each other ',
#  'Till well toward noon when the storm settled down ',
#  "With a swish in the grass. 'What if the others ",
#  "Are there,' they said. 'It isn't going to rain.' ",
#  'Only one from a farm not far away ',
#  'Strolled thither, not expecting he would find ',
#  'Anyone else, but out of idleness. ',
#  'One, and one other, yes, for there were two. ',
#  'The second round the curving hillside road ',
#  'Was a girl; and she halted some way off ',
#  'To reconnoitre, and then made up her mind ',
#  'At least to pass by and see who he was, ',
#  'And perhaps hear some word about the weather. ',
#  "This was some Stark she didn't know. He nodded. ",
#  "'No fête to-day,' he said. ",
#  "'It looks that way.' ",
#  'She swept the heavens, turning on her heel. ',
#  "'I only idled down.' ",
#  "'I idled down.' ",
#  'Provision there had been for just such meeting ',
#  'Of stranger cousins, in a family tree ',
#  'Drawn on a sort of passport with the branch ',
#  'Of the one bearing it done in detail- ',
#  "Some zealous one's laborious device. ",
#  'She made a sudden movement toward her bodice, ',
#  'As one who clasps her heart. They laughed together. ',
#  "'Stark?' he inquired. 'No matter for the proof.' ",
#  "'Yes, Stark. And you?' ",
#  "'I'm Stark.' He drew his passport. ",
#  "'You know we might not be and still be cousins: ",
#  'The town is full of Chases, Lowes, and Baileys, ',
#  'All claiming some priority in Starkness. ',
#  'My mother was a Lane, yet might have married ',
#  'Anyone upon earth and still her children ',
#  "Would have been Starks, and doubtless here to-day.' ",
#  "'You riddle with your genealogy ",
#  "Like a Viola. I don't follow you.' ",
#  "'I only mean my mother was a Stark ",
#  'Several times over, and by marrying father ',
#  "No more than brought us back into the name.' ",
#  "'One ought not to be thrown into confusion ",
#  'By a plain statement of relationship, ',
#  'But I own what you say makes my head spin. ',
#  'You take my card- you seem so good at such things- ',
#  'And see if you can reckon our cousinship. ',
#  'Why not take seats here on the cellar wall ',
#  "And dangle feet among the raspberry vines?' ",
#  "'Under the shelter of the family tree.' ",
#  "'Just so- that ought to be enough protection.' ",
#  "'Not from the rain. I think it's going to rain.' ",
#  "'It's raining.' ",
#  "'No, it's misting; let's be fair. ",
#  "Does the rain seem to you to cool the eyes?' ",
#  'The situation was like this: the road ',
#  'Bowed outward on the mountain half-way up, ',
#  'And disappeared and ended not far off. ',
#  'No one went home that way. The only house ',
#  'Beyond where they were was a shattered seedpod. ',
#  'And below roared a brook hidden in trees, ',
#  'The sound of which was silence for the place. ',
#  'This he sat listening to till she gave judgment. ',
#  "'On father's side, it seems, we're- let me see- - ' ",
#  "'Don't be too technical.- You have three cards.' ",
#  "'Four cards, one yours, three mine, one for each branch ",
#  "Of the Stark family I'm a member of.' ",
#  "'D'you know a person so related to herself ",
#  "Is supposed to be mad.' ",
#  "'I may be mad.' ",
#  "'You look so, sitting out here in the rain ",
#  'Studying genealogy with me ',
#  'You never saw before. What will we come to ',
#  'With all this pride of ancestry, we Yankees? ',
#  "I think we're all mad. Tell me why we're here ",
#  'Drawn into town about this cellar hole ',
#  'Like wild geese on a lake before a storm? ',
#  "What do we see in such a hole, I wonder.' ",
#  "'The Indians had a myth of Chicamoztoc, ",
#  'Which means The Seven Caves that We Came out of. ',
#  "This is the pit from which we Starks were digged.' ",
#  "'You must be learned. That's what you see in it?' ",
#  "'And what do you see?' ",
#  "'Yes, what do I see? ",
#  "First let me look. I see raspberry vines- - ' ",
#  "'Oh, if you're going to use your eyes, just hear ",
#  "What I see. It's a little, little boy, ",
#  'As pale and dim as a match flame in the sun; ',
#  "He's groping in the cellar after jam, ",
#  "He thinks it's dark and it's flooded with daylight.' ",
#  "'He's nothing. Listen. When I lean like this ",
#  'I can make out old Grandsir Stark distinctly,- ',
#  'With his pipe in his mouth and his brown jug- ',
#  "Bless you, it isn't Grandsir Stark, it's Granny, ",
#  "But the pipe's there and smoking and the jug. ",
#  "She's after cider, the old girl, she's thirsty; ",
#  "Here's hoping she gets her drink and gets out safely.' ",
#  "'Tell me about her. Does she look like me?' ",
#  "'She should, shouldn't she, you're so many times ",
#  'Over descended from her. I believe ',
#  'She does look like you. Stay the way you are. ',
#  "The nose is just the same, and so's the chin- ",
#  "Making allowance, making due allowance.' ",
#  "'You poor, dear, great, great, great, great Granny!' ",
#  "'See that you get her greatness right. Don't stint her.' ",
#  "'Yes, it's important, though you think it isn't. ",
#  "I won't be teased. But see how wet I am.' ",
#  "'Yes, you must go; we can't stay here for ever. ",
#  'But wait until I give you a hand up. ',
#  'A bead of silver water more or less ',
#  "Strung on your hair won't hurt your summer looks. ",
#  'I wanted to try something with the noise ',
#  'That the brook raises in the empty valley. ',
#  'We have seen visions- now consult the voices. ',
#  'Something I must have learned riding in trains ',
#  'When I was young. I used the roar ',
#  'To set the voices speaking out of it, ',
#  'Speaking or singing, and the band-music playing. ',
#  'Perhaps you have the art of what I mean. ',
#  "I've never listened in among the sounds ",
#  'That a brook makes in such a wild descent. ',
#  "It ought to give a purer oracle.' ",
#  "'It's as you throw a picture on a screen: ",
#  'The meaning of it all is out of you; ',
#  "The voices give you what you wish to hear.' ",
#  "'Strangely, it's anything they wish to give.' ",
#  "'Then I don't know. It must be strange enough. ",
#  "I wonder if it's not your make-believe. ",
#  "What do you think you're like to hear to-day?' ",
#  "'From the sense of our having been together- ",
#  "But why take time for what I'm like to hear? ",
#  "I'll tell you what the voices really say. ",
#  'You will do very well right where you are ',
#  "A little longer. I mustn't feel too hurried, ",
#  "Or I can't give myself to hear the voices.' ",
#  "'Is this some trance you are withdrawing into?' ",
#  "'You must be very still; you mustn't talk.' ",
#  "'I'll hardly breathe.' ",
#  "'The voices seem to say- - ' ",
#  "'I'm waiting.' ",
#  "'Don't! The voices seem to say: ",
#  'Call her Nausicaa, the unafraid ',
#  "Of an acquaintance made adventurously.' ",
#  "'I let you say that- on consideration.' ",
#  "'I don't see very well how you can help it. ",
#  'You want the truth. I speak but by the voices. ',
#  "You see they know I haven't had your name, ",
#  "Though what a name should matter between us- - ' ",
#  "'I shall suspect- - ' ",
#  "'Be good. The voices say: ",
#  'Call her Nausicaa, and take a timber ',
#  'That you shall find lies in the cellar charred ',
#  'Among the raspberries, and hew and shape it ',
#  'For a door-sill or other corner piece ',
#  'In a new cottage on the ancient spot. ',
#  'The life is not yet all gone out of it. ',
#  'And come and make your summer dwelling here, ',
#  'And perhaps she will come, still unafraid, ',
#  'And sit before you in the open door ',
#  'With flowers in her lap until they fade, ',
#  "But not come in across the sacred sill- - ' ",
#  "'I wonder where your oracle is tending. ",
#  "You can see that there's something wrong with it, ",
#  'Or it would speak in dialect. Whose voice ',
#  "Does it purport to speak in? Not old Grandsir's ",
#  "Nor Granny's, surely. Call up one of them. ",
#  ...]

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
#collect data into lists
input_text = []
labels = []

for line in eap_list:
    line = line.lower()
    if line:
        line = line.translate(str.maketrans('', '', string.punctuation))
        labels.append(0)
        input_text.append(line)
        
for line in rf_list:
    line = line.lower()
    if line:
        line = line.translate(str.maketrans('', '', string.punctuation))
        labels.append(1)
        input_text.append(line)
        
input_text
# Out:
# ['lo death hath reard himself a throne',
#  'in a strange city all alone',
#  'far down within the dim west',
#  'where the good and the bad and the worst and the best',
#  'have gone to their eternal rest',
#  '\u2009',
#  'there shrines and palaces and towers',
#  'are not like any thing of ours',
#  'oh no o no ours never loom',
#  'to heaven with that ungodly gloom',
#  'timeeaten towers that tremble not',
#  'resemble nothing that is ours',
#  'around by lifting winds forgot',
#  'resignedly beneath the sky',
#  'the melancholy waters lie',
#  '\u2009',
#  'no holy rays from heaven come down',
#  'on the long nighttime of that town',
#  'but light from out the lurid sea',
#  'streams up the turrets silently',
#  'up thrones up longforgotten bowers',
#  'of sculturd ivy and stone flowers',
#  'up domes up spires up kingly halls',
#  'up fanes up babylonlike walls',
#  'up many a melancholy shrine',
#  'whose entablatures intertwine',
#  'the mask the viol and the vine',
#  '\u2009',
#  'there open temples open graves',
#  'are on a level with the waves',
#  'but not the riches there that lie',
#  'in each idols diamond eye',
#  'not the gailyjewelld dead',
#  'tempt the waters from their bed',
#  'for no ripples curl alas',
#  'along that wilderness of glass',
#  'no swellings hint that winds may be',
#  'upon a faroff happier sea',
#  'so blend the turrets and shadows there',
#  'that all seem pendulous in air',
#  'while from the high towers of the town',
#  'death looks gigantically down',
#  '\u2009',
#  'but lo a stir is in the air',
#  'the wave there is a ripple there',
#  'as if the towers had thrown aside',
#  'in slightly sinking the dull tide',
#  'as if the turrettops had given',
#  'a vacuum in the filmy heaven',
#  'the waves have now a redder glow',
#  'the very hours are breathing low',
#  'and when amid no earthly moans',
#  'down down that town shall settle hence',
#  'all hades from a thousand thrones',
#  'shall do it reverence',
#  'and death to some more happy clime',
#  'shall give his undivided time',
#  'the skies they were ashen and sober',
#  'the leaves they were crisped and sere ',
#  'the leaves they were withering and sere',
#  'it was night in the lonesome october',
#  'of my most immemorial year',
#  'it was hard by the dim lake of auber',
#  'in the misty mid region of weir ',
#  'it was down by the dank tarn of auber',
#  'in the ghoulhaunted woodland of weir',
#  'here once through an alley titanic',
#  'of cypress i roamed with my soul ',
#  'of cypress with psyche my soul',
#  'these were days when my heart was volcanic',
#  'as the scoriac rivers that roll ',
#  'as the lavas that restlessly roll',
#  'their sulphurous currents down yaanek',
#  'in the ultimate climes of the pole ',
#  'that groan as they roll down mount yaanek',
#  'in the realms of the boreal pole',
#  'our talk had been serious and sober',
#  'but our thoughts they were palsied and sere ',
#  'our memories were treacherous and sere ',
#  'for we knew not the month was october',
#  'and we marked not the night of the year ',
#  'ah night of all nights in the year',
#  'we noted not the dim lake of auber ',
#  'though once we had journey down here',
#  'remembered not the dank tarn of auber',
#  'nor the ghoulhaunted woodland of weir',
#  'and now as the night was senescent',
#  'and stardials pointed to morn ',
#  'as the stardials hinted of morn ',
#  'at the end of our path a liquescent',
#  'and nebulous lustre was born',
#  'out of which a miraculous crescent',
#  'arose with a duplicate horn ',
#  'astartes bediamonded crescent',
#  'distinct with its duplicate horn',
#  'and i said  she is warmer than dian',
#  'she rolls through an ether of sighs ',
#  'she revels in a region of sighs',
#  'she has seen that the tears are not dry on',
#  'these cheeks where the worm never dies',
#  'and has come past the stars of the lion',
#  'to point us the path to the skies ',
#  'to the lethean peace of the skies ',
#  'come up in despite of the lion',
#  'to shine on us with her bright eyes ',
#  'come up through the lair of the lion',
#  'with love in her luminous eyes',
#  'but psyche uplifting her finger',
#  'said  sadly this star i mistrust ',
#  'her pallor i strangely mistrust ',
#  'oh hasten  oh let us not linger',
#  'oh fly  let us fly  for we must',
#  'in terror she spoke letting sink her',
#  'wings until they trailed in the dust ',
#  'in agony sobbed letting sink her',
#  'plumes till they trailed in the dust ',
#  'till they sorrowfully trailed in the dust',
#  'i replied  this is nothing but dreaming',
#  'let us on by this tremulous light',
#  'let us bathe in this crystalline light',
#  'its sybilic splendor is beaming',
#  'with hope and in beauty tonight ',
#  'see  it flickers up the sky through the night',
#  'ah we safely may trust to its gleaming',
#  'and be sure it will lead us aright ',
#  'we safely may trust to a gleaming',
#  'that cannot but guide us aright',
#  'since it flickers up to heaven through the night',
#  'thus i pacified psyche and kissed her',
#  'and tempted her out of her gloom ',
#  'and conquered her scruples and gloom',
#  'and we passed to the end of the vista',
#  'but were stopped by the door of a tomb ',
#  'by the door of a legended tomb',
#  'and i said  what is written sweet sister',
#  'on the door of this legended tomb',
#  'she replied  ulalume  ulalume ',
#  '‘tis the vault of thy lost ulalume',
#  'then my heart it grew ashen and sober',
#  'as the leaves that were crisped and sere ',
#  'as the leaves that were withering and sere',
#  'and i cried  it was surely october',
#  'on this very night of last year',
#  'that i journeyed  i journeyed down here ',
#  'that i brought a dread burden down here',
#  'on this night of all nights in the year',
#  'ah what demon has tempted me here',
#  'well i know now this dim lake of auber ',
#  'this misty mid region of weir ',
#  'well i know now this dank tarn of auber ',
#  'this ghoulhaunted woodland of weir',
#  'wreathed in myrtle my sword ill conceal',
#  'like those champions devoted and brave',
#  'when they plunged in the tyrant their steel',
#  'and to athens deliverance gave ',
#  'beloved heroes your deathless souls roam',
#  'in the joy breathing isles of the blest',
#  'where the mighty of old have their home ',
#  'where achilles and diomed rest ',
#  'in fresh myrtle my blade ill entwine',
#  'like harmodious the gallant and good',
#  'when he made at the tutelar shrine',
#  'a libation of tyrannys blood ',
#  'ye deliverers of athens from shame',
#  'ye avengers of libertys wrongs',
#  'endless ages shall cherish your fame',
#  'embalmed in their echoing songs',
#  'of all who hail thy presence as the morning',
#  'of all to whom thine absence is the night',
#  'the blotting utterly from out high heaven',
#  'the sacred sun of all who weeping bless thee',
#  'hourly for hope for life ah above all',
#  'for the resurrection of deepburied faith',
#  'in truth in virtue in humanity',
#  'of all who on despairs unhallowed bed',
#  'lying down to die have suddenly arisen',
#  'at thy softmurmured words let there be light',
#  'at the softmurmured words that were fulfilled',
#  'in the seraphic glancing of thine eyes',
#  'of all who owe thee most whose gratitude',
#  'nearest resembles worship oh remember',
#  'the truest the most fervently devoted',
#  'and think that these weak lines are written by him',
#  'by him who as he pens them thrills to think',
#  'his spirit is communing with an angels ',
#  'thou wouldst be loved then let thy heart',
#  'from its present pathway part not',
#  'being everything which now thou art',
#  'be nothing which thou art not',
#  'so with the world thy gentle ways',
#  'thy grace thy more than beauty',
#  'shall be an endless theme of praise',
#  'and love a simple duty ',
#  'when from your gems of thought i turn ',
#  'to those pure orbs your heart to learn ',
#  'i scarce know which to prize most high ',
#  'the bright idea or the bright deareye',
#  'of all who hail thy presence as the morning',
#  'of all to whom thine absence is the night',
#  'the blotting utterly from out high heaven',
#  'the sacred sun of all who weeping bless thee',
#  'hourly for hope for life ah above all',
#  'for the resurrection of deepburied faith',
#  'in truth in virtue in humanity',
#  'of all who on despairs unhallowed bed',
#  'lying down to die have suddenly arisen',
#  'at thy softmurmured words let there be light',
#  'at the softmurmured words that were fulfilled',
#  'in the seraphic glancing of thine eyes',
#  'of all who owe thee most whose gratitude',
#  'nearest resembles worship oh remember',
#  'the truest the most fervently devoted',
#  'and think that these weak lines are written by him',
#  'by him who as he pens them thrills to think',
#  'his spirit is communing with an angels',
#  'fair isle that from the fairest of all flowers',
#  'thy gentlest of all gentle names dost take',
#  'how many memories of what radiant hours',
#  'at sight of thee and thine at once awake',
#  'how many scenes of what departed bliss',
#  'how many thoughts of what entombed hopes',
#  'how many visions of a maiden that is',
#  'no more no more upon thy verdant slopes',
#  'no more alas that magical sad sound',
#  'transforming all thy charms shall please no more',
#  'thy memory no more accursed ground',
#  'henceforth i hold thy flowerenameled shore',
#  'o hyacinthine isle o purple zante',
#  'isola doro fior di levante',
#  'o i care not that my earthly lot',
#  'hath little of earth in it',
#  'that years of love have been forgot',
#  'in the fever of a minute',
#  'i heed not that the desolate',
#  'are happier sweet than i',
#  'but that you meddle with my fate',
#  'who am a passer by',
#  'it is not that my founts of bliss',
#  'are gushing strange with tears',
#  'or that the thrill of a single kiss',
#  'hath palsied many years',
#  'tis not that the flowers of twenty springs',
#  'which have witherd as they rose',
#  'lie dead on my heartstrings',
#  'with the weight of an age of snows',
#  'not that the grass o may it thrive',
#  'on my grave is growing or grown',
#  'but that while i am dead yet alive',
#  'i cannot be lady alone',
#  'sancta maria turn thine eyes ',
#  'upon the sinners sacrifice',
#  'of fervent prayer and humble love',
#  'from thy holy throne above ',
#  'at morn  at noon  at twilight dim ',
#  'maria thou hast heard my hymn',
#  'in joy and wo  in good and ill ',
#  'mother of god be with me still ',
#  'when the hours flew brightly by',
#  'and not a cloud obscured the sky',
#  'my soul lest it should truant be',
#  'thy grace did guide to thine and thee ',
#  'now when storms of fate oercast',
#  'darkly my present and my past',
#  'let my future radiant shine',
#  'with sweet hopes of thee and thine',
#  'the bells ah the bells ',
#  'the little silver bells ',
#  'how fairylike a melody there floats ',
#  'from their throats ',
#  'from their merry little throats ',
#  'from the silver tinkling throats ',
#  'of the bells bells bells ',
#  'of the bells ',
#  'the bells ah the bells ',
#  'the heavy iron bells ',
#  'how horrible a monody there floats ',
#  'from their throats ',
#  'from their deeptoned throats ',
#  'from their melancholy throats ',
#  'how i shudder at the notes ',
#  'of the bells bells bells ',
#  'of the bells',
#  'how often we forget all time when lone',
#  'admiring natures universal throne',
#  'her woods her wilds her mountains the intense',
#  'reply of hers to our intelligence',
#  'in youth have i known one with whom the earth',
#  'in secret communing held as he with it',
#  'in daylight and in beauty from his birth',
#  'whose fervid flickering torch of life was lit',
#  'from the sun and stars whence he had drawn forth',
#  'a passionate light such for his spirit was fit',
#  'and yet that spirit knew not in the hour',
#  'of its own fervor what had oer it power',
#  'perhaps it may be that my mind is wrought',
#  'to a fever by the moonbeam that hangs oer',
#  'but i will half believe that wild light fraught',
#  'with more of sovereignty than ancient lore',
#  'hath ever told or is it of a thought',
#  'the unembodied essence and no more',
#  'that with a quickening spell doth oer us pass',
#  'as dew of the nighttime oer the summer grass',
#  'doth oer us pass when as th expanding eye',
#  'to the loved object so the tear to the lid',
#  'will start which lately slept in apathy',
#  'and yet it need not be that object hid',
#  'from us in life but common which doth lie',
#  'each hour before us but then only bid',
#  'with a strange sound as of a harpstring broken',
#  'to awake us tis a symbol and a token',
#  'of what in other worlds shall be and given',
#  'in beauty by our god to those alone',
#  'who otherwise would fall from life and heaven',
#  'drawn by their hearts passion and that tone',
#  'that high tone of the spirit which hath striven',
#  'tho not with faith with godliness whose throne',
#  'with desperate energy t hath beaten down',
#  'wearing its own deep feeling as a crown',
#  'not long ago the writer of these lines',
#  'in the mad pride of intellectuality',
#  'maintained the power of words denied that ever',
#  'a thought arose within the human brain',
#  'beyond the utterance of the human tongue',
#  'and now as if in mockery of that boast',
#  'two words two foreign soft dissyllables',
#  'italian tones made only to be murmured',
#  'by angels dreaming in the moonlit dew',
#  'that hangs like chains of pearl on hermon hill',
#  'have stirred from out the abysses of his heart',
#  'unthoughtlike thoughts that are the souls of thought',
#  'richer far wilder far diviner visions',
#  'than even seraph harper israfel',
#  'who has the sweetest voice of all gods creatures',
#  'could hope to utter and i my spells are broken',
#  'the pen falls powerless from my shivering hand',
#  'with thy dear name as text though bidden by thee',
#  'i cannot write i cannot speak or think',
#  'alas i cannot feel for tis not feeling',
#  'this standing motionless upon the golden',
#  'threshold of the wideopen gate of dreams',
#  'gazing entranced adown the gorgeous vista',
#  'and thrilling as i see upon the right',
#  'upon the left and all the way along',
#  'amid empurpled vapors far away',
#  'to where the prospect terminates thee only',
#  'beloved amid the earnest woes',
#  'that crowd around my earthly path',
#  'drear path alas where grows',
#  'not even one lonely rose',
#  'my soul at least a solace hath',
#  'in dreams of thee and therein knows',
#  'an eden of bland repose',
#  'and thus thy memory is to me',
#  'like some enchanted faroff isle',
#  'in some tumultuous sea',
#  'some ocean throbbing far and free',
#  'with storms but where meanwhile',
#  'serenest skies continually',
#  'just oer that one bright island smile',
#  'i saw thee once once only years ago ',
#  'i must not say how many but not many ',
#  'it was a july midnight and from out ',
#  'a fullorbed moon that like thine own soul soaring ',
#  'sought a precipitate pathway up through heaven ',
#  'there fell a silverysilken veil of light ',
#  'with quietude and sultriness and slumber ',
#  'upon the upturned faces of a thousand ',
#  'roses that grew in an enchanted garden ',
#  'where no wind dared to stir unless on tiptoe ',
#  'fell on the upturnd faces of these roses ',
#  'that gave out in return for the lovelight ',
#  'their odorous souls in an ecstatic death ',
#  'fell on the upturnd faces of these roses ',
#  'that smiled and died in this parterre enchanted ',
#  'by thee and by the poetry of thy presence ',
#  'clad all in white upon a violet bank ',
#  'i saw thee half reclining while the moon ',
#  'fell on the upturnd faces of the roses ',
#  'and on thine own upturnd alas in sorrow ',
#  'was it not fate that on this july midnight ',
#  'was it not fate whose name is also sorrow ',
#  'that bade me pause before that gardengate ',
#  'to breathe the incense of those slumbering roses ',
#  'no footstep stirred the hated world an slept ',
#  'save only thee and me oh heaven oh god ',
#  'how my heart beats in coupling those two words ',
#  'save only thee and me i paused i looked ',
#  'and in an instant all things disappeared ',
#  'ah bear in mind this garden was enchanted ',
#  'the pearly lustre of the moon went out ',
#  'the mossy banks and the meandering paths ',
#  'the happy flowers and the repining trees ',
#  'were seen no more the very roses odors ',
#  'died in the arms of the adoring airs ',
#  'all all expired save thee save less than thou ',
#  'save only the divine light in thine eyes ',
#  'save but the soul in thine uplifted eyes ',
#  'i saw but them they were the world to me ',
#  'i saw but them saw only them for hours ',
#  'saw only them until the moon went down ',
#  'what wild hearthistories seemed to he enwritten ',
#  'upon those crystalline celestial spheres ',
#  'how dark a woe yet how sublime a hope ',
#  'how silently serene a sea of pride ',
#  'how daring an ambition yet how deep ',
#  'how fathomless a capacity for love ',
#  'but now at length dear dian sank from sight ',
#  'into a western couch of thundercloud ',
#  'and thou a ghost amid the entombing trees ',
#  'didst glide away only thine eyes remained ',
#  'they would not go they never yet have gone ',
#  'lighting my lonely pathway home that night ',
#  'they have not left me as my hopes have since ',
#  'they follow me they lead me through the years ',
#  'they are my ministers yet i their slave ',
#  'their office is to illumine and enkindle ',
#  'my duty to be saved by their bright light ',
#  'and purified in their electric fire ',
#  'and sanctified in their elysian fire ',
#  'they fill my soul with beauty which is hope ',
#  'and are far up in heaven the stars i kneel to ',
#  'in the sad silent watches of my night ',
#  'while even in the meridian glare of day ',
#  'i see them still two sweetly scintillant ',
#  'venuses unextinguished by the sun',
#  'the bowers whereat in dreams i see',
#  'the wantonest singing birds',
#  'are lips and all thy melody',
#  'of lipbegotten words',
#  'thine eyes in heaven of heart enshrined',
#  'then desolately fall',
#  'o god on my funereal mind',
#  'like starlight on a pall',
#  'thy heart thy heart i wake and sigh',
#  'and sleep to dream till day',
#  'of the truth that gold can never buy',
#  'of the baubles that it may',
#  'in heaven a spirit doth dwell',
#  'whose heartstrings are a lute',
#  'none sing so wildly well',
#  'as the angel israfel',
#  'and the giddy stars so legends tell',
#  'ceasing their hymns attend the spell',
#  'of his voice all mute',
#  'tottering above',
#  'in her highest noon',
#  'the enamored moon',
#  'blushes with love',
#  'while to listen the red levin',
#  'with the rapid pleiads even',
#  'which were seven',
#  'pauses in heaven',
#  'and they say the starry choir',
#  'and the other listening things',
#  'that israfelis fire',
#  'is owing to that lyre',
#  'by which he sits and sings',
#  'the trembling living wire',
#  'of those unusual strings',
#  'but the skies that angel trod',
#  'where deep thoughts are a duty',
#  'where loves a grownup god',
#  'where the houri glances are',
#  'imbued with all the beauty',
#  'which we worship in a star',
#  'therefore thou art not wrong',
#  'israfeli who despisest',
#  'an unimpassioned song',
#  'to thee the laurels belong',
#  'best bard because the wisest',
#  'merrily live and long',
#  'the ecstasies above',
#  'with thy burning measures suit',
#  'thy grief thy joy thy hate thy love',
#  'with the fervor of thy lute',
#  'well may the stars be mute',
#  'yes heaven is thine but this',
#  'is a world of sweets and sours',
#  'our flowers are merely flowers',
#  'and the shadow of thy perfect bliss',
#  'is the sunshine of ours',
#  'if i could dwell',
#  'where israfel',
#  'hath dwelt and he where i',
#  'he might not sing so wildly well',
#  'a mortal melody',
#  'while a bolder note than this might swell',
#  'from my lyre within the sky',
#  'science true daughter of old time thou art',
#  'who alterest all things with thy peering eyes',
#  'why preyest thou thus upon the poets heart',
#  'vulture whose wings are dull realities',
#  'how should he love thee or how deem thee wise',
#  'who wouldst not leave him in his wandering',
#  'to seek for treasure in the jewelled skies',
#  'albeit he soared with an undaunted wing',
#  'hast thou not dragged diana from her car',
#  'and driven the hamadryad from the wood',
#  'to seek a shelter in some happier star',
#  'hast thou not torn the naiad from her flood',
#  'the elfin from the green grass and from me',
#  'the summer dream beneath the tamarind tree',
#  'ill tell you a plan for gaining wealth',
#  'better than banking trade or leases ',
#  'take a bank note and fold it up ',
#  'and then you will find your money in creases ',
#  'this wonderful plan without danger or loss ',
#  'keeps your cash in your hands where nothing can trouble it ',
#  'and every time that you fold it across ',
#  'tis as plain as the light of the day that you double it',
#  'the skies they were ashen and sober',
#  'the leaves they were crisped and sere',
#  'the leaves they were withering and sere',
#  'it was night in the lonesome october',
#  'of my most immemorial year',
#  'it was hard by the dim lake of auber',
#  'in the misty mid region of weir',
#  'it was down by the dank tarn of auber',
#  'in the ghoulhaunted woodland of weir',
#  'here once through an alley titanic',
#  'of cypress i roamed with my soul',
#  'of cypress with psyche my soul',
#  'there were days when my heart was volcanic',
#  'as the scoriac rivers that roll',
#  'as the lavas that restlessly roll',
#  'their sulphurous currents down yaanek',
#  'in the ultimate climes of the pole',
#  'that groan as they roll down mount yaanek',
#  'in the realms of the boreal pole',
#  'our talk had been serious and sober',
#  'but our thoughts they were palsied and sere',
#  'our memories were treacherous and sere',
#  'for we knew not the month was october',
#  'and we marked not the night of the year',
#  'ah night of all nights in the year',
#  'we noted not the dim lake of auber',
#  'though once we had journeyed down here',
#  'remembered not the dank tarn of auber',
#  'nor the ghoulhaunted woodland of weir',
#  'and now as the night was senescent',
#  'and stardials pointed to morn',
#  'as the stardials hinted of morn',
#  'at the end of our path a liquescent',
#  'and nebulous lustre was born',
#  'out of which a miraculous crescent',
#  'arose with a duplicate horn',
#  'astartes bediamonded crescent',
#  'distinct with its duplicate horn',
#  'and i said she is warmer than dian',
#  'she rolls through an ether of sighs',
#  'she revels in a region of sighs',
#  'she has seen that the tears are not dry on',
#  'these cheeks where the worm never dies',
#  'and has come past the stars of the lion',
#  'to point us the path to the skies',
#  'to the lethean peace of the skies',
#  'come up in despite of the lion',
#  'to shine on us with her bright eyes',
#  'come up through the lair of the lion',
#  'with love in her luminous eyes',
#  'but psyche uplifting her finger',
#  'said sadly this star i mistrust',
#  'her pallor i strangely mistrust',
#  'oh hasten oh let us not linger',
#  'oh fly let us fly for we must',
#  'in terror she spoke letting sink her',
#  'wings until they trailed in the dust',
#  'in agony sobbed letting sink her',
#  'plumes till they trailed in the dust',
#  'till they sorrowfully trailed in the dust',
#  'i replied this is nothing but dreaming',
#  'let us on by this tremulous light',
#  'let us bathe in this crystalline light',
#  'its sybilic splendor is beaming',
#  'with hope and in beauty tonight',
#  'see it flickers up the sky through the night',
#  'ah we safely may trust to its gleaming',
#  'and be sure it will lead us aright',
#  'we safely may trust to a gleaming',
#  'that cannot but guide us aright',
#  'since it flickers up to heaven through the night',
#  'thus i pacified psyche and kissed her',
#  'and tempted her out of her gloom',
#  'and conquered her scruples and gloom',
#  'and we passed to the end of the vista',
#  'but were stopped by the door of a tomb',
#  'by the door of a legended tomb',
#  'and i said what is written sweet sister',
#  'on the door of this legended tomb',
#  'she replied ulalume ulalume',
#  'tis the vault of thy lost ulalume',
#  'then my heart it grew ashen and sober',
#  'as the leaves that were crisped and sere',
#  'as the leaves that were withering and sere',
#  'and i cried it was surely october',
#  'on this very night of last year',
#  'that i journeyed i journeyed down here',
#  'that i brought a dread burden down here',
#  'on this night of all nights in the year',
#  'ah what demon has tempted me here',
#  'well i know now this dim lake of auber',
#  'this misty mid region of weir',
#  'well i know now this dank tarn of auber',
#  'this ghoulhaunted woodland of weir ',
#  'how often we forget all time when lone ',
#  'admiring natures universal throne ',
#  'her woods  her winds  her mountains  the intense ',
#  'reply of hers to our intelligence ',
#  'in youth i have known one with whom the earth ',
#  'in secret communing held  as he with it ',
#  'in daylight and in beauty from his birth ',
#  'whose fervid flickering torch of life was lit ',
#  'from the sun and stars whence he had drawn forth ',
#  'a passionate light  such for his spirit was fit  ',
#  'and yet that spirit knew  not in the hour ',
#  'of its own fervour  what had oer it power ',
#  'perhaps it may be that my mind is wrought ',
#  'to a fever by the moonbeam that hangs oer ',
#  'but i will half believe that wild light fraught ',
#  'with more of sovereignty than ancient lore ',
#  'hath ever told  or is it of a thought ',
#  'the unembodied essence and no more ',
#  'that with a quickening spell doth oer us pass ',
#  'as dew of the night time oer the summer grass ',
#  'doth oer us pass when as th expanding eye ',
#  'to the loved object  so the tear to the lid ',
#  'will start which lately slept in apathy ',
#  'and yet it need not be  that object hid ',
#  'from us in life  but common  which doth lie ',
#  'each hour before us  but then only bid ',
#  'with a strange sound as of a harpstring broken ',
#  't awake us  tis a symbol and a token  ',
#  'of what in other worlds shall be  and given ',
#  'in beauty by our god to those alone ',
#  'who otherwise would fall from life and heaven ',
#  'drawn by their hearts passion and that tone ',
#  'that high tone of the spirit which hath striven ',
#  'though not with faith  with godliness  whose throne ',
#  'with desperate energy t hath beaten down ',
#  'wearing its own deep feeling as a crown',
#  'tis said that when ',
#  'the hands of men ',
#  'tamed this primeval wood ',
#  'and hoary trees with groans of woe ',
#  'like warriors by an unknown foe ',
#  'were in their strength subdued ',
#  'the virgin earth gave instant birth ',
#  'to springs that neer did flow ',
#  'that in the sun did rivulets run ',
#  'and all around rare flowers did blow ',
#  'the wild rose pale perfumed the gale ',
#  'and the queenly lily adown the dale ',
#  'whom the sun and the dew ',
#  'and the winds did woo ',
#  'with the gourd and the grape luxuriant grew ',
#  'so when in tears ',
#  'the love of years ',
#  'is wasted like the snow ',
#  'and the fine fibrils of its life ',
#  'by the rude wrong of instant strife ',
#  'are broken at a blow ',
#  'within the heart ',
#  'do springs upstart ',
#  'of which it doth now know ',
#  'and strange sweet dreams ',
#  'like silent streams ',
#  'that from new fountains overflow ',
#  'with the earlier tide ',
#  'of rivers glide ',
#  'deep in the heart whose hope has died ',
#  'quenching the fires its ashes hide ',
#  'its ashes whence will spring and grow ',
#  'sweet flowers ere long ',
#  'the rare and radiant flowers of song',
#  'in the greenest of our valleys',
#  'by good angels tenanted',
#  'once fair and stately palace ',
#  'radiant palace reared its head',
#  'in the monarch thoughts dominion ',
#  'it stood there',
#  'never seraph spread a pinion',
#  'over fabric half so fair',
#  'banners yellow glorious golden',
#  'on its roof did float and flow',
#  'this all this was in the olden',
#  'time long ago',
#  'and every gentle air that dallied',
#  'in that sweet day',
#  'along the ramparts plumed and pallid',
#  'a winged odour went away',
#  'wanderers in that happy valley',
#  'through two luminous windows saw',
#  'spirits moving musically',
#  'to a lutes welltuned law',
#  'round about a throne where sitting',
#  'porphyrogene',
#  'in state his glory well befitting',
#  'the ruler of the realm was seen',
#  'and all with pearl and ruby glowing',
#  'was the fair palace door',
#  'through which came flowing flowing flowing',
#  'and sparkling evermore',
#  'a troop of echoes whose sweet duty',
#  'was but to sing',
#  'in voices of surpassing beauty',
#  'the wit and wisdom of their king',
#  'but evil things in robes of sorrow',
#  'assailed the monarchs high estate',
#  'ah let us mourn for never morrow',
#  'shall dawn upon him desolate',
#  'and round about his home the glory',
#  'that blushed and bloomed',
#  'is but a dimremembered story',
#  'of the old time entombed',
#  'and travellers now within that valley',
#  'through the redlitten windows see',
#  'vast forms that move fantastically',
#  'to a discordant melody',
#  'while like a rapid ghastly river',
#  'through the pale door',
#  'a hideous throng rush out forever',
#  'and laugh but smile no more',
#  'two roads diverged in a yellow wood',
#  'and sorry i could not travel both',
#  'and be one traveler long i stood',
#  'and looked down one as far as i could',
#  'to where it bent in the undergrowth ',
#  'then took the other as just as fair',
#  'and having perhaps the better claim',
#  'because it was grassy and wanted wear',
#  'though as for that the passing there',
#  'had worn them really about the same',
#  'and both that morning equally lay',
#  'in leaves no step had trodden black',
#  'oh i kept the first for another day ',
#  'yet knowing how way leads on to way',
#  'i doubted if i should ever come back',
#  'i shall be telling this with a sigh',
#  'somewhere ages and ages hence',
#  'two roads diverged in a wood and i',
#  'i took the one less traveled by',
#  'and that has made all the difference',
#  'whose woods these are i think i know',
#  'his house is in the village though ',
#  'he will not see me stopping here',
#  'to watch his woods fill up with snow',
#  'my little horse must think it queer',
#  'to stop without a farmhouse near',
#  'between the woods and frozen lake',
#  'the darkest evening of the year',
#  'he gives his harness bells a shake',
#  'to ask if there is some mistake',
#  'the only other sounds the sweep',
#  'of easy wind and downy flake',
#  'the woods are lovely dark and deep',
#  'but i have promises to keep',
#  'and miles to go before i sleep',
#  'and miles to go before i sleep ',
#  'some say the world will end in fire',
#  'some say in ice',
#  'from what ive tasted of desire',
#  'i hold with those who favor fire',
#  'but if it had to perish twice',
#  'i think i know enough of hate',
#  'to say that for destruction ice',
#  'is also great',
#  'and would suffice',
#  'natures first green is gold',
#  'her hardest hue to hold',
#  'her early leafs a flower ',
#  'but only so an hour',
#  'then leaf subsides to leaf',
#  'so eden sank to grief',
#  'so dawn goes down to day',
#  'nothing gold can stay',
#  'i have been one acquainted with the night',
#  'i have walked out in rain  and back in rain',
#  'i have outwalked the furthest city light',
#  'i have looked down the saddest city lane',
#  'i have passed by the watchman on his beat',
#  'and dropped my eyes unwilling to explain',
#  'i have stood still and stopped the sound of feet',
#  'when far away an interrupted cry',
#  'came over houses from another street',
#  'but not to call me back or say goodbye ',
#  'and further still at an unearthly height',
#  'one luminary clock against the sky',
#  'proclaimed the time was neither wrong nor right',
#  'i have been one acquainted with the night',
#  'when i go up through the mowing field',
#  'the headless aftermath',
#  'smoothlaid like thatch with the heavy dew',
#  'half closes the garden path',
#  'and when i come to the garden ground',
#  'the whir of sober birds',
#  'up from the tangle of withered weeds',
#  'is sadder than any words',
#  'a tree beside the wall stands bare',
#  'but a leaf that lingered brown',
#  'disturbed i doubt not by my thought',
#  'comes softly rattling down',
#  'i end not far from my going forth',
#  'by picking the faded blue',
#  'of the last remaining aster flower',
#  'to carry again to you',
#  'a voice said look me in the stars',
#  'and tell me truly men of earth',
#  'if all the soulandbody scars',
#  'were not too much to pay for birth',
#  'to think to know the country and now know',
#  'the hillside on the day the sun lets go',
#  'ten million silver lizards out of snow',
#  'as often as ive seen it done before',
#  'i cant pretend to tell the way its done',
#  'it looks as if some magic of the sun',
#  'lifted the rug that bred them on the floor',
#  'and the light breaking on them made them run',
#  'but if i though to stop the wet stampede',
#  'and caught one silver lizard by the tail',
#  'and put my foot on one without avail',
#  'and threw myself wetelbowed and wetkneed',
#  'in front of twenty others wriggling speed ',
#  'in the confusion of them all aglitter',
#  'and birds that joined in the excited fun',
#  'by doubling and redoubling song and twitter',
#  'i have no doubt id end by holding none',
#  'it takes the moon for this the suns a wizard',
#  'by all i tell but sos the moon a witch',
#  'from the high west she makes a gentle cast',
#  'and suddenly without a jerk or twitch',
#  'she has her speel on every single lizard',
#  'i fancied when i looked at six oclock',
#  'the swarm still ran and scuttled just as fast',
#  'the moon was waiting for her chill effect',
#  'i looked at nine the swarm was turned to rock',
#  'in every lifelike posture of the swarm',
#  'transfixed on mountain slopes almost erect',
#  'across each other and side by side they lay',
#  'the spell that so could hold them as they were',
#  'was wrought through trees without a breath of storm',
#  'to make a leaf if there had been one stir',
#  'one lizard at the end of every ray',
#  'the thought of my attempting such a stray ',
#  'once on the kind of day called weather breeder',
#  'when the heat slowly hazes and the sun',
#  'by its own power seems to be undone',
#  'i was half boring through half climbing through',
#  'a swamp of cedar choked with oil of cedar',
#  'and scurf of plants and weary and overheated',
#  'and sorry i ever left the road i knew',
#  'i paused and rested on a sort of hook',
#  'that had me by the coat as good as seated',
#  'and since there was no other way to look',
#  'looked up toward heaven and there against the blue',
#  'stood over me a resurrected tree',
#  'a tree that had been down and raised again—',
#  'a barkless spectre he had halted too',
#  'as if for fear of treading upon me',
#  'i saw the strange position of his hands—',
#  'up at his shoulders dragging yellow strands',
#  'of wire with something in it from men to men',
#  'you here i said where arent you nowadays',
#  'and whats the news you carry—if you know',
#  'and tell me where youre off for—montreal',
#  'me im not off for anywhere at all',
#  'sometimes i wander out of beaten ways',
#  'half looking for the orchid calypso',
#  'brown lived at such a lofty farm',
#  'that everyone for miles could see',
#  'his lantern when he did his chores',
#  'in winter after halfpast three',
#  'and many must have seen him make',
#  'his wild descent from there one night',
#  'cross lots cross walls cross everything',
#  'describing rings of lantern light',
#  'between the house and barn the gale',
#  'got him by something he had on',
#  'and blew him out on the icy crust',
#  'that cased the world and he was gone',
#  'walls were all buried trees were few',
#  'he saw no stay unless he stove',
#  'a hole in somewhere with his heel',
#  'but though repeatedly he strove',
#  'and stamped and said things to himself',
#  'and sometimes something seemed to yield',
#  'he gained no foothold but pursued',
#  'his journey down from field to field',
#  'sometimes he came with arms outspread',
#  'like wings revolving in the scene',
#  'upon his longer axis and',
#  'with no small dignity of mien',
#  'faster or slower as he chanced',
#  'sitting or standing as he chose',
#  'according as he feared to risk',
#  'his neck or thought to spare his clothes',
#  'he never let the lantern drop',
#  'and some exclaimed who saw afar',
#  'the figures he described with it',
#  'i wonder what those signals are',
#  'brown makes at such an hour of night',
#  'hes celebrating something strange',
#  'i wonder if hes sold his farm',
#  'or been made master of the grange',
#  'he reeled he lurched he bobbed he checked',
#  'he fell and made the lantern rattle',
#  'but saved the light from going out',
#  'so halfway down he fought the battle',
#  'incredulous of his own bad luck',
#  'and then becoming reconciled',
#  'to everything he gave it up',
#  'and came down like a coasting child',
#  'well—i—be— that was all he said',
#  'as standing in the river road',
#  'he looked back up the slippery slope',
#  'two miles it was to his abode',
#  'sometimes as an authority',
#  'on motorcars im asked if i',
#  'should say our stock was petered out',
#  'and this is my sincere reply',
#  'yankees are what they always were',
#  'dont think brown ever gave up hope',
#  'of getting home again because',
#  'he couldnt climb that slippery slope',
#  'or even thought of standing there',
#  'until the january thaw',
#  'should take the polish off the crust',
#  'he bowed with grace to natural law',
#  'and then went round it on his feet',
#  'after the manner of our stock',
#  'not much concerned for those to whom',
#  'at that particular time oclock',
#  'it must have looked as if the course',
#  'he steered was really straight away',
#  'from that which he was headed for—',
#  'not much concerned for them i say',
#  'no more so than became a man—',
#  'and politician at odd seasons',
#  'ive kept brown standing in the cold',
#  'while i invested him with reasons',
#  'but now he snapped his eyes three times',
#  'then shook his lantern saying iles',
#  'bout out and took the long way home',
#  'by road a matter of several miles',
#  'now that theyve got it settled whose i be',
#  'im going to tell them something they wont like',
#  'theyve got it settled wrong and i can prove it',
#  'flattered i must be to have two towns fighting',
#  'to make a present of me to each other',
#  'they dont dispose me either one of them',
#  'to spare them any trouble double troubles',
#  'always the witchs motto anyway',
#  'ill double theirs for both of them you watch me',
#  'theyll find theyve got the whole thing to do over',
#  'that is if facts is what they want to go by',
#  'they set a lot now dont they by a record',
#  'of arthur amys having once been up',
#  'for hog reeve in march meeting here in warren',
#  'i could have told them any time this twelvemonth',
#  'the arthur amy i was married to',
#  'couldnt have been the one they say was up',
#  'in warren at march meeting for the reason',
#  'he want but fifteen at the time they say',
#  'the arthur amy i was married to',
#  'voted the only times he ever voted',
#  'which wasnt many in the town of wentworth',
#  'one of the times was when twas in the warrant',
#  'to see if the town wanted to take over',
#  'the tote road to our clearing where we lived',
#  'ill tell you whod remember heman lapish',
#  'their arthur amy was the father of mine',
#  'so now theyve dragged it through the law courts once',
#  'i guess theyd better drag it through again',
#  'wentworth and warrens both good towns to live in',
#  'only i happen to prefer to live',
#  'in wentworth from now on and when alls said',
#  'rights right and the temptation to do right',
#  'when i can hurt someone by doing it',
#  'has always been too much for me it has',
#  'i know of some folks thatd be set up',
#  'at having in their town a noted witch',
#  'but most would have to think of the expense',
#  'that even i would be they ought to know',
#  'that as a witch id often milk a bat',
#  'and thatd be enough to last for days',
#  'itd make my position stronger i think',
#  'if i was to consent to give some sign',
#  'to make it surer that i was a witch',
#  'it want no sign i spose when mallice huse',
#  'said that i took him out in his old age',
#  'and rode all over everything on him',
#  'until id had him worn to skin and bones',
#  'and if id left him hitched unblanketed',
#  'in front of one town hall id left him hitched',
#  'in front of every one in grafton county',
#  'some cried shame on me not to blanket him',
#  'the poor old man it would have been all right',
#  'if some one hadnt said to gnaw the posts',
#  'he stood beside and leave his trade mark on them',
#  'so they could recognize them not a post',
#  'that they could hear tell of was scarified',
#  ...]

# %% [markdown]
# * Save the labels too (another list)

# %%
#create labels
eap_labels = [0]*len(eap_list)
rf_labels = [1]*len(rf_list)

#combine data and labels
eap = list(zip(eap_list, eap_labels))
rf = list(zip(rf_list, rf_labels))

#combine all data
data = eap + rf

data
# Out:
# [("LO! Death hath rear'd himself a throne", 0),
#  ('In a strange city, all alone,', 0),
#  ('Far down within the dim west', 0),
#  ('Where the good, and the bad, and the worst, and the best,', 0),
#  ('Have gone to their eternal rest.', 0),
#  ('\u2009', 0),
#  ('There shrines, and palaces, and towers', 0),
#  ('Are not like any thing of ours', 0),
#  ('Oh no! O no! ours never loom', 0),
#  ('To heaven with that ungodly gloom!', 0),
#  ('Time-eaten towers that tremble not!', 0),
#  ('Resemble nothing that is ours.', 0),
#  ('Around, by lifting winds forgot,', 0),
#  ('Resignedly beneath the sky', 0),
#  ('The melancholy waters lie.', 0),
#  ('\u2009', 0),
#  ('No holy rays from heaven come down', 0),
#  ('On the long night-time of that town,', 0),
#  ('But light from out the lurid sea', 0),
#  ('Streams up the turrets silently', 0),
#  ('Up thrones up long-forgotten bowers', 0),
#  ("Of scultur'd ivy and stone flowers", 0),
#  ('Up domes up spires up kingly halls', 0),
#  ('Up fanes up Babylon-like walls', 0),
#  ('Up many a melancholy shrine', 0),
#  ('Whose entablatures intertwine', 0),
#  ('The mask the viol and the vine.', 0),
#  ('\u2009', 0),
#  ('There open temples open graves', 0),
#  ('Are on a level with the waves', 0),
#  ('But not the riches there that lie', 0),
#  ("In each idol's diamond eye,", 0),
#  ("Not the gaily-jewell'd dead", 0),
#  ('Tempt the waters from their bed:', 0),
#  ('For no ripples curl, alas!', 0),
#  ('Along that wilderness of glass', 0),
#  ('No swellings hint that winds may be', 0),
#  ('Upon a far-off happier sea:', 0),
#  ('So blend the turrets and shadows there', 0),
#  ('That all seem pendulous in air,', 0),
#  ('While from the high towers of the town', 0),
#  ('Death looks gigantically down.', 0),
#  ('\u2009', 0),
#  ('But lo! a stir is in the air!', 0),
#  ('The wave there is a ripple there!', 0),
#  ('As if the towers had thrown aside,', 0),
#  ('In slightly sinking, the dull tide', 0),
#  ('As if the turret-tops had given', 0),
#  ('A vacuum in the filmy heaven.', 0),
#  ('The waves have now a redder glow', 0),
#  ('The very hours are breathing low', 0),
#  ('And when, amid no earthly moans,', 0),
#  ('Down, down, that town shall settle hence,', 0),
#  ('All Hades, from a thousand thrones,', 0),
#  ('Shall do it reverence,', 0),
#  ('And Death to some more happy clime', 0),
#  ('Shall give his undivided time.', 0),
#  ('', 0),
#  ('The skies they were ashen and sober;', 0),
#  ('The leaves they were crisped and sere -', 0),
#  ('The leaves they were withering and sere;', 0),
#  ('It was night in the lonesome October', 0),
#  ('Of my most immemorial year;', 0),
#  ('It was hard by the dim lake of Auber,', 0),
#  ('In the misty mid region of Weir -', 0),
#  ('It was down by the dank tarn of Auber,', 0),
#  ('In the ghoul-haunted woodland of Weir.', 0),
#  ('', 0),
#  ('Here once, through an alley Titanic,', 0),
#  ('Of cypress, I roamed with my Soul -', 0),
#  ('Of cypress, with Psyche, my Soul.', 0),
#  ('These were days when my heart was volcanic', 0),
#  ('As the scoriac rivers that roll -', 0),
#  ('As the lavas that restlessly roll', 0),
#  ('Their sulphurous currents down Yaanek', 0),
#  ('In the ultimate climes of the pole -', 0),
#  ('That groan as they roll down Mount Yaanek', 0),
#  ('In the realms of the boreal pole.', 0),
#  ('', 0),
#  ('Our talk had been serious and sober,', 0),
#  ('But our thoughts they were palsied and sere -', 0),
#  ('Our memories were treacherous and sere, -', 0),
#  ('For we knew not the month was October,', 0),
#  ('And we marked not the night of the year -', 0),
#  ('(Ah, night of all nights in the year!)', 0),
#  ('We noted not the dim lake of Auber -', 0),
#  ('(Though once we had journey down here),', 0),
#  ('Remembered not the dank tarn of Auber,', 0),
#  ('Nor the ghoul-haunted woodland of Weir.', 0),
#  ('', 0),
#  ('And now, as the night was senescent,', 0),
#  ('And star-dials pointed to morn -', 0),
#  ('As the star-dials hinted of morn -', 0),
#  ('At the end of our path a liquescent', 0),
#  ('And nebulous lustre was born,', 0),
#  ('Out of which a miraculous crescent', 0),
#  ('Arose with a duplicate horn -', 0),
#  ("Astarte's bediamonded crescent", 0),
#  ('Distinct with its duplicate horn.', 0),
#  ('', 0),
#  ('And I said - "She is warmer than Dian:', 0),
#  ('She rolls through an ether of sighs -', 0),
#  ('She revels in a region of sighs:', 0),
#  ('She has seen that the tears are not dry on', 0),
#  ('These cheeks, where the worm never dies,', 0),
#  ('And has come past the stars of the Lion', 0),
#  ('To point us the path to the skies -', 0),
#  ('To the Lethean peace of the skies -', 0),
#  ('Come up, in despite of the Lion,', 0),
#  ('To shine on us with her bright eyes -', 0),
#  ('Come up through the lair of the Lion,', 0),
#  ('With love in her luminous eyes."', 0),
#  ('', 0),
#  ('But Psyche, uplifting her finger,', 0),
#  ('Said - "Sadly this star I mistrust -', 0),
#  ('Her pallor I strangely mistrust: -', 0),
#  ('Oh, hasten! - oh, let us not linger!', 0),
#  ('Oh, fly! - let us fly! - for we must."', 0),
#  ('In terror she spoke, letting sink her', 0),
#  ('Wings until they trailed in the dust -', 0),
#  ('In agony sobbed, letting sink her', 0),
#  ('Plumes till they trailed in the dust -', 0),
#  ('Till they sorrowfully trailed in the dust.', 0),
#  ('', 0),
#  ('I replied - "This is nothing but dreaming:', 0),
#  ('Let us on by this tremulous light!', 0),
#  ('Let us bathe in this crystalline light!', 0),
#  ('Its Sybilic splendor is beaming', 0),
#  ('With Hope and in Beauty to-night! -', 0),
#  ('See! - it flickers up the sky through the night!', 0),
#  ('Ah, we safely may trust to its gleaming,', 0),
#  ('And be sure it will lead us aright -', 0),
#  ('We safely may trust to a gleaming,', 0),
#  ('That cannot but guide us aright,', 0),
#  ('Since it flickers up to Heaven through the night."', 0),
#  ('', 0),
#  ('Thus I pacified Psyche and kissed her,', 0),
#  ('And tempted her out of her gloom -', 0),
#  ('And conquered her scruples and gloom;', 0),
#  ('And we passed to the end of the vista,', 0),
#  ('But were stopped by the door of a tomb -', 0),
#  ('By the door of a legended tomb;', 0),
#  ('And I said - "What is written, sweet sister,', 0),
#  ('On the door of this legended tomb?"', 0),
#  ('She replied - "Ulalume - Ulalume -', 0),
#  ('‘Tis the vault of thy lost Ulalume!"', 0),
#  ('', 0),
#  ('Then my heart it grew ashen and sober', 0),
#  ('As the leaves that were crisped and sere -', 0),
#  ('As the leaves that were withering and sere,', 0),
#  ('And I cried - "It was surely October', 0),
#  ('On this very night of last year', 0),
#  ('That I journeyed - I journeyed down here -', 0),
#  ('That I brought a dread burden down here!', 0),
#  ('On this night of all nights in the year,', 0),
#  ('Ah, what demon has tempted me here?', 0),
#  ('Well I know, now, this dim lake of Auber -', 0),
#  ('This misty mid region of Weir -', 0),
#  ('Well I know, now, this dank tarn of Auber, -', 0),
#  ('This ghoul-haunted woodland of Weir."', 0),
#  ('', 0),
#  ("Wreathed in myrtle, my sword I'll conceal", 0),
#  ('Like those champions devoted and brave,', 0),
#  ('When they plunged in the tyrant their steel,', 0),
#  ('And to Athens deliverance gave. ', 0),
#  ('', 0),
#  ('Beloved heroes! your deathless souls roam', 0),
#  ('In the joy breathing isles of the blest;', 0),
#  ('Where the mighty of old have their home -', 0),
#  ('Where Achilles and Diomed rest. ', 0),
#  ('', 0),
#  ("In fresh myrtle my blade I'll entwine,", 0),
#  ('Like Harmodious, the gallant and good,', 0),
#  ('When he made at the tutelar shrine', 0),
#  ("A libation of Tyranny's blood. ", 0),
#  ('', 0),
#  ('Ye deliverers of Athens from shame!', 0),
#  ("Ye avengers of Liberty's wrongs!", 0),
#  ('Endless ages shall cherish your fame', 0),
#  ('Embalmed in their echoing songs!', 0),
#  ('', 0),
#  ('Of all who hail thy presence as the morning-', 0),
#  ('Of all to whom thine absence is the night-', 0),
#  ('The blotting utterly from out high heaven', 0),
#  ('The sacred sun- of all who, weeping, bless thee', 0),
#  ('Hourly for hope- for life- ah! above all,', 0),
#  ('For the resurrection of deep-buried faith', 0),
#  ('In Truth- in Virtue- in Humanity-', 0),
#  ("Of all who, on Despair's unhallowed bed", 0),
#  ('Lying down to die, have suddenly arisen', 0),
#  ("At thy soft-murmured words, 'Let there be light!'", 0),
#  ('At the soft-murmured words that were fulfilled', 0),
#  ('In the seraphic glancing of thine eyes-', 0),
#  ('Of all who owe thee most- whose gratitude', 0),
#  ('Nearest resembles worship- oh, remember', 0),
#  ('The truest- the most fervently devoted,', 0),
#  ('And think that these weak lines are written by him-', 0),
#  ('By him who, as he pens them, thrills to think', 0),
#  ("His spirit is communing with an angel's. ", 0),
#  ('', 0),
#  ('Thou wouldst be loved?- then let thy heart', 0),
#  ('From its present pathway part not!', 0),
#  ('Being everything which now thou art,', 0),
#  ('Be nothing which thou art not.', 0),
#  ('So with the world thy gentle ways,', 0),
#  ('Thy grace, thy more than beauty,', 0),
#  ('Shall be an endless theme of praise,', 0),
#  ('And love- a simple duty. ', 0),
#  ('', 0),
#  ('When from your gems of thought I turn ', 0),
#  ('To those pure orbs, your heart to learn, ', 0),
#  ('I scarce know which to prize most high ', 0),
#  ('The bright i-dea, or the bright dear-eye.', 0),
#  ('', 0),
#  ('Of all who hail thy presence as the morning-', 0),
#  ('Of all to whom thine absence is the night-', 0),
#  ('The blotting utterly from out high heaven', 0),
#  ('The sacred sun- of all who, weeping, bless thee', 0),
#  ('Hourly for hope- for life- ah! above all,', 0),
#  ('For the resurrection of deep-buried faith', 0),
#  ('In Truth- in Virtue- in Humanity-', 0),
#  ("Of all who, on Despair's unhallowed bed", 0),
#  ('Lying down to die, have suddenly arisen', 0),
#  ('At thy soft-murmured words, "Let there be light!"', 0),
#  ('At the soft-murmured words that were fulfilled', 0),
#  ('In the seraphic glancing of thine eyes-', 0),
#  ('Of all who owe thee most- whose gratitude', 0),
#  ('Nearest resembles worship- oh, remember', 0),
#  ('The truest- the most fervently devoted,', 0),
#  ('And think that these weak lines are written by him-', 0),
#  ('By him who, as he pens them, thrills to think', 0),
#  ("His spirit is communing with an angel's.", 0),
#  ('', 0),
#  ('Fair isle, that from the fairest of all flowers,', 0),
#  ('Thy gentlest of all gentle names dost take!', 0),
#  ('How many memories of what radiant hours', 0),
#  ('At sight of thee and thine at once awake!', 0),
#  ('How many scenes of what departed bliss!', 0),
#  ('How many thoughts of what entombed hopes!', 0),
#  ('How many visions of a maiden that is', 0),
#  ('No more- no more upon thy verdant slopes!', 0),
#  ('No more! alas, that magical sad sound', 0),
#  ('Transforming all! Thy charms shall please no more-', 0),
#  ('Thy memory no more! Accursed ground', 0),
#  ('Henceforth I hold thy flower-enameled shore,', 0),
#  ('O hyacinthine isle! O purple Zante!', 0),
#  ('"Isola d\'oro! Fior di Levante!"', 0),
#  ('', 0),
#  ('O! I care not that my earthly lot', 0),
#  ('Hath little of Earth in it,', 0),
#  ('That years of love have been forgot', 0),
#  ('In the fever of a minute:', 0),
#  ('', 0),
#  ('I heed not that the desolate', 0),
#  ('Are happier, sweet, than I,', 0),
#  ('But that you meddle with my fate', 0),
#  ('Who am a passer by.', 0),
#  ('', 0),
#  ('It is not that my founts of bliss', 0),
#  ('Are gushing- strange! with tears-', 0),
#  ('Or that the thrill of a single kiss', 0),
#  ('Hath palsied many years-', 0),
#  ('', 0),
#  ("'Tis not that the flowers of twenty springs", 0),
#  ("Which have wither'd as they rose", 0),
#  ('Lie dead on my heart-strings', 0),
#  ('With the weight of an age of snows.', 0),
#  ('', 0),
#  ('Not that the grass- O! may it thrive!', 0),
#  ('On my grave is growing or grown-', 0),
#  ('But that, while I am dead yet alive', 0),
#  ('I cannot be, lady, alone.', 0),
#  ('', 0),
#  ('Sancta Maria! turn thine eyes -', 0),
#  ("Upon the sinner's sacrifice,", 0),
#  ('Of fervent prayer and humble love,', 0),
#  ('From thy holy throne above. ', 0),
#  ('At morn - at noon - at twilight dim -', 0),
#  ('Maria! thou hast heard my hymn!', 0),
#  ('In joy and wo - in good and ill -', 0),
#  ('Mother of God, be with me still! ', 0),
#  ('', 0),
#  ('When the Hours flew brightly by,', 0),
#  ('And not a cloud obscured the sky,', 0),
#  ('My soul, lest it should truant be,', 0),
#  ('Thy grace did guide to thine and thee; ', 0),
#  ('', 0),
#  ("Now, when storms of Fate o'ercast", 0),
#  ('Darkly my Present and my Past,', 0),
#  ('Let my Future radiant shine', 0),
#  ('With sweet hopes of thee and thine!', 0),
#  ('', 0),
#  ('The bells! ah, the bells! ', 0),
#  ('The little silver bells! ', 0),
#  ('How fairy-like a melody there floats ', 0),
#  ('From their throats. ', 0),
#  ('From their merry little throats ', 0),
#  ('From the silver, tinkling throats ', 0),
#  ('Of the bells, bells, bells ', 0),
#  ('Of the bells! ', 0),
#  ('', 0),
#  ('The bells! ah, the bells! ', 0),
#  ('The heavy iron bells! ', 0),
#  ('How horrible a monody there floats ', 0),
#  ('From their throats ', 0),
#  ('From their deep-toned throats ', 0),
#  ('From their melancholy throats! ', 0),
#  ('How I shudder at the notes ', 0),
#  ('Of the bells, bells, bells ', 0),
#  ('Of the bells!', 0),
#  ('', 0),
#  ('How often we forget all time, when lone', 0),
#  ("Admiring Nature's universal throne;", 0),
#  ('Her woods- her wilds- her mountains- the intense', 0),
#  ('Reply of HERS to OUR intelligence!', 0),
#  ('', 0),
#  ('In youth have I known one with whom the Earth', 0),
#  ('In secret communing held- as he with it,', 0),
#  ('In daylight, and in beauty from his birth:', 0),
#  ('Whose fervid, flickering torch of life was lit', 0),
#  ('From the sun and stars, whence he had drawn forth', 0),
#  ('A passionate light- such for his spirit was fit-', 0),
#  ('And yet that spirit knew not, in the hour', 0),
#  ("Of its own fervor what had o'er it power.", 0),
#  ('', 0),
#  ('Perhaps it may be that my mind is wrought', 0),
#  ("To a fever by the moonbeam that hangs o'er,", 0),
#  ('But I will half believe that wild light fraught', 0),
#  ('With more of sovereignty than ancient lore', 0),
#  ('Hath ever told- or is it of a thought', 0),
#  ('The unembodied essence, and no more,', 0),
#  ("That with a quickening spell doth o'er us pass", 0),
#  ("As dew of the night-time o'er the summer grass?", 0),
#  ('', 0),
#  ("Doth o'er us pass, when, as th' expanding eye", 0),
#  ('To the loved object- so the tear to the lid', 0),
#  ('Will start, which lately slept in apathy?', 0),
#  ('And yet it need not be- (that object) hid', 0),
#  ('From us in life- but common- which doth lie', 0),
#  ('Each hour before us- but then only, bid', 0),
#  ('With a strange sound, as of a harp-string broken,', 0),
#  ("To awake us- 'Tis a symbol and a token", 0),
#  ('', 0),
#  ('Of what in other worlds shall be- and given', 0),
#  ('In beauty by our God, to those alone', 0),
#  ('Who otherwise would fall from life and Heaven', 0),
#  ("Drawn by their heart's passion, and that tone,", 0),
#  ('That high tone of the spirit which hath striven,', 0),
#  ("Tho' not with Faith- with godliness- whose throne", 0),
#  ("With desperate energy 't hath beaten down;", 0),
#  ('Wearing its own deep feeling as a crown.', 0),
#  ('', 0),
#  ('Not long ago, the writer of these lines,', 0),
#  ('In the mad pride of intellectuality,', 0),
#  ('Maintained "the power of words"- denied that ever', 0),
#  ('A thought arose within the human brain', 0),
#  ('Beyond the utterance of the human tongue:', 0),
#  ('And now, as if in mockery of that boast,', 0),
#  ('Two words- two foreign soft dissyllables-', 0),
#  ('Italian tones, made only to be murmured', 0),
#  ('By angels dreaming in the moonlit "dew', 0),
#  ('That hangs like chains of pearl on Hermon hill,"', 0),
#  ('Have stirred from out the abysses of his heart,', 0),
#  ('Unthought-like thoughts that are the souls of thought,', 0),
#  ('Richer, far wilder, far diviner visions', 0),
#  ('Than even seraph harper, Israfel,', 0),
#  ('(Who has "the sweetest voice of all God\'s creatures,")', 0),
#  ('Could hope to utter. And I! my spells are broken.', 0),
#  ('The pen falls powerless from my shivering hand.', 0),
#  ('With thy dear name as text, though bidden by thee,', 0),
#  ('I cannot write- I cannot speak or think-', 0),
#  ("Alas, I cannot feel; for 'tis not feeling,", 0),
#  ('This standing motionless upon the golden', 0),
#  ('Threshold of the wide-open gate of dreams.', 0),
#  ('Gazing, entranced, adown the gorgeous vista,', 0),
#  ('And thrilling as I see, upon the right,', 0),
#  ('Upon the left, and all the way along,', 0),
#  ('Amid empurpled vapors, far away', 0),
#  ('To where the prospect terminates- thee only.', 0),
#  ('', 0),
#  ('Beloved! amid the earnest woes', 0),
#  ('That crowd around my earthly path-', 0),
#  ('(Drear path, alas! where grows', 0),
#  ('Not even one lonely rose)-', 0),
#  ('My soul at least a solace hath', 0),
#  ('In dreams of thee, and therein knows', 0),
#  ('An Eden of bland repose.', 0),
#  ('', 0),
#  ('And thus thy memory is to me', 0),
#  ('Like some enchanted far-off isle', 0),
#  ('In some tumultuous sea-', 0),
#  ('Some ocean throbbing far and free', 0),
#  ('With storms- but where meanwhile', 0),
#  ('Serenest skies continually', 0),
#  ("Just o'er that one bright island smile.", 0),
#  ('', 0),
#  ('I saw thee once- once only- years ago: ', 0),
#  ('I must not say how many- but not many. ', 0),
#  ('It was a July midnight; and from out ', 0),
#  ('A full-orbed moon, that, like thine own soul, soaring, ', 0),
#  ('Sought a precipitate pathway up through heaven, ', 0),
#  ('There fell a silvery-silken veil of light, ', 0),
#  ('With quietude, and sultriness, and slumber, ', 0),
#  ('Upon the upturned faces of a thousand ', 0),
#  ('Roses that grew in an enchanted garden, ', 0),
#  ('Where no wind dared to stir, unless on tiptoe- ', 0),
#  ("Fell on the upturn'd faces of these roses ", 0),
#  ('That gave out, in return for the love-light, ', 0),
#  ('Their odorous souls in an ecstatic death- ', 0),
#  ("Fell on the upturn'd faces of these roses ", 0),
#  ('That smiled and died in this parterre, enchanted ', 0),
#  ('By thee, and by the poetry of thy presence. ', 0),
#  ('Clad all in white, upon a violet bank ', 0),
#  ('I saw thee half reclining; while the moon ', 0),
#  ("Fell on the upturn'd faces of the roses, ", 0),
#  ("And on thine own, upturn'd- alas, in sorrow! ", 0),
#  ('', 0),
#  ('Was it not Fate, that, on this July midnight- ', 0),
#  ('Was it not Fate, (whose name is also Sorrow,) ', 0),
#  ('That bade me pause before that garden-gate, ', 0),
#  ('To breathe the incense of those slumbering roses? ', 0),
#  ('No footstep stirred: the hated world an slept, ', 0),
#  ('Save only thee and me. (Oh, Heaven!- oh, God! ', 0),
#  ('How my heart beats in coupling those two words!) ', 0),
#  ('Save only thee and me. I paused- I looked- ', 0),
#  ('And in an instant all things disappeared. ', 0),
#  ('(Ah, bear in mind this garden was enchanted!) ', 0),
#  ('', 0),
#  ('The pearly lustre of the moon went out: ', 0),
#  ('The mossy banks and the meandering paths, ', 0),
#  ('The happy flowers and the repining trees, ', 0),
#  ("Were seen no more: the very roses' odors ", 0),
#  ('Died in the arms of the adoring airs. ', 0),
#  ('All- all expired save thee- save less than thou: ', 0),
#  ('Save only the divine light in thine eyes- ', 0),
#  ('Save but the soul in thine uplifted eyes. ', 0),
#  ('I saw but them- they were the world to me! ', 0),
#  ('I saw but them- saw only them for hours, ', 0),
#  ('Saw only them until the moon went down. ', 0),
#  ('What wild heart-histories seemed to he enwritten ', 0),
#  ('Upon those crystalline, celestial spheres! ', 0),
#  ('How dark a woe, yet how sublime a hope! ', 0),
#  ('How silently serene a sea of pride! ', 0),
#  ('How daring an ambition; yet how deep- ', 0),
#  ('How fathomless a capacity for love! ', 0),
#  ('', 0),
#  ('But now, at length, dear Dian sank from sight, ', 0),
#  ('Into a western couch of thunder-cloud; ', 0),
#  ('And thou, a ghost, amid the entombing trees ', 0),
#  ('Didst glide away. Only thine eyes remained; ', 0),
#  ('They would not go- they never yet have gone; ', 0),
#  ('Lighting my lonely pathway home that night, ', 0),
#  ('They have not left me (as my hopes have) since; ', 0),
#  ('They follow me- they lead me through the years. ', 0),
#  ('They are my ministers- yet I their slave. ', 0),
#  ('Their office is to illumine and enkindle- ', 0),
#  ('My duty, to be saved by their bright light, ', 0),
#  ('And purified in their electric fire, ', 0),
#  ('And sanctified in their elysian fire. ', 0),
#  ('They fill my soul with Beauty (which is Hope), ', 0),
#  ('And are far up in Heaven- the stars I kneel to ', 0),
#  ('In the sad, silent watches of my night; ', 0),
#  ('While even in the meridian glare of day ', 0),
#  ('I see them still- two sweetly scintillant ', 0),
#  ('Venuses, unextinguished by the sun!', 0),
#  ('', 0),
#  ('The bowers whereat, in dreams, I see', 0),
#  ('The wantonest singing birds,', 0),
#  ('Are lips- and all thy melody', 0),
#  ('Of lip-begotten words-', 0),
#  ('', 0),
#  ('Thine eyes, in Heaven of heart enshrined,', 0),
#  ('Then desolately fall,', 0),
#  ('O God! on my funereal mind', 0),
#  ('Like starlight on a pall-', 0),
#  ('', 0),
#  ('Thy heart- thy heart!- I wake and sigh,', 0),
#  ('And sleep to dream till day', 0),
#  ('Of the truth that gold can never buy-', 0),
#  ('Of the baubles that it may.', 0),
#  ('', 0),
#  ('In Heaven a spirit doth dwell', 0),
#  ('"Whose heart-strings are a lute";', 0),
#  ('None sing so wildly well', 0),
#  ('As the angel Israfel,', 0),
#  ('And the giddy stars (so legends tell),', 0),
#  ('Ceasing their hymns, attend the spell', 0),
#  ('Of his voice, all mute.', 0),
#  ('', 0),
#  ('Tottering above', 0),
#  ('In her highest noon,', 0),
#  ('The enamored moon', 0),
#  ('Blushes with love,', 0),
#  ('While, to listen, the red levin', 0),
#  ('(With the rapid Pleiads, even,', 0),
#  ('Which were seven,)', 0),
#  ('Pauses in Heaven.', 0),
#  ('', 0),
#  ('And they say (the starry choir', 0),
#  ('And the other listening things)', 0),
#  ("That Israfeli's fire", 0),
#  ('Is owing to that lyre', 0),
#  ('By which he sits and sings-', 0),
#  ('The trembling living wire', 0),
#  ('Of those unusual strings.', 0),
#  ('', 0),
#  ('But the skies that angel trod,', 0),
#  ('Where deep thoughts are a duty-', 0),
#  ("Where Love's a grown-up God-", 0),
#  ('Where the Houri glances are', 0),
#  ('Imbued with all the beauty', 0),
#  ('Which we worship in a star.', 0),
#  ('', 0),
#  ('Therefore thou art not wrong,', 0),
#  ('Israfeli, who despisest', 0),
#  ('An unimpassioned song;', 0),
#  ('To thee the laurels belong,', 0),
#  ('Best bard, because the wisest!', 0),
#  ('Merrily live, and long!', 0),
#  ('', 0),
#  ('The ecstasies above', 0),
#  ('With thy burning measures suit-', 0),
#  ('Thy grief, thy joy, thy hate, thy love,', 0),
#  ('With the fervor of thy lute-', 0),
#  ('Well may the stars be mute!', 0),
#  ('', 0),
#  ('Yes, Heaven is thine; but this', 0),
#  ('Is a world of sweets and sours;', 0),
#  ('Our flowers are merely- flowers,', 0),
#  ('And the shadow of thy perfect bliss', 0),
#  ('Is the sunshine of ours.', 0),
#  ('', 0),
#  ('If I could dwell', 0),
#  ('Where Israfel', 0),
#  ('Hath dwelt, and he where I,', 0),
#  ('He might not sing so wildly well', 0),
#  ('A mortal melody,', 0),
#  ('While a bolder note than this might swell', 0),
#  ('From my lyre within the sky.', 0),
#  ('', 0),
#  ('Science! true daughter of Old Time thou art!', 0),
#  ('Who alterest all things with thy peering eyes.', 0),
#  ("Why preyest thou thus upon the poet's heart,", 0),
#  ('Vulture, whose wings are dull realities?', 0),
#  ('How should he love thee? or how deem thee wise,', 0),
#  ('Who wouldst not leave him in his wandering', 0),
#  ('To seek for treasure in the jewelled skies,', 0),
#  ('Albeit he soared with an undaunted wing?', 0),
#  ('Hast thou not dragged Diana from her car?', 0),
#  ('And driven the Hamadryad from the wood', 0),
#  ('To seek a shelter in some happier star?', 0),
#  ('Hast thou not torn the Naiad from her flood,', 0),
#  ('The Elfin from the green grass, and from me', 0),
#  ('The summer dream beneath the tamarind tree?', 0),
#  ('', 0),
#  ("I'll tell you a plan for gaining wealth,", 0),
#  ('Better than banking, trade or leases ', 0),
#  ('Take a bank note and fold it up, ', 0),
#  ('And then you will find your money in creases! ', 0),
#  ('This wonderful plan, without danger or loss, ', 0),
#  ('Keeps your cash in your hands, where nothing can trouble it; ', 0),
#  ('And every time that you fold it across, ', 0),
#  ("'Tis as plain as the light of the day that you double it!", 0),
#  ('', 0),
#  ('The skies they were ashen and sober;', 0),
#  ('The leaves they were crisped and sere-', 0),
#  ('The leaves they were withering and sere;', 0),
#  ('It was night in the lonesome October', 0),
#  ('Of my most immemorial year;', 0),
#  ('It was hard by the dim lake of Auber,', 0),
#  ('In the misty mid region of Weir-', 0),
#  ('It was down by the dank tarn of Auber,', 0),
#  ('In the ghoul-haunted woodland of Weir.', 0),
#  ('', 0),
#  ('Here once, through an alley Titanic,', 0),
#  ('Of cypress, I roamed with my Soul-', 0),
#  ('Of cypress, with Psyche, my Soul.', 0),
#  ('There were days when my heart was volcanic', 0),
#  ('As the scoriac rivers that roll-', 0),
#  ('As the lavas that restlessly roll', 0),
#  ('Their sulphurous currents down Yaanek', 0),
#  ('In the ultimate climes of the pole-', 0),
#  ('That groan as they roll down Mount Yaanek', 0),
#  ('In the realms of the boreal pole.', 0),
#  ('', 0),
#  ('Our talk had been serious and sober,', 0),
#  ('But our thoughts they were palsied and sere-', 0),
#  ('Our memories were treacherous and sere-', 0),
#  ('For we knew not the month was October,', 0),
#  ('And we marked not the night of the year-', 0),
#  ('(Ah, night of all nights in the year!)', 0),
#  ('We noted not the dim lake of Auber-', 0),
#  ('(Though once we had journeyed down here),', 0),
#  ('Remembered not the dank tarn of Auber,', 0),
#  ('Nor the ghoul-haunted woodland of Weir.', 0),
#  ('', 0),
#  ('And now, as the night was senescent,', 0),
#  ('And star-dials pointed to morn-', 0),
#  ('As the star-dials hinted of morn-', 0),
#  ('At the end of our path a liquescent', 0),
#  ('And nebulous lustre was born,', 0),
#  ('Out of which a miraculous crescent', 0),
#  ('Arose with a duplicate horn-', 0),
#  ("Astarte's bediamonded crescent", 0),
#  ('Distinct with its duplicate horn.', 0),
#  ('', 0),
#  ("And I said- 'She is warmer than Dian:", 0),
#  ('She rolls through an ether of sighs-', 0),
#  ('She revels in a region of sighs:', 0),
#  ('She has seen that the tears are not dry on', 0),
#  ('These cheeks, where the worm never dies,', 0),
#  ('And has come past the stars of the Lion,', 0),
#  ('To point us the path to the skies-', 0),
#  ('To the Lethean peace of the skies-', 0),
#  ('Come up, in despite of the Lion,', 0),
#  ('To shine on us with her bright eyes-', 0),
#  ('Come up through the lair of the Lion,', 0),
#  ("With love in her luminous eyes.'", 0),
#  ('', 0),
#  ('But Psyche, uplifting her finger,', 0),
#  ("Said- 'Sadly this star I mistrust-", 0),
#  ('Her pallor I strangely mistrust:-', 0),
#  ('Oh, hasten!- oh, let us not linger!', 0),
#  ("Oh, fly!- let us fly!- for we must.'", 0),
#  ('In terror she spoke, letting sink her', 0),
#  ('Wings until they trailed in the dust-', 0),
#  ('In agony sobbed, letting sink her', 0),
#  ('Plumes till they trailed in the dust-', 0),
#  ('Till they sorrowfully trailed in the dust.', 0),
#  ('', 0),
#  ("I replied- 'This is nothing but dreaming:", 0),
#  ('Let us on by this tremulous light!', 0),
#  ('Let us bathe in this crystalline light!', 0),
#  ('Its Sybilic splendor is beaming', 0),
#  ('With Hope and in Beauty to-night:-', 0),
#  ('See!- it flickers up the sky through the night!', 0),
#  ('Ah, we safely may trust to its gleaming,', 0),
#  ('And be sure it will lead us aright-', 0),
#  ('We safely may trust to a gleaming', 0),
#  ('That cannot but guide us aright,', 0),
#  ("Since it flickers up to Heaven through the night.'", 0),
#  ('', 0),
#  ('Thus I pacified Psyche and kissed her,', 0),
#  ('And tempted her out of her gloom-', 0),
#  ('And conquered her scruples and gloom;', 0),
#  ('And we passed to the end of the vista,', 0),
#  ('But were stopped by the door of a tomb-', 0),
#  ('By the door of a legended tomb;', 0),
#  ("And I said- 'What is written, sweet sister,", 0),
#  ("On the door of this legended tomb?'", 0),
#  ("She replied- 'Ulalume- Ulalume-", 0),
#  ("'Tis the vault of thy lost Ulalume!'", 0),
#  ('', 0),
#  ('Then my heart it grew ashen and sober', 0),
#  ('As the leaves that were crisped and sere-', 0),
#  ('As the leaves that were withering and sere-', 0),
#  ("And I cried- 'It was surely October", 0),
#  ('On this very night of last year', 0),
#  ('That I journeyed- I journeyed down here-', 0),
#  ('That I brought a dread burden down here-', 0),
#  ('On this night of all nights in the year,', 0),
#  ('Ah, what demon has tempted me here?', 0),
#  ('Well I know, now, this dim lake of Auber-', 0),
#  ('This misty mid region of Weir-', 0),
#  ('Well I know, now, this dank tarn of Auber,', 0),
#  ("This ghoul-haunted woodland of Weir.' ", 0),
#  ('', 0),
#  ('How often we forget all time, when lone ', 0),
#  ("Admiring Nature's universal throne; ", 0),
#  ('Her woods - her winds - her mountains - the intense ', 0),
#  ('Reply of Hers to Our intelligence! ', 0),
#  ('', 0),
#  ('In youth I have known one with whom the Earth ', 0),
#  ('In secret communing held - as he with it, ', 0),
#  ('In daylight, and in beauty, from his birth: ', 0),
#  ('Whose fervid, flickering torch of life was lit ', 0),
#  ('From the sun and stars, whence he had drawn forth ', 0),
#  ('A passionate light - such for his spirit was fit - ', 0),
#  ('And yet that spirit knew - not in the hour ', 0),
#  ("Of its own fervour - what had o'er it power. ", 0),
#  ('', 0),
#  ('Perhaps it may be that my mind is wrought ', 0),
#  ("To a fever by the moonbeam that hangs o'er, ", 0),
#  ('But I will half believe that wild light fraught ', 0),
#  ('With more of sovereignty than ancient lore ', 0),
#  ('Hath ever told - or is it of a thought ', 0),
#  ('The unembodied essence, and no more ', 0),
#  ("That with a quickening spell doth o'er us pass ", 0),
#  ("As dew of the night time, o'er the summer grass? ", 0),
#  ('', 0),
#  ("Doth o'er us pass, when as th' expanding eye ", 0),
#  ('To the loved object - so the tear to the lid ', 0),
#  ('Will start, which lately slept in apathy? ', 0),
#  ('And yet it need not be - (that object) hid ', 0),
#  ('From us in life - but common - which doth lie ', 0),
#  ('Each hour before us - but then only bid ', 0),
#  ('With a strange sound, as of a harpstring broken ', 0),
#  ("T' awake us - 'Tis a symbol and a token - ", 0),
#  ('', 0),
#  ('Of what in other worlds shall be - and given ', 0),
#  ('In beauty by our God, to those alone ', 0),
#  ('Who otherwise would fall from life and Heaven ', 0),
#  ("Drawn by their heart's passion, and that tone, ", 0),
#  ('That high tone of the spirit which hath striven ', 0),
#  ('Though not with Faith - with godliness - whose throne ', 0),
#  ("With desperate energy 't hath beaten down; ", 0),
#  ('Wearing its own deep feeling as a crown.', 0),
#  ('', 0),
#  ("'Tis said that when ", 0),
#  ('The hands of men ', 0),
#  ('Tamed this primeval wood, ', 0),
#  ('And hoary trees with groans of woe, ', 0),
#  ('Like warriors by an unknown foe, ', 0),
#  ('Were in their strength subdued, ', 0),
#  ('The virgin Earth Gave instant birth ', 0),
#  ("To springs that ne'er did flow ", 0),
#  ('That in the sun Did rivulets run, ', 0),
#  ('And all around rare flowers did blow ', 0),
#  ('The wild rose pale Perfumed the gale ', 0),
#  ('And the queenly lily adown the dale ', 0),
#  ('(Whom the sun and the dew ', 0),
#  ('And the winds did woo), ', 0),
#  ('With the gourd and the grape luxuriant grew. ', 0),
#  ('', 0),
#  ('So when in tears ', 0),
#  ('The love of years ', 0),
#  ('Is wasted like the snow, ', 0),
#  ('And the fine fibrils of its life ', 0),
#  ('By the rude wrong of instant strife ', 0),
#  ('Are broken at a blow ', 0),
#  ('Within the heart ', 0),
#  ('Do springs upstart ', 0),
#  ('Of which it doth now know, ', 0),
#  ('And strange, sweet dreams, ', 0),
#  ('Like silent streams ', 0),
#  ('That from new fountains overflow, ', 0),
#  ('With the earlier tide ', 0),
#  ('Of rivers glide ', 0),
#  ('Deep in the heart whose hope has died-- ', 0),
#  ('Quenching the fires its ashes hide,-- ', 0),
#  ('Its ashes, whence will spring and grow ', 0),
#  ('Sweet flowers, ere long, ', 0),
#  ('The rare and radiant flowers of song!', 0),
#  ('', 0),
#  ('In the greenest of our valleys,', 0),
#  ('By good angels tenanted,', 0),
#  ('Once fair and stately palace --', 0),
#  ('Radiant palace --reared its head.', 0),
#  ("In the monarch Thought's dominion --", 0),
#  ('It stood there!', 0),
#  ('Never seraph spread a pinion', 0),
#  ('Over fabric half so fair.', 0),
#  ('', 0),
#  ('Banners yellow, glorious, golden,', 0),
#  ('On its roof did float and flow;', 0),
#  ('(This --all this --was in the olden', 0),
#  ('Time long ago)', 0),
#  ('And every gentle air that dallied,', 0),
#  ('In that sweet day,', 0),
#  ('Along the ramparts plumed and pallid,', 0),
#  ('A winged odour went away.', 0),
#  ('', 0),
#  ('Wanderers in that happy valley', 0),
#  ('Through two luminous windows saw', 0),
#  ('Spirits moving musically', 0),
#  ("To a lute's well-tuned law,", 0),
#  ('Round about a throne, where sitting', 0),
#  ('(Porphyrogene!)', 0),
#  ('In state his glory well befitting,', 0),
#  ('The ruler of the realm was seen.', 0),
#  ('', 0),
#  ('And all with pearl and ruby glowing', 0),
#  ('Was the fair palace door,', 0),
#  ('Through which came flowing, flowing, flowing', 0),
#  ('And sparkling evermore,', 0),
#  ('A troop of Echoes whose sweet duty', 0),
#  ('Was but to sing,', 0),
#  ('In voices of surpassing beauty,', 0),
#  ('The wit and wisdom of their king.', 0),
#  ('', 0),
#  ('But evil things, in robes of sorrow,', 0),
#  ("Assailed the monarch's high estate;", 0),
#  ('(Ah, let us mourn, for never morrow', 0),
#  ('Shall dawn upon him, desolate!)', 0),
#  ('And, round about his home, the glory', 0),
#  ('That blushed and bloomed', 0),
#  ('Is but a dim-remembered story', 0),
#  ('Of the old time entombed.', 0),
#  ('', 0),
#  ('And travellers now within that valley,', 0),
#  ('Through the red-litten windows, see', 0),
#  ('Vast forms that move fantastically', 0),
#  ('To a discordant melody;', 0),
#  ('While, like a rapid ghastly river,', 0),
#  ('Through the pale door,', 0),
#  ('A hideous throng rush out forever,', 0),
#  ('And laugh --but smile no more.', 0),
#  ('Two roads diverged in a yellow wood,', 1),
#  ('And sorry I could not travel both', 1),
#  ('And be one traveler, long I stood', 1),
#  ('And looked down one as far as I could', 1),
#  ('To where it bent in the undergrowth; ', 1),
#  ('', 1),
#  ('Then took the other, as just as fair,', 1),
#  ('And having perhaps the better claim', 1),
#  ('Because it was grassy and wanted wear,', 1),
#  ('Though as for that the passing there', 1),
#  ('Had worn them really about the same,', 1),
#  ('', 1),
#  ('And both that morning equally lay', 1),
#  ('In leaves no step had trodden black.', 1),
#  ('Oh, I kept the first for another day! ', 1),
#  ('Yet knowing how way leads on to way', 1),
#  ('I doubted if I should ever come back.', 1),
#  ('', 1),
#  ('I shall be telling this with a sigh', 1),
#  ('Somewhere ages and ages hence:', 1),
#  ('Two roads diverged in a wood, and I,', 1),
#  ('I took the one less traveled by,', 1),
#  ('And that has made all the difference.', 1),
#  ('', 1),
#  ('Whose woods these are I think I know.', 1),
#  ('His house is in the village, though; ', 1),
#  ('He will not see me stopping here', 1),
#  ('To watch his woods fill up with snow.', 1),
#  ('', 1),
#  ('My little horse must think it queer', 1),
#  ('To stop without a farmhouse near', 1),
#  ('Between the woods and frozen lake', 1),
#  ('The darkest evening of the year.', 1),
#  ('', 1),
#  ('He gives his harness bells a shake', 1),
#  ('To ask if there is some mistake.', 1),
#  ("The only other sound's the sweep", 1),
#  ('Of easy wind and downy flake.', 1),
#  ('', 1),
#  ('The woods are lovely, dark and deep,', 1),
#  ('But I have promises to keep,', 1),
#  ('And miles to go before I sleep,', 1),
#  ('And miles to go before I sleep. ', 1),
#  ('', 1),
#  ('Some say the world will end in fire,', 1),
#  ('Some say in ice.', 1),
#  ("From what I've tasted of desire", 1),
#  ('I hold with those who favor fire.', 1),
#  ('But if it had to perish twice,', 1),
#  ('I think I know enough of hate', 1),
#  ('To say that for destruction ice', 1),
#  ('Is also great', 1),
#  ('And would suffice.', 1),
#  ('', 1),
#  ("Nature's first green is gold,", 1),
#  ('Her hardest hue to hold.', 1),
#  ("Her early leaf's a flower; ", 1),
#  ('But only so an hour.', 1),
#  ('Then leaf subsides to leaf,', 1),
#  ('So Eden sank to grief,', 1),
#  ('So dawn goes down to day', 1),
#  ('Nothing gold can stay.', 1),
#  ('', 1),
#  ('I have been one acquainted with the night.', 1),
#  ('I have walked out in rain - and back in rain.', 1),
#  ('I have outwalked the furthest city light.', 1),
#  ('', 1),
#  ('I have looked down the saddest city lane.', 1),
#  ('I have passed by the watchman on his beat', 1),
#  ('And dropped my eyes, unwilling to explain.', 1),
#  ('', 1),
#  ('I have stood still and stopped the sound of feet', 1),
#  ('When far away an interrupted cry', 1),
#  ('Came over houses from another street,', 1),
#  ('', 1),
#  ('But not to call me back or say good-bye; ', 1),
#  ('And further still at an unearthly height,', 1),
#  ('One luminary clock against the sky', 1),
#  ('', 1),
#  ('Proclaimed the time was neither wrong nor right.', 1),
#  ('I have been one acquainted with the night.', 1),
#  ('', 1),
#  ('When I go up through the mowing field,', 1),
#  ('The headless aftermath,', 1),
#  ('Smooth-laid like thatch with the heavy dew,', 1),
#  ('Half closes the garden path.', 1),
#  ('', 1),
#  ('And when I come to the garden ground,', 1),
#  ('The whir of sober birds', 1),
#  ('Up from the tangle of withered weeds', 1),
#  ('Is sadder than any words', 1),
#  ('', 1),
#  ('A tree beside the wall stands bare,', 1),
#  ('But a leaf that lingered brown,', 1),
#  ('Disturbed, I doubt not, by my thought,', 1),
#  ('Comes softly rattling down.', 1),
#  ('', 1),
#  ('I end not far from my going forth', 1),
#  ('By picking the faded blue', 1),
#  ('Of the last remaining aster flower', 1),
#  ('To carry again to you.', 1),
#  ('', 1),
#  ('A voice said, Look me in the stars', 1),
#  ('And tell me truly, men of earth,', 1),
#  ('If all the soul-and-body scars', 1),
#  ('Were not too much to pay for birth.', 1),
#  ('', 1),
#  ('To think to know the country and now know', 1),
#  ('The hillside on the day the sun lets go', 1),
#  ('Ten million silver lizards out of snow!', 1),
#  ("As often as I've seen it done before", 1),
#  ("I can't pretend to tell the way it's done.", 1),
#  ('It looks as if some magic of the sun', 1),
#  ('Lifted the rug that bred them on the floor', 1),
#  ('And the light breaking on them made them run.', 1),
#  ('But if I though to stop the wet stampede,', 1),
#  ('And caught one silver lizard by the tail,', 1),
#  ('And put my foot on one without avail,', 1),
#  ('And threw myself wet-elbowed and wet-kneed', 1),
#  ("In front of twenty others' wriggling speed,- ", 1),
#  ('In the confusion of them all aglitter,', 1),
#  ('And birds that joined in the excited fun', 1),
#  ('By doubling and redoubling song and twitter,', 1),
#  ("I have no doubt I'd end by holding none.", 1),
#  ('', 1),
#  ("It takes the moon for this. The sun's a wizard", 1),
#  ("By all I tell; but so's the moon a witch.", 1),
#  ('From the high west she makes a gentle cast', 1),
#  ('And suddenly, without a jerk or twitch,', 1),
#  ('She has her speel on every single lizard.', 1),
#  ("I fancied when I looked at six o'clock", 1),
#  ('The swarm still ran and scuttled just as fast.', 1),
#  ('The moon was waiting for her chill effect.', 1),
#  ('I looked at nine: the swarm was turned to rock', 1),
#  ('In every lifelike posture of the swarm,', 1),
#  ('Transfixed on mountain slopes almost erect.', 1),
#  ('Across each other and side by side they lay.', 1),
#  ('The spell that so could hold them as they were', 1),
#  ('Was wrought through trees without a breath of storm', 1),
#  ('To make a leaf, if there had been one, stir.', 1),
#  ('One lizard at the end of every ray.', 1),
#  ('The thought of my attempting such a stray! ', 1),
#  ('', 1),
#  ('ONCE on the kind of day called "weather breeder,"', 1),
#  ('When the heat slowly hazes and the sun', 1),
#  ('By its own power seems to be undone,', 1),
#  ('I was half boring through, half climbing through', 1),
#  ('A swamp of cedar. Choked with oil of cedar', 1),
#  ('And scurf of plants, and weary and over-heated,', 1),
#  ('And sorry I ever left the road I knew,', 1),
#  ('I paused and rested on a sort of hook', 1),
#  ('That had me by the coat as good as seated,', 1),
#  ('And since there was no other way to look,', 1),
#  ('Looked up toward heaven, and there against the blue,', 1),
#  ('Stood over me a resurrected tree,', 1),
#  ('A tree that had been down and raised again—', 1),
#  ('A barkless spectre. He had halted too,', 1),
#  ('As if for fear of treading upon me.', 1),
#  ('I saw the strange position of his hands—', 1),
#  ('Up at his shoulders, dragging yellow strands', 1),
#  ('Of wire with something in it from men to men.', 1),
#  ('"You here?" I said. "Where aren\'t you nowadays', 1),
#  ("And what's the news you carry—if you know?", 1),
#  ("And tell me where you're off for—Montreal?", 1),
#  ("Me? I'm not off for anywhere at all.", 1),
#  ('Sometimes I wander out of beaten ways', 1),
#  ('Half looking for the orchid Calypso."', 1),
#  ('', 1),
#  ('Brown lived at such a lofty farm', 1),
#  ('That everyone for miles could see', 1),
#  ('His lantern when he did his chores', 1),
#  ('In winter after half-past three.', 1),
#  ('', 1),
#  ('And many must have seen him make', 1),
#  ('His wild descent from there one night,', 1),
#  ("'Cross lots, 'cross walls, 'cross everything,", 1),
#  ('Describing rings of lantern light.', 1),
#  ('', 1),
#  ('Between the house and barn the gale', 1),
#  ('Got him by something he had on', 1),
#  ('And blew him out on the icy crust', 1),
#  ('That cased the world, and he was gone!', 1),
#  ('', 1),
#  ('Walls were all buried, trees were few:', 1),
#  ('He saw no stay unless he stove', 1),
#  ('A hole in somewhere with his heel.', 1),
#  ('But though repeatedly he strove', 1),
#  ('', 1),
#  ('And stamped and said things to himself,', 1),
#  ('And sometimes something seemed to yield,', 1),
#  ('He gained no foothold, but pursued', 1),
#  ('His journey down from field to field.', 1),
#  ('', 1),
#  ('Sometimes he came with arms outspread', 1),
#  ('Like wings, revolving in the scene', 1),
#  ('Upon his longer axis, and', 1),
#  ('With no small dignity of mien.', 1),
#  ('', 1),
#  ('Faster or slower as he chanced,', 1),
#  ('Sitting or standing as he chose,', 1),
#  ('According as he feared to risk', 1),
#  ('His neck, or thought to spare his clothes,', 1),
#  ('', 1),
#  ...]

# %% [markdown]
# * Train-test split

# %%
#shuffle data
import random
random.shuffle(data)

# %%
split = int(0.8*len(data))
train = data[:split]
test = data[split:]

train
# Out:
# [('In the seraphic glancing of thine eyes-', 0),
#  ('As if the turret-tops had given', 0),
#  ("The road there, if you'll let a guide direct you", 1),
#  ("You'll be expecting John. I pity Estelle; ", 1),
#  ("And last year's berries shining scarlet red.", 1),
#  ('Oh, I kept the first for another day! ', 1),
#  ('And the other listening things)', 0),
#  ('From north to south across the blue;', 1),
#  ('In her highest noon,', 0),
#  ('And built a stone baptismal font outdoors-', 1),
#  ("No doubt it's grown up some to woods around it.", 1),
#  ('She seems to have the housework, and besides, ', 1),
#  ('', 1),
#  ('voted the only times he ever voted,', 1),
#  ("They don't dispose me, either one of them,", 1),
#  ('Say it right out- no matter for her mother. ', 1),
#  ('The moon was waiting for her chill effect.', 1),
#  ('I listened till it almost climbed the stairs', 1),
#  ('I never could have done the thing I did', 1),
#  ('Of all who owe thee most- whose gratitude', 0),
#  ('', 0),
#  ('I had a glimpse through curtain laces', 1),
#  ("In fresh myrtle my blade I'll entwine,", 0),
#  ('Take a bank note and fold it up, ', 0),
#  ("'No, he won't, either. He'll just drop the reins ", 1),
#  ('At least to pass by and see who he was, ', 1),
#  ('So as to sort of turn me out of it.', 1),
#  ('Well I know, now, this dim lake of Auber -', 0),
#  ('Better than banking, trade or leases ', 0),
#  ('When all who would come seeking in New Hampshire ', 1),
#  ("'I thought you were a guide.'", 1),
#  ('I made him gather me wet snow berries', 1),
#  ('Not answering your knock. I can no more ', 1),
#  ('Nearest resembles worship- oh, remember', 0),
#  ('Was counting winter dinners, one a hill,', 1),
#  ('Of cypress, with Psyche, my Soul.', 0),
#  ('And yet that spirit knew not, in the hour', 0),
#  ('Off from the house as far as we could keep', 1),
#  ("He'll sort of swear the time away. He's awful! ", 1),
#  ('The Arthur Amy I was married to', 1),
#  ('', 1),
#  ("'What bones?' 'The cellar bones- out of the grave.'", 1),
#  ("'Aren't you afraid of him? What's that gun for?' ", 1),
#  ('With sounds like the dry rattling of a shutter,', 1),
#  ('To drag down man', 1),
#  ("On Marshall, look like donkey's ears.", 1),
#  ('This wonderful plan, without danger or loss, ', 0),
#  ('Of constellations.', 1),
#  ('My little horse must think it queer', 1),
#  ("'I mean she's married- married someone else.' ", 1),
#  ('', 1),
#  ('', 1),
#  ("'For God's sake, aren't you fond of viewing nature?", 1),
#  ('', 1),
#  ('', 1),
#  ('Was it some money suddenly come into?', 1),
#  ("So that was what was back. She's bad, that's all!' ", 1),
#  ('John Hall touch me! Not if he knows his friends. ', 1),
#  ('', 1),
#  ('(Ah, let us mourn, for never morrow', 0),
#  ('Perhaps, to where it ended at a house', 1),
#  ('Still more unfettered,', 1),
#  ('In daylight, and in beauty, from his birth: ', 0),
#  ('Though set so far', 1),
#  ('', 1),
#  ("He guessed they'd know what he had to put up with.", 1),
#  ('Of getting home again because', 1),
#  ('', 1),
#  ('The ecstasies above', 0),
#  ('A hole in somewhere with his heel.', 1),
#  ('And would suffice.', 1),
#  ("Haven't as good. They don't go with the farm. ", 1),
#  ('Uttered alone', 1),
#  ('Might just as well be ice and the clothes snow.', 1),
#  ('I turned and repented, but coming back', 1),
#  ('From sleeping warm', 1),
#  ("He's fifty-five, you know, if he's a day.' ", 1),
#  ('The faintest restless rustling ran all through them.', 1),
#  ('We noted not the dim lake of Auber -', 0),
#  ('', 1),
#  ('The pen falls powerless from my shivering hand.', 0),
#  ("Of all who, on Despair's unhallowed bed", 0),
#  ('In the sad, silent watches of my night; ', 0),
#  ('Which were seven,)', 0),
#  ('in one self station.', 1),
#  ('', 0),
#  ("'I know.' ", 1),
#  ('She revels in a region of sighs:', 0),
#  ('And sleep to dream till day', 0),
#  ('The way he did in life once; but this time', 1),
#  ('The waves have now a redder glow', 0),
#  ('Resignedly beneath the sky', 0),
#  ("Whose shoes I primped to dance in!' ", 1),
#  ('But only a belilaced cellar hole,', 1),
#  ('So with the world thy gentle ways,', 0),
#  ('', 1),
#  ('One lizard at the end of every ray.', 1),
#  ("But when I've said, 'Why shouldn't they be married,' ", 1),
#  ('Some say in ice.', 1),
#  ('Then shook his lantern, saying, "Ile\'s', 1),
#  ('With the gourd and the grape luxuriant grew. ', 0),
#  ('Of lip-begotten words-', 0),
#  ("And between what he doesn't know", 1),
#  ('In voices of surpassing beauty,', 0),
#  ('Disturbed the slumbering village street', 1),
#  ("'I'm sure she won't come back. She's hiding somewhere. ", 1),
#  ('That groan as they roll down Mount Yaanek', 0),
#  ("I think we're all mad. Tell me why we're here ", 1),
#  ("They found he'd gnawed the four posts of his bed,", 1),
#  ('And every gentle air that dallied,', 0),
#  ('', 0),
#  ('He can eat off a barrel from the ground. ', 1),
#  ('The tote road to our clearing where we lived.', 1),
#  ('Tried to improve on sailing like a tile', 1),
#  ('Well may the stars be mute!', 0),
#  ("Tho' not with Faith- with godliness- whose throne", 0),
#  ('Quenching the fires its ashes hide,-- ', 0),
#  ("Does the rain seem to you to cool the eyes?' ", 1),
#  ('And sit up by me and take hold of me.', 1),
#  ('With sweet hopes of thee and thine!', 0),
#  ('Serenest skies continually', 0),
#  ("Couldn't have been the one they say was up", 1),
#  ('By road, a matter of several miles.', 1),
#  ('But not the riches there that lie', 0),
#  ("'He's nothing. Listen. When I lean like this ", 1),
#  ('But a leaf that lingered brown,', 1),
#  ("Not that he hadn't gnawed the hitching posts", 1),
#  ('Thy heart- thy heart!- I wake and sigh,', 0),
#  ('However far you must go for bricks,', 1),
#  ('', 1),
#  ('Of here and there a tent in grove and orchard. ', 1),
#  ('I vow we must be near the place from where', 1),
#  ('', 1),
#  ("'And we live up to it; or I don't know ", 1),
#  ('And the queenly lily adown the dale ', 0),
#  ('Within the heart ', 0),
#  ('Then that same smarty someone said to look- ', 1),
#  ('Over descended from her. I believe ', 1),
#  ("That's no way for a man to do at his age: ", 1),
#  ("Our business first's up attic with her books.'", 1),
#  ('The happy flowers and the repining trees, ', 0),
#  ("And this bill.' ", 1),
#  ('And every time that you fold it across, ', 0),
#  ('Not to sink under being man and wife,', 1),
#  ('The bowers whereat, in dreams, I see', 0),
#  ('And came down like a coasting child.', 1),
#  ('The poetess who wrote the book of verses', 1),
#  ('Around and under', 1),
#  ('He saw no stay unless he stove', 1),
#  ('That cannot but guide us aright,', 0),
#  ('Of what was either cloud or smoke', 1),
#  ('And hoary trees with groans of woe, ', 0),
#  ('', 1),
#  ('', 1),
#  ('I think I know enough of hate', 1),
#  ('According as he feared to risk', 1),
#  ('And conquered her scruples and gloom;', 0),
#  ('Our talk had been serious and sober,', 0),
#  ('Lifted the rug that bred them on the floor', 1),
#  ("I don't know where myself. John thinks I do. ", 1),
#  ('Was it not Fate, (whose name is also Sorrow,) ', 0),
#  ('', 0),
#  ("'I mean Estelle has always held the purse.' ", 1),
#  ('We have seen visions- now consult the voices. ', 1),
#  ('Up domes up spires up kingly halls', 0),
#  ('What is this talked-of mystery of birth', 1),
#  ('In the fever of a minute:', 0),
#  ("With love in her luminous eyes.'", 0),
#  ('They spoke of the sun', 1),
#  ("So's to take any comfort. I can sew: ", 1),
#  ("Where Love's a grown-up God-", 0),
#  ('You _can_ come down from everything to nothing.', 1),
#  ("In eighty-five.'", 1),
#  ("If you don't want to spend the night outdoors.", 1),
#  ('And Jupiter.', 1),
#  ('In dust once more. We followed this a mile,', 1),
#  ('In the misty mid region of Weir-', 0),
#  ("I hate to think of the old place when we're gone, ", 1),
#  ('To the place where John has been cutting trees', 1),
#  ("I've never listened in among the sounds ", 1),
#  ('My duty, to be saved by their bright light, ', 0),
#  ('', 1),
#  ('Of the baubles that it may.', 0),
#  ('But Psyche, uplifting her finger,', 0),
#  ('Among unearthed potatoes standing still,', 1),
#  ('And sanctified in their elysian fire. ', 0),
#  ('Or old love on an impulse not to care- ', 1),
#  ('By him who, as he pens them, thrills to think', 0),
#  ("You don't like nature. All you like is books.", 1),
#  ('', 1),
#  ('Have stirred from out the abysses of his heart,', 0),
#  ("That Israfeli's fire", 0),
#  ('My French Indian Esquimaux,', 1),
#  ('They were crooking many a trillium', 1),
#  ('Brushing their chalky skull with chalky fingers,', 1),
#  ('By good angels tenanted,', 0),
#  ('Up one flight from the cellar to the kitchen,', 1),
#  ("Estelle's to take me when she's settled down. ", 1),
#  ('And blew him out on the icy crust', 1),
#  ('', 1),
#  ("Strung on your hair won't hurt your summer looks. ", 1),
#  ('The attic wasps went missing by like bullets.', 1),
#  ('At the end of our path a liquescent', 0),
#  ('One luminary clock against the sky', 1),
#  ('Where Achilles and Diomed rest. ', 0),
#  ('', 0),
#  ('We came out on a look-off where we faced', 1),
#  ('And spoke of the lettered,', 1),
#  ('And we passed to the end of the vista,', 0),
#  ('He must have changed his mind and gone to Garlands. ', 1),
#  ('', 1),
#  ("Someday I will.'", 1),
#  ('The situation was like this: the road ', 1),
#  ('', 0),
#  ('', 1),
#  ('', 1),
#  ("Come here- I'll show you- in that apple tree. ", 1),
#  ('This he sat listening to till she gave judgment. ', 1),
#  ('Transfixed on mountain slopes almost erect.', 1),
#  ('But lo! a stir is in the air!', 0),
#  ('', 1),
#  ('With all the rain and snow of seven years;', 1),
#  ('Well then, right here is where I show you books.', 1),
#  ('That a brook makes in such a wild descent. ', 1),
#  ('He gives his harness bells a shake', 1),
#  ('None sing so wildly well', 0),
#  ('', 0),
#  ('They have not left me (as my hopes have) since; ', 0),
#  ('', 1),
#  ('The life is not yet all gone out of it. ', 1),
#  ('The bulkhead double-doors were double-locked', 1),
#  ('Who used to live here. They were Robinsons.', 1),
#  ('Come up through the lair of the Lion,', 0),
#  ('At sight of thee and thine at once awake!', 0),
#  ('And he liked everything I made him do.', 1),
#  ('Should say our stock was petered out,', 1),
#  ("I'll tell you who'd remember- Heman Lapish.", 1),
#  ("'Don't! The voices seem to say: ", 1),
#  ("Right's right, and the temptation to do right", 1),
#  ('To say that for destruction ice', 1),
#  ('(Nine times removed. Correct me if I err.) ', 1),
#  ('(Drear path, alas! where grows', 0),
#  ('To be a nova,', 1),
#  ("'I let you say that- on consideration.' ", 1),
#  ("'It's you,' she said. 'I can't get up. Forgive me ", 1),
#  ('And birds that joined in the excited fun', 1),
#  ('Then my heart it grew ashen and sober', 0),
#  ('That from new fountains overflow, ', 0),
#  ("We're not allowed to take them upside down, ", 1),
#  ("Wentworth and Warren's both good towns to live in,", 1),
#  ('That I brought a dread burden down here-', 0),
#  ('Boys and bad hunters had known what to do', 1),
#  ("That there's something the dead are keeping back?", 1),
#  ("I can't keep track of other people's daughters. ", 1),
#  ("'It looks that way.' ", 1),
#  ('How often we forget all time, when lone ', 0),
#  ("'I only mean my mother was a Stark ", 1),
#  ("The same as you seize cat's-cradle strings,", 1),
#  ('', 0),
#  ("I can't say he's much help;", 1),
#  ('Of dust and feather.', 1),
#  ("Yes, there's something the dead are keeping back.", 1),
#  ("'I idled down.' ", 1),
#  ('By picking the faded blue', 1),
#  ('Were not their own:', 1),
#  ("He's got hay down that's been rained on three times. ", 1),
#  ("'If I remember rightly, it had sprung", 1),
#  ('Drink and be whole again beyond confusion.', 1),
#  ("But I don't see why it should have to bear", 1),
#  ("'And where's John?' ", 1),
#  ('The playthings in the playhouse of the children.', 1),
#  ("That's what I sit up in the dark to say-", 1),
#  ("Mebbe I'm wrong to take it as I do. ", 1),
#  ('He always used to sing along the tote-road.', 1),
#  ("She might as well herself.' But he liked best", 1),
#  ("We'd kept all these years between ourselves", 1),
#  ('Ah, we safely may trust to its gleaming,', 0),
#  ('Thou wouldst be loved?- then let thy heart', 0),
#  ('Ascending to descend to reascend.', 1),
#  ('But I have promises to keep,', 1),
#  ("Ye avengers of Liberty's wrongs!", 0),
#  ('In youth I have known one with whom the Earth ', 0),
#  ('The snow fell deep', 1),
#  ('Let us bathe in this crystalline light!', 0),
#  ('But evil things, in robes of sorrow,', 0),
#  ('And not melt snow or start a dormant tree.', 1),
#  ('Old Davis owned a solid mica mountain', 1),
#  ('The darkest evening of the year.', 1),
#  ('Let my Future radiant shine', 0),
#  ("This ghoul-haunted woodland of Weir.' ", 0),
#  ('Upon those crystalline, celestial spheres! ', 0),
#  ('', 1),
#  ('The enamored moon', 0),
#  ('A barkless spectre. He had halted too,', 1),
#  ('Nor never will be to my way of thinking. ', 1),
#  ('', 1),
#  ('', 1),
#  ('Of youthful forms and youthful faces.', 1),
#  ("But to-night I don't care enough to lie-", 1),
#  ("One of the times was when 'twas in the warrant", 1),
#  ('On this very night of last year', 0),
#  ('', 0),
#  ('I guess he found he got more out of me', 1),
#  ('', 1),
#  ("And if I'd left him hitched unblanketed", 1),
#  ('But our thoughts they were palsied and sere -', 0),
#  ('', 0),
#  ('And be sure it will lead us aright -', 0),
#  ('Come up, in despite of the Lion,', 0),
#  ('Hourly for hope- for life- ah! above all,', 0),
#  ("'That's a long time ", 1),
#  ('Maria! thou hast heard my hymn!', 0),
#  ('2o3 Let them stay in the attic since they went there.', 1),
#  ('Here are your waters and your watering place.', 1),
#  ('The whir of sober birds', 1),
#  ('I wanted to try something with the noise ', 1),
#  ('Among the buttons poured out in her lap.', 1),
#  ('Whose fervid, flickering torch of life was lit', 0),
#  ('When the Hours flew brightly by,', 0),
#  ('To the Lethean peace of the skies -', 0),
#  ('Got him by something he had on', 1),
#  ('Of detail, burned, dissolved, and broken off', 1),
#  ('Through the pale door,', 0),
#  ("He's given her time to think of something else. ", 1),
#  ('MOTHER: Bones - a skeleton.', 1),
#  ('Who otherwise would fall from life and Heaven', 0),
#  ('Lie dead on my heart-strings', 0),
#  ('', 1),
#  ('I staid the night for shelter at a farm', 1),
#  ("'Where shall we meet again?' ", 1),
#  ('', 1),
#  ('done?', 1),
#  ("I'll tell you a plan for gaining wealth,", 0),
#  ('', 1),
#  ('And then a steeple.', 1),
#  ("Up attic that we'd ever want again.", 1),
#  ('', 0),
#  ('Twenty for this cock, twenty-five for that. ', 1),
#  ('Yankees are what they always were.', 1),
#  ("'Tis said that when ", 0),
#  ('The young folk held some hope out to each other ', 1),
#  ('(Though once we had journeyed down here),', 0),
#  ('The very hours are breathing low', 0),
#  ("'Hadn't you long suspected where you were?'", 1),
#  ('It was a July midnight; and from out ', 0),
#  ('You see our pretty things are all outdoors. ', 1),
#  ('When I can hurt someone by doing it', 1),
#  ("That with a quickening spell doth o'er us pass", 0),
#  ('But though it runs unbridled off its course,', 1),
#  ('Since it flickers up to Heaven through the night."', 0),
#  ('It was the bones. I knew them - and good reason.', 1),
#  ('I must not say how many- but not many. ', 0),
#  ('', 1),
#  ('To shine on us with her bright eyes -', 0),
#  ('Of castles I used to build in air.', 1),
#  ('All four of them to splinters. What did that prove?', 1),
#  ('', 1),
#  ('Into each other. Both of them are lost.', 1),
#  ("Two at a time's the rule, one on each arm, ", 1),
#  ("'Yes, what do I see? ", 1),
#  ('', 0),
#  ('Disturbed, I doubt not, by my thought,', 1),
#  ("He's groping in the cellar after jam, ", 1),
#  ('So Eden sank to grief,', 1),
#  ('Then he came at me with one hand outstretched,', 1),
#  ('Their Arthur Amy was the father of mine.', 1),
#  ('The meaning of it all is out of you; ', 1),
#  ("And, 'Better defeat almost,", 1),
#  ('A piercing little star was through.', 1),
#  ("'I'm waiting.' ", 1),
#  ('All Hades, from a thousand thrones,', 0),
#  ('Moving a flock of hens from place to place. ', 1),
#  ('With stone and lead to unprotected glass:', 1),
#  ("What childishness he wouldn't give way to. ", 1),
#  ("I can't explain it any other way. ", 1),
#  ('Of yawning lenses.', 1),
#  ('A feather-hammer gives a double knock.', 1),
#  ('I promised Toffile to be cruel to them', 1),
#  ('Save only thee and me. I paused- I looked- ', 0),
#  ("Making allowance, making due allowance.' ", 1),
#  ('And the fur trade,', 1),
#  ("'Take one,' Old Davis bade me graciously.", 1),
#  ("Said- 'Sadly this star I mistrust-", 0),
#  ('A troop of Echoes whose sweet duty', 0),
#  ('How my heart beats in coupling those two words!) ', 0),
#  ("You won't see any Mormon swimming in it.", 1),
#  ('And travellers now within that valley,', 0),
#  ('Across each other and side by side they lay.', 1),
#  ('Of the old time entombed.', 0),
#  ('As we can fall and keep a-bouncing on our feet.', 1),
#  ('How fathomless a capacity for love! ', 0),
#  ('I went to sleep before I went to bed,', 1),
#  ('', 1),
#  ('From their merry little throats ', 0),
#  ("At thy soft-murmured words, 'Let there be light!'", 0),
#  ("'Not from the rain. I think it's going to rain.' ", 1),
#  ('No matter how far and how many times ', 1),
#  ('From their melancholy throats! ', 0),
#  ('I saw but them- saw only them for hours, ', 0),
#  ("Now left's no bigger than a harness gall.", 1),
#  ('In Heaven a spirit doth dwell', 0),
#  ("And dangle feet among the raspberry vines?' ", 1),
#  ("And won't tell", 1),
#  ('All fresh and sound from the recent axe.', 1),
#  ('', 0),
#  ('', 1),
#  ("From what I've tasted of desire", 1),
#  ('Down, down, that town shall settle hence,', 0),
#  ("Nothing's too good for them. We say it pays. ", 1),
#  ('', 1),
#  ('With the furthest bodies', 1),
#  ('And that was all there was to see', 1),
#  ('But the skies that angel trod,', 0),
#  ('Of wire with something in it from men to men.', 1),
#  ('Was the fair palace door,', 0),
#  ("A libation of Tyranny's blood. ", 0),
#  ('I have been one acquainted with the night.', 1),
#  ('While, like a rapid ghastly river,', 0),
#  ('', 1),
#  ('Come up, in despite of the Lion,', 0),
#  ('To where the prospect terminates- thee only.', 0),
#  ('And since there was no other way to look,', 1),
#  ('Of the last remaining aster flower', 1),
#  ('Inscription for a Garden Wall', 1),
#  ('The uncommonly deep snow has made him think', 1),
#  ('In an old cellar hole in a by-road ', 1),
#  ('Its Sybilic splendor is beaming', 0),
#  ('', 1),
#  ("'Estelle's the one. You needn't talk to me.' ", 1),
#  ('Transforming all! Thy charms shall please no more-', 0),
#  ('In the misty mid region of Weir -', 0),
#  ('They spoke for the clock', 1),
#  ('And, round about his home, the glory', 0),
#  ('John said I was too old to have grandchildren. ', 1),
#  ('And I cried - "It was surely October', 0),
#  ('The wantonest singing birds,', 0),
#  ('With our arms at the level of our knees,', 1),
#  ('With thy dear name as text, though bidden by thee,', 0),
#  ('Like silent streams ', 0),
#  ('Beloved! amid the earnest woes', 0),
#  ("'Oho, oho!' ", 1),
#  ("'Oh, if you're going to use your eyes, just hear ", 1),
#  ('Two words- two foreign soft dissyllables-', 0),
#  ('Time someone came with cart and pair', 1),
#  ('And sparkling evermore,', 0),
#  ("You don't know what a gentle lot we are: ", 1),
#  ("Of its own fervor what had o'er it power.", 0),
#  ('Of my most immemorial year;', 0),
#  ('They left the named', 1),
#  ('I went till there were no cottages found.', 1),
#  ("'Oh, that's been there for hawks since chicken-time. ", 1),
#  ('No holy rays from heaven come down', 0),
#  ('I took the one less traveled by,', 1),
#  ('', 1),
#  ('', 1),
#  ("Receipted. And the cock is in the yard.' ", 1),
#  ('Of his voice, all mute.', 0),
#  ('They were at Bow, but that was not enough: ', 1),
#  ('Bowed outward on the mountain half-way up, ', 1),
#  ('The heavy iron bells! ', 0),
#  ('That is, if facts is what they want to go by.', 1),
#  ('With furs to sell.', 1),
#  ('In daylight, and in beauty from his birth:', 0),
#  ('But feared the cold', 1),
#  ('See!- it flickers up the sky through the night!', 0),
#  ("That's his mistake. The dear knows my interest ", 1),
#  ("With desperate energy 't hath beaten down; ", 0),
#  ('', 1),
#  ('To seek a shelter in some happier star?', 0),
#  ('In the realms of the boreal pole.', 0),
#  ('Death looks gigantically down.', 0),
#  ('The leaves they were crisped and sere -', 0),
#  ('\u2009', 0),
#  ('Strolled thither, not expecting he would find ', 1),
#  ("My, but he looks as if he must have heard!' ", 1),
#  ('Are not like any thing of ours', 0),
#  ('And sometimes something seemed to yield,', 1),
#  ("On motor-cars, I'm asked if I", 1),
#  ('Who failed to find or force a strait', 1),
#  ('', 1),
#  ("His name's Joe,", 1),
#  ("'Who wants to hear your news, you- dreadful fool?'", 1),
#  ('To make it surer that I was a witch?', 1),
#  ("'Who'd marry her straight out of such a mess? ", 1),
#  ('Darkly my Present and my Past,', 0),
#  ('For no ripples curl, alas!', 0),
#  ("No more than brought us back into the name.' ", 1),
#  ("It'd make my position stronger, I think,", 1),
#  ('He never let the lantern drop.', 1),
#  ('I have been one acquainted with the night.', 1),
#  ('The sigmas and taus', 1),
#  ('Should take the polish off the crust.', 1),
#  ('She thinks if it was bad to live with him, ', 1),
#  ('As the angel Israfel,', 0),
#  ('To such a ghost—', 1),
#  ("To undo what he'd done and make it right,", 1),
#  ("And bring the chalk-pile down. 'I'll tell you what-", 1),
#  ('As the star-dials hinted of morn-', 0),
#  ("It doesn't seem as if I'd had the courage", 1),
#  ('And such few people', 1),
#  ("(And I know of one that didn't thrive)", 1),
#  ("Drawn by their heart's passion, and that tone,", 0),
#  ('I cannot write- I cannot speak or think-', 0),
#  ('And turn Doll out to pasture, rig and all. ', 1),
#  ('All- all expired save thee- save less than thou: ', 0),
#  ("'The Indians had a myth of Chicamoztoc, ", 1),
#  ('And thought I heard him downstairs in the cellar.', 1),
#  ("And what's the news you carry—if you know?", 1),
#  ('', 0),
#  ('Half of the outdoor work, though as for that, ', 1),
#  ('And nothing came of all be sailed.', 1),
#  ('That crowd around my earthly path-', 0),
#  ('Its hands of gold', 1),
#  ("He don't gnaw trees and posts and fences too.", 1),
#  ('The hillside on the day the sun lets go', 1),
#  ("Now give me your hand up.- Pick me that flower.' ", 1),
#  ("But you have said it, and we're off to find it.", 1),
#  ("Which have wither'd as they rose", 0),
#  ('Tamed this primeval wood, ', 0),
#  ('I mean a man he killed instead of me.', 1),
#  ("'I may be mad.' ", 1),
#  ('That sends light rustle rushes to their leaves,', 1),
#  ('By which he sits and sings-', 0),
#  ('In going twice around the tree.', 1),
#  ('Pauses in Heaven.', 0),
#  ('Israfeli, who despisest', 0),
#  ('Saturn and Mars', 1),
#  ("I'll say that for him, John's no threatener ", 1),
#  ('And I dread the ominous stain of tar', 1),
#  ('Like starlight on a pall-', 0),
#  ("There wasn't always Hudson's Bay", 1),
#  ("Waiting for things to happen in their favour.'", 1),
#  ('While, to listen, the red levin', 0),
#  ('Speaking or singing, and the band-music playing. ', 1),
#  ('Their sulphurous currents down Yaanek', 0),
#  ('How had the tender verse escaped their outrage?', 1),
#  ('Up to their shining eyes in snow.', 1),
#  ('On planets over', 1),
#  ('And I said - "What is written, sweet sister,', 0),
#  ('But wait until I give you a hand up. ', 1),
#  ('She has her speel on every single lizard.', 1),
#  ('Keeps your cash in your hands, where nothing can trouble it; ', 0),
#  ("Your destination and your destiny's", 1),
#  ("So now they've dragged it through the law courts once", 1),
#  ('To say which buds are leaf and which are bloom.', 1),
#  ('Another from the kitchen to the bedroom,', 1),
#  ('Almost the moment he was given an opening,', 1),
#  ('That braced his feet against the Arctic Pole.', 1),
#  ('To thee the laurels belong,', 0),
#  ('And fight in a smother', 1),
#  ('Enough to stock a village library-', 1),
#  ('Is wasted like the snow, ', 0),
#  ('No bird was singing in it now.', 1),
#  ('Is back into the cellar where it came from.', 1),
#  ('He read in one and I read in another,', 1),
#  ('I replied - "This is nothing but dreaming:', 0),
#  ("They've got it settled wrong, and I can prove it.", 1),
#  ("Now, when storms of Fate o'ercast", 0),
#  ('Unthought-like thoughts that are the souls of thought,', 0),
#  ('The sun in the new-cut narrow gap', 1),
#  ("'It's as you throw a picture on a screen: ", 1),
#  ('"Isola d\'oro! Fior di Levante!"', 0),
#  ('Then cane one knock!', 1),
#  ("If some one hadn't said to gnaw the posts", 1),
#  ('Up thrones up long-forgotten bowers', 0),
#  ('The poetess had sighed, I knew, in heaven', 1),
#  ("'Reason enough, there was no property. ", 1),
#  ('Of stranger cousins, in a family tree ', 1),
#  ('A cliff, and on the cliff a bottle painted,', 1),
#  ('The past and get some strangeness out of it. ', 1),
#  ("That as a witch I'd often milk a bat", 1),
#  ('Her pallor I strangely mistrust:-', 0),
#  ('Were in their strength subdued, ', 0),
#  ('Here he is now. This box! Put it away. ', 1),
#  ('The bright i-dea, or the bright dear-eye.', 0),
#  ('I saw thee half reclining; while the moon ', 0),
#  ('', 1),
#  ('The small book in my pocket. It was there.', 1),
#  ("If he's untidy now, what will he be- - ? ", 1),
#  ('(Though not yet light)', 1),
#  ("Good-looking books like that.' He picked one fresh", 1),
#  ('He will not see me stopping here', 1),
#  ('I thought the growing things would do him good. ', 1),
#  ('Before its face.', 1),
#  ('Streams up the turrets silently', 0),
#  ("Some zealous one's laborious device. ", 1),
#  ('', 1),
#  ('I was just coming to myself enough', 1),
#  ("But why take time for what I'm like to hear? ", 1),
#  ('He gained no foothold, but pursued', 1),
#  ('', 1),
#  ('Was but to sing,', 0),
#  ("You said you'd seen the stone baptismal font.", 1),
#  ('Not in position to look too close.', 1),
#  ('But we get on.', 1),
#  ('I saw the strange position of his hands—', 1),
#  ('But please please me in the kitchen chimney:', 1),
#  ('', 1),
#  ('The spell that so could hold them as they were', 1),
#  ('', 1),
#  ('But I got wonted to it. And besides- ', 1),
#  ('I stay;', 1),
#  ('Would name the hour', 1),
#  ('Plumes till they trailed in the dust-', 0),
#  ('', 1),
#  ("Couldn't one talk to her? What does she say? ", 1),
#  ('Of his old song, The Wild Colonial Boy,', 1),
#  ('And not a cloud obscured the sky,', 0),
#  ('To wonder where the cold was coming from,', 1),
#  ("And if you're lost enough to find yourself", 1),
#  ('So suddenly I flung the door wide on him.', 1),
#  ('His small fist buried in the bushy hide.', 1),
#  ("I might have, but it doesn't seem as if.", 1),
#  ('Let us bathe in this crystalline light!', 0),
#  ("But what's the use of talking when it's done? ", 1),
#  ('Are happier, sweet, than I,', 0),
#  ("I'll show you. Here you are.' ", 1),
#  ('With the fervor of thy lute-', 0),
#  ('', 1),
#  ("'No, it's misting; let's be fair. ", 1),
#  ('One level nearer heaven overhead,', 1),
#  ('But rain spoiled all. The day began uncertain, ', 1),
#  ('If the bones liked the attic, let them have it.', 1),
#  ('Let people in than I can keep them out. ', 1),
#  ('', 1),
#  ('Someone had literally run to earth ', 1),
#  ('Not much concerned for those to whom,', 1),
#  ('Left here with nothing but the furniture. ', 1),
#  ('But not to call me back or say good-bye; ', 1),
#  ('And miles to go before I sleep,', 1),
#  ("He'd say, 'Why should they?' no more words than that.' ", 1),
#  ('Only too well. I knew there must be something! ', 1),
#  ("'You must be learned. That's what you see in it?' ", 1),
#  ('Therefore thou art not wrong,', 0),
#  ('It was night in the lonesome October', 0),
#  ('To send it sailing out the attic window', 1),
#  ('The swarm still ran and scuttled just as fast.', 1),
#  ('All claiming some priority in Starkness. ', 1),
#  ('Proclaimed the time was neither wrong nor right.', 1),
#  ("How shall we say good-bye in such a case?' ", 1),
#  ("But you see, don't you, we take care of him.' ", 1),
#  ('At the end of our path a liquescent', 0),
#  ("At that particular time o'clock,", 1),
#  ('Hath dwelt, and he where I,', 0),
#  ('Vast forms that move fantastically', 0),
#  ('As pale and dim as a match flame in the sun; ', 1),
#  ("If he could sell the place, but then, he can't: ", 1),
#  ('Ah, what demon has tempted me here?', 0),
#  ('', 1),
#  ("'No, I don't trust your eyes. You've said enough. ", 1),
#  ("Does it purport to speak in? Not old Grandsir's ", 1),
#  ('I have passed by the watchman on his beat', 1),
#  ('Will start, which lately slept in apathy? ', 0),
#  ('Describing rings of lantern light.', 1),
#  ('Books, I should say!- if books are what is needed.', 1),
#  ('I never saw so good a house deserted.', 1),
#  ('', 0),
#  ("At ten o'clock of a winter eve.", 1),
#  ('By now, pull in your ladder road behind you', 1),
#  ('From the sun and stars, whence he had drawn forth', 0),
#  ('The leaves they were withering and sere;', 0),
#  ("Old as I am, I'm going to let myself", 1),
#  ("There ain't no names quite like the old ones though, ", 1),
#  ('That groan as they roll down Mount Yaanek', 0),
#  ("Such as it is. It isn't worth the mortgage.' ", 1),
#  ('Thine eyes, in Heaven of heart enshrined,', 0),
#  ('Or some extravagance young love had been to?', 1),
#  ('If I could dwell', 0),
#  ('Their solemn peals', 1),
#  ("'What's this?' ", 1),
#  ('The headless aftermath,', 1),
#  ('He steered was really straight away', 1),
#  ('I blame his being brought up by his mother. ', 1),
#  ('In the joy breathing isles of the blest;', 0),
#  ('The night the bones came up the cellar-stairs', 1),
#  ('It was down by the dank tarn of Auber,', 0),
#  ("'Tis the vault of thy lost Ulalume!'", 0),
#  ("As dew of the night time, o'er the summer grass? ", 0),
#  ("'You mean miles from that Mormon settlement?", 1),
#  ("I name all the flowers I am sure they weren't;", 1),
#  ('Italian tones, made only to be murmured', 0),
#  ('I have walked out in rain - and back in rain.', 1),
#  ("Who are they for?' ", 1),
#  ('That blushed and bloomed', 0),
#  ("They set a lot (now don't they?) by a record", 1),
#  ('Through a house stripped of everything', 1),
#  ('To see if the town wanted to take over', 1),
#  ('A voice said, Look me in the stars', 1),
#  ("Here's hoping she gets her drink and gets out safely.' ", 1),
#  ("He's just dropped everything. He's like a child. ", 1),
#  ('The skies they were ashen and sober;', 0),
#  ("I can't talk to her, and, Lord, if I could!' ", 1),
#  ('Long since gave up pretense of keeping covered.', 1),
#  ("'I'm Stark.' He drew his passport. ", 1),
#  ('Or been made Master of the Grange."', 1),
#  ('', 1),
#  ('', 0),
#  ("NOW that they've got it settled whose I be,", 1),
#  ('Had checked the pace', 1),
#  ("'I want my fountain.'", 1),
#  ("I sat up on the floor and shouted, 'Toffile,", 1),
#  ("'I'll hardly breathe.' ", 1),
#  ("It's going to rain.' ", 1),
#  ("'Nor want to! ", 1),
#  ('No footstep stirred: the hated world an slept, ', 0),
#  ('Which means The Seven Caves that We Came out of. ', 1),
#  ('The thought of my attempting such a stray! ', 1),
#  ('As the leaves that were crisped and sere -', 0),
#  ('(Porphyrogene!)', 0),
#  ('And rode all over everything on him', 1),
#  ('They made him keep on gnawing till he whined.', 1),
#  ('', 1),
#  ("I wonder if it's not your make-believe. ", 1),
#  ('Resemble nothing that is ours.', 0),
#  ('How should he love thee? or how deem thee wise,', 0),
#  ('Yet knowing how way leads on to way', 1),
#  ('Smoke rolled inside the sockets of his eyes.)', 1),
#  ('Died in the arms of the adoring airs. ', 0),
#  ('Well I know, now, this dank tarn of Auber, -', 0),
#  ('Half looking for the orchid Calypso."', 1),
#  ('Or even thought of standing there', 1),
#  ('To blow the earth or anything self-clear;', 1),
#  ('While even in the meridian glare of day ', 0),
#  ('Anyone upon earth and still her children ', 1),
#  ('Our flowers are merely- flowers,', 0),
#  ("Of its own fervour - what had o'er it power. ", 0),
#  ('You never saw before. What will we come to ', 1),
#  ("It's harmless. Mother hears it in the night", 1),
#  ('', 0),
#  ('Whose entablatures intertwine', 0),
#  ('Spirits moving musically', 0),
#  ('In the realms of the boreal pole.', 0),
#  ("Fell on the upturn'd faces of these roses ", 0),
#  ("I've kept Brown standing in the cold", 1),
#  ("Against the' attic door: the door is nailed.", 1),
#  ('The pearly lustre of the moon went out: ', 0),
#  ("'You poor, dear, great, great, great, great Granny!' ", 1),
#  ('Embalmed in their echoing songs!', 0),
#  ('Who am a passer by.', 0),
#  ('Oh, hasten!- oh, let us not linger!', 0),
#  ('For fifty dollars for one Langshang cock- ', 1),
#  ('A hideous throng rush out forever,', 0),
#  ('Then make yourself at home. The only field', 1),
#  ('Looked up toward heaven, and there against the blue,', 1),
#  ('', 1),
#  ('Some say the world will end in fire,', 1),
#  ('Of all who hail thy presence as the morning-', 0),
#  ("I don't remember why I ever cared.", 1),
#  ('Off here', 1),
#  ('The wave there is a ripple there!', 0),
#  ('', 0),
#  ('Are lips- and all thy melody', 0),
#  ('Sancta Maria! turn thine eyes -', 0),
#  ('And now, as the night was senescent,', 0),
#  ('Perhaps it may be that my mind is wrought ', 0),
#  ('Half closes the garden path.', 1),
#  ('Ah, we safely may trust to its gleaming,', 0),
#  ('Was a girl; and she halted some way off ', 1),
#  ('A vacuum in the filmy heaven.', 0),
#  ('', 1),
#  ("'Why not take two or three?'", 1),
#  ('Perhaps it may be that my mind is wrought', 0),
#  ('I had to stop and lift my face;', 1),
#  ('Merrily live, and long!', 0),
#  ('A broken drinking goblet like the Grail', 1),
#  ('With the brook going by below the yard, ', 1),
#  ("I help out with this beadwork what I can.' ", 1),
#  ("On something- there's no harm. See, there he is! ", 1),
#  ('Fair isle, that from the fairest of all flowers,', 0),
#  ("'You know we might not be and still be cousins: ", 1),
#  ('Like Harmodious, the gallant and good,', 0),
#  ('And save for the wonder ', 1),
#  ('', 0),
#  ("That isn't it. Folks aren't afraid of us.' ", 1),
#  ('Content with bud-inspecting. They presume', 1),
#  ("I was a baby: I don't know where I was.", 1),
#  ('And since it was coming up had to come.', 1),
#  ('To reconnoitre, and then made up her mind ', 1),
#  ("'Cross lots, 'cross walls, 'cross everything,", 1),
#  ('And stamped and said things to himself,', 1),
#  ('Have gone to their eternal rest.', 0),
#  ('Though not with Faith - with godliness - whose throne ', 0),
#  ('And thou, a ghost, amid the entombing trees ', 0),
#  ("And anyway this tells me where I am.'", 1),
#  ("And I cried- 'It was surely October", 0),
#  ("To make them out.' ", 1),
#  ("There was no quarrel about property.' ", 1),
#  ("Oh, fly!- let us fly!- for we must.'", 0),
#  ('As standing in the river road,', 1),
#  ('The virgin Earth Gave instant birth ', 0),
#  ("I fancied when I looked at six o'clock", 1),
#  ("Coming down Ryan's Hill. I thought 'twas him. ", 1),
#  ('Over fabric half so fair.', 0),
#  ('Or else by some remoteness that defied them', 1),
#  ('Flattered I must be to have two towns fighting', 1),
#  ('With quietude, and sultriness, and slumber, ', 0),
#  ("Of scultur'd ivy and stone flowers", 0),
#  ('But were stopped by the door of a tomb -', 0),
#  ('', 1),
#  ('Only one from a farm not far away ', 1),
#  ('I want to introduce you to the people', 1),
#  ('A note unruffled', 1),
#  ("It's hell for knees unless done hell-for-leather.'", 1),
#  ("Someone's road home from work this once was,", 1),
#  ('So near to paradise all pairing ends:', 1),
#  ('He hoed a little yesterday for me: ', 1),
#  ("'As long ago as that?'", 1),
#  ('Back out of all this now too much for us,', 1),
#  ('And scurf of plants, and weary and over-heated,', 1),
#  ('Arose with a duplicate horn -', 0),
#  ('The attic was less to us than the cellar.', 1),
#  ('She does look like you. Stay the way you are. ', 1),
#  ('I often see flowers from a passing car', 1),
#  ('Where the Houri glances are', 0),
#  ('For helping them be cruel once to him.', 1),
#  ('Great monolithic knees the former town', 1),
#  ('The door; they halted helpless on the landing,', 1),
#  ('To set the voices speaking out of it, ', 1),
#  ('There shrines, and palaces, and towers', 0),
#  ("'Haven't you seen him? Strange what set you off ", 1),
#  ('And both that morning equally lay', 1),
#  ('', 1),
#  ("'Oh, if you ask me that, what will he do? ", 1),
#  ('With more of sovereignty than ancient lore ', 0),
#  ('Up from the tangle of withered weeds', 1),
#  ('That I journeyed- I journeyed down here-', 0),
#  ('Builder, in building the little house,', 1),
#  ('', 0),
#  ('In the ghoul-haunted woodland of Weir.', 0),
#  ('Was singing in it sweet and swift.', 1),
#  ('', 0),
#  ('There fell a silvery-silken veil of light, ', 0),
#  ('(Who has "the sweetest voice of all God\'s creatures,")', 0),
#  ('But now he snapped his eyes three times;', 1),
#  ('With storms- but where meanwhile', 0),
#  ('Was hot enough for the first of May,', 1),
#  ("Except, it seemed, the poetess's poems.", 1),
#  ('Hath ever told - or is it of a thought ', 0),
#  ('And suddenly, without a jerk or twitch,', 1),
#  ('Of the bells! ', 0),
#  ("What's wanted and how much and where it is. ", 1),
#  ("On some wild apple tree's young tender bark,", 1),
#  ('The blotting utterly from out high heaven', 0),
#  ('In the ultimate climes of the pole -', 0),
#  ('From thy holy throne above. ', 0),
#  ('Stood over me a resurrected tree,', 1),
#  ('In a strange city, all alone,', 0),
#  ('The ledges show lines ruled southeast-northwest,', 1),
#  ('My first impulse was to get to the knob', 1),
#  ('That had budded before the boughs were piled', 1),
#  ("What do you mean?- she's done harm to herself?' ", 1),
#  ('And full of it, that this would be the end,', 1),
#  ("'Why do you speak like that? What do you know? ", 1),
#  ('The little silver bells! ', 0),
#  ('it.', 1),
#  ('', 1),
#  ('', 1),
#  ('I saw but them- they were the world to me! ', 0),
#  ('\'Bout out!" and took the long way home', 1),
#  ('But were stopped by the door of a tomb-', 0),
#  ('He gets some sort of bakeshop meals together, ', 1),
#  ('In snow and mist', 1),
#  ('Saw only them until the moon went down. ', 0),
#  ("It ought to give a purer oracle.' ", 1),
#  ('With whose vast wheels', 1),
#  ('', 0),
#  ("Are there,' they said. 'It isn't going to rain.' ", 1),
#  ('That there always is on the papered walls,', 1),
#  ('(But not unhouse).', 1),
#  ("We have ideas yet that we haven't tried.", 1),
#  ('On the long night-time of that town,', 0),
#  ('And think that these weak lines are written by him-', 0),
#  ('To watch his woods fill up with snow.', 1),
#  ('Where were they all not twenty years ago?', 1),
#  ('When from your gems of thought I turn ', 0),
#  ('These were days when my heart was volcanic', 0),
#  ("With a swish in the grass. 'What if the others ", 1),
#  ('The truest- the most fervently devoted,', 0),
#  ('Hath palsied many years-', 0),
#  ("He knows he's kinder than the run of men. ", 1),
#  ('Come out here if you want to hear me talk. ', 1),
#  ('And in it a piano loudly playing.', 1),
#  ('SON: We never could find out whose bones they were.', 1),
#  ("'How are you, neighbour? Just the man I'm after. ", 1),
#  ('Distinct with its duplicate horn.', 0),
#  ('One level higher than the earth below,', 1),
#  ('Of all to whom thine absence is the night-', 0),
#  ('', 0),
#  ('So half-way down he fought the battle', 1),
#  ("To springs that ne'er did flow ", 0),
#  ('That the brook raises in the empty valley. ', 1),
#  ("MOTHER: We'll never let them, will we, son! We'll", 1),
#  ('Ten million silver lizards out of snow!', 1),
#  ("Don't build me a chimney upon a shelf.", 1),
#  ('However natural? Give you your books!', 1),
#  ('Until the January thaw', 1),
#  ('Nor the ghoul-haunted woodland of Weir.', 0),
#  ('(The kitchen had been dark) I had to own', 1),
#  ('These cheeks, where the worm never dies,', 0),
#  ("Wampum, I call it. Mind, we don't complain. ", 1),
#  ('And now, as the night was senescent,', 0),
#  ('Because it was grassy and wanted wear,', 1),
#  ('A passionate light - such for his spirit was fit - ', 0),
#  ('His lantern when he did his chores', 1),
#  ('', 1),
#  ('Though what good you can be, or anyone- ', 1),
#  ('That need endless talk-talk', 1),
#  ('', 0),
#  ("Not the gaily-jewell'd dead", 0),
#  ("Fell on the upturn'd faces of these roses ", 0),
#  ("I didn't relish it along at first. ", 1),
#  ("Let's trap him with an open door up attic.'", 1),
#  ('', 0),
#  ('How horrible a monody there floats ', 0),
#  ('Nor the ghoul-haunted woodland of Weir.', 0),
#  ("Drawn by their heart's passion, and that tone, ", 0),
#  ("'One ought not to be thrown into confusion ", 1),
#  ('', 1),
#  ("To break it to him. You may have the job.' ", 1),
#  ('From that which he was headed for—', 1),
#  ('The little tin box on the cupboard shelf, ', 1),
#  ("Wreathed in myrtle, my sword I'll conceal", 0),
#  ('', 0),
#  ('Sitting or standing as he chose,', 1),
#  ('', 1),
#  ('Is a world of sweets and sours;', 0),
#  ('Small good to anything growing wild,', 1),
#  ('For we knew not the month was October,', 0),
#  ("He broke my trance. Don't that make you suspicious", 1),
#  ("There's not a soul", 1),
#  ('Who alterest all things with thy peering eyes.', 0),
#  ('He said the dead had souls, but when I asked him', 1),
#  ('It was down by the dank tarn of Auber,', 0),
#  ('His neck, or thought to spare his clothes,', 1),
#  ('Some cried shame on me not to blanket him,', 1),
#  ('His journey down from field to field.', 1),
#  ("More of the salt wherewith they're to be salted. ", 1),
#  ("Like some men folk. No one's afraid of him; ", 1),
#  ('And I said - "She is warmer than Dian:', 0),
#  ('Well I know, now, this dank tarn of Auber,', 0),
#  ('My soul at least a solace hath', 0),
#  ('We made a day of it out of the world,', 1),
#  ('Is sadder than any words', 1),
#  ('And left it lying where it fell rejected.', 1),
#  ('And all our blandishments would seem defied,', 1),
#  ('That gave out, in return for the love-light, ', 0),
#  ("Bless you, it's all expense, though. Reach me down ", 1),
#  ('Then leaf subsides to leaf,', 1),
#  ('But left an open door to cool the room off', 1),
#  ('Its whirling frenzies', 1),
#  ("LO! Death hath rear'd himself a throne", 0),
#  ('She rolls through an ether of sighs -', 0),
#  ('In Truth- in Virtue- in Humanity-', 0),
#  ('There was an old, old house renewed with paint,', 1),
#  ("He'd like to take me there and show it to me.", 1),
#  ("In Wentworth from now on; and when all's said,", 1),
#  ('The unembodied essence, and no more ', 0),
#  ('A winged odour went away.', 0),
#  ('A brush had left a crooked stroke', 1),
#  ('She raised her voice against the closing door:', 1),
#  ('What wild heart-histories seemed to he enwritten ', 0),
#  ('Besides the wear of iron wagon wheels', 1),
#  ('Henceforth I hold thy flower-enameled shore,', 0),
#  ('', 0),
#  ('Lord, if I were to dream of everyone ', 1),
#  ('', 0),
#  ('Faster or slower as he chanced,', 1),
#  ('May seem as if it should have been a quarry -', 1),
#  ("This Eden day is done at two o'clock.", 1),
#  ('How silently serene a sea of pride! ', 0),
#  ('', 1),
#  ('In Warren at March Meeting for the reason', 1),
#  ("Summoning spirits isn't 'Button, button,", 1),
#  ('But only so an hour.', 1),
#  ("He won't be long in that case. You can wait. ", 1),
#  ('In the mad pride of intellectuality,', 0),
#  ('The cellar windows were banked up with sawdust', 1),
#  ('I was going to say,', 1),
#  ("'Not so but I can find it.", 1),
#  ('In the confusion of them all aglitter,', 1),
#  ("'And like it, too. It makes it all the worse.' ", 1),
#  ("What signify a donkey's cars and bottle,", 1),
#  ("'In rain?' ", 1),
#  ("To stand together on the crater's verge ", 1),
#  ("'You mean that's John's idea.' ", 1),
#  ('Was it not Fate, that, on this July midnight- ', 0),
#  ("MOTHER: And when I've done it, what good have I", 1),
#  ('A mortal melody,', 0),
#  ('With the weight of an age of snows.', 0),
#  ('Except always John-Joe,', 1),
#  ("Astarte's bediamonded crescent", 0),
#  ("The upper shelf, the tin box. That's the one. ", 1),
#  ('And love- a simple duty. ', 0),
#  ('', 1),
#  ('The sacred sun- of all who, weeping, bless thee', 0),
#  ('While from the high towers of the town', 0),
#  ('Upon his longer axis, and', 1),
#  ('To point us the path to the skies -', 0),
#  ('She revels in a region of sighs:', 0),
#  ("'Toffile, get nails.' I made him nail the door shut,", 1),
#  ...]

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
train_text, test_text, Ytrain, Ytest = train_test_split(input_text, labels)

# %%
len(Ytrain), len(Ytest)
# Out:
# (1618, 540)

# %%
train_text[:5]  #first 5 lines of training data
# Out:
# ['ye avengers of libertys wrongs',
#  'i know and it was raining ',
#  'what bones the cellar bones out of the grave',
#  'in the ultimate climes of the pole',
#  'to go west to a worse fight with the desert']

# %%
Ytrain[:5]  #first 5 labels of training data
# Out:
# [0, 1, 1, 0, 1]

# %% [markdown]
# * Create a mapping from unique word to unique integer

# %%
#mapping words to integers
word2idx = {}
current_idx = 0
for sentence, _ in (train + test):
    for word in sentence.split(" "):
        if word not in word2idx:
            word2idx[word] = current_idx
            current_idx += 1
            
V = len(word2idx)
V
# Out:
# 4523

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
idx = 1
word2idx = {'<unk>': 0}

# %%
#populate word2idx
for text in train_text:
    tokens = text.split()
    for token in tokens:
        if token not in word2idx:
            word2idx[token] = idx
            idx += 1

# %%
word2idx
# Out:
# {'<unk>': 0,
#  'ye': 1,
#  'avengers': 2,
#  'of': 3,
#  'libertys': 4,
#  'wrongs': 5,
#  'i': 6,
#  'know': 7,
#  'and': 8,
#  'it': 9,
#  'was': 10,
#  'raining': 11,
#  'what': 12,
#  'bones': 13,
#  'the': 14,
#  'cellar': 15,
#  'out': 16,
#  'grave': 17,
#  'in': 18,
#  'ultimate': 19,
#  'climes': 20,
#  'pole': 21,
#  'to': 22,
#  'go': 23,
#  'west': 24,
#  'a': 25,
#  'worse': 26,
#  'fight': 27,
#  'with': 28,
#  'desert': 29,
#  'as': 30,
#  'stardials': 31,
#  'hinted': 32,
#  'morn': 33,
#  'or': 34,
#  'like': 35,
#  'poetesss': 36,
#  'heart': 37,
#  'love': 38,
#  'elfin': 39,
#  'from': 40,
#  'green': 41,
#  'grass': 42,
#  'me': 43,
#  'creation': 44,
#  'height': 45,
#  'adventure': 46,
#  'is': 47,
#  'monarch': 48,
#  'thoughts': 49,
#  'dominion': 50,
#  'do': 51,
#  'along': 52,
#  'him': 53,
#  'stop': 54,
#  'his': 55,
#  'shouting': 56,
#  'disturbed': 57,
#  'slumbering': 58,
#  'village': 59,
#  'street': 60,
#  'kitchen': 61,
#  'had': 62,
#  'been': 63,
#  'dark': 64,
#  'own': 65,
#  'perhaps': 66,
#  'you': 67,
#  'have': 68,
#  'art': 69,
#  'mean': 70,
#  'poetess': 71,
#  'who': 72,
#  'wrote': 73,
#  'book': 74,
#  'verses': 75,
#  'but': 76,
#  'please': 77,
#  'chimney': 78,
#  'anyone': 79,
#  'else': 80,
#  'idleness': 81,
#  'dont': 82,
#  'ask': 83,
#  'joe': 84,
#  'on': 85,
#  'fathers': 86,
#  'side': 87,
#  'seems': 88,
#  'were': 89,
#  'let': 90,
#  'see': 91,
#  'call': 92,
#  'her': 93,
#  'nausicaa': 94,
#  'unafraid': 95,
#  'oh': 96,
#  'if': 97,
#  'youre': 98,
#  'going': 99,
#  'use': 100,
#  'your': 101,
#  'eyes': 102,
#  'just': 103,
#  'hear': 104,
#  'comes': 105,
#  'softly': 106,
#  'rattling': 107,
#  'down': 108,
#  'must': 109,
#  'be': 110,
#  'very': 111,
#  'still': 112,
#  'mustnt': 113,
#  'talk': 114,
#  'dimremembered': 115,
#  'story': 116,
#  'halting': 117,
#  'perplexed': 118,
#  'behind': 119,
#  'barrier': 120,
#  'too': 121,
#  'short': 122,
#  'sell': 123,
#  'give': 124,
#  'away': 125,
#  'lethean': 126,
#  'peace': 127,
#  'skies': 128,
#  'not': 129,
#  'that': 130,
#  'he': 131,
#  'hadnt': 132,
#  'gnawed': 133,
#  'hitching': 134,
#  'posts': 135,
#  'doubted': 136,
#  'should': 137,
#  'ever': 138,
#  'come': 139,
#  'back': 140,
#  'timeeaten': 141,
#  'towers': 142,
#  'tremble': 143,
#  'brook': 144,
#  'water': 145,
#  'house': 146,
#  'so': 147,
#  'now': 148,
#  'theyve': 149,
#  'dragged': 150,
#  'through': 151,
#  'law': 152,
#  'courts': 153,
#  'once': 154,
#  'lift': 155,
#  'themselves': 156,
#  'up': 157,
#  'off': 158,
#  'ground': 159,
#  'seek': 160,
#  'for': 161,
#  'treasure': 162,
#  'jewelled': 163,
#  'one': 164,
#  'self': 165,
#  'station': 166,
#  'wild': 167,
#  'geese': 168,
#  'lake': 169,
#  'before': 170,
#  'storm': 171,
#  'stopped': 172,
#  'by': 173,
#  'door': 174,
#  'tomb': 175,
#  'their': 176,
#  'strength': 177,
#  'subdued': 178,
#  'road': 179,
#  'there': 180,
#  'youll': 181,
#  'guide': 182,
#  'direct': 183,
#  'whats': 184,
#  'wanted': 185,
#  'how': 186,
#  'much': 187,
#  'where': 188,
#  'remembered': 189,
#  'dank': 190,
#  'tarn': 191,
#  'auber': 192,
#  'hes': 193,
#  'nothing': 194,
#  'listen': 195,
#  'when': 196,
#  'lean': 197,
#  'this': 198,
#  'speculation': 199,
#  'they': 200,
#  'plunged': 201,
#  'tyrant': 202,
#  'steel': 203,
#  'night': 204,
#  'all': 205,
#  'nights': 206,
#  'year': 207,
#  'guess': 208,
#  'youd': 209,
#  'find': 210,
#  'fountain': 211,
#  'empty': 212,
#  'hasten': 213,
#  'us': 214,
#  'linger': 215,
#  'plain': 216,
#  'statement': 217,
#  'relationship': 218,
#  'tears': 219,
#  'makes': 220,
#  'someone': 221,
#  'literally': 222,
#  'run': 223,
#  'earth': 224,
#  'she': 225,
#  'housework': 226,
#  'besides': 227,
#  'which': 228,
#  'sits': 229,
#  'sings': 230,
#  'gone': 231,
#  'yours': 232,
#  'our': 233,
#  'business': 234,
#  'firsts': 235,
#  'attic': 236,
#  'books': 237,
#  'soulandbody': 238,
#  'scars': 239,
#  'expecting': 240,
#  'john': 241,
#  'pity': 242,
#  'estelle': 243,
#  'fiftyfive': 244,
#  'day': 245,
#  'will': 246,
#  'leave': 247,
#  'way': 248,
#  'lost': 249,
#  'enough': 250,
#  'yourself': 251,
#  'weight': 252,
#  'an': 253,
#  'age': 254,
#  'snows': 255,
#  'small': 256,
#  'my': 257,
#  'pocket': 258,
#  'incredulous': 259,
#  'bad': 260,
#  'luck': 261,
#  'some': 262,
#  'extravagance': 263,
#  'young': 264,
#  'legended': 265,
#  'truest': 266,
#  'most': 267,
#  'fervently': 268,
#  'devoted': 269,
#  'follow': 270,
#  'lead': 271,
#  'years': 272,
#  'describing': 273,
#  'rings': 274,
#  'lantern': 275,
#  'light': 276,
#  'why': 277,
#  'speak': 278,
#  'we': 279,
#  'friends': 280,
#  'am': 281,
#  'thy': 282,
#  'holy': 283,
#  'throne': 284,
#  'above': 285,
#  'governor': 286,
#  'proclaimed': 287,
#  'time': 288,
#  'tempted': 289,
#  'gloom': 290,
#  'curl': 291,
#  'little': 292,
#  'finger': 293,
#  'round': 294,
#  'two': 295,
#  'weeks': 296,
#  'since': 297,
#  'need': 298,
#  'endless': 299,
#  'talktalk': 300,
#  'while': 301,
#  'bolder': 302,
#  'note': 303,
#  'than': 304,
#  'might': 305,
#  'swell': 306,
#  'israfel': 307,
#  'gained': 308,
#  'no': 309,
#  'foothold': 310,
#  'pursued': 311,
#  'between': 312,
#  'north': 313,
#  'pole—': 314,
#  'its': 315,
#  'fervor': 316,
#  'oer': 317,
#  'power': 318,
#  'drag': 319,
#  'man': 320,
#  'sweet': 321,
#  'flowers': 322,
#  'ere': 323,
#  'long': 324,
#  'saw': 325,
#  'strange': 326,
#  'position': 327,
#  'hands—': 328,
#  'knew': 329,
#  'them': 330,
#  'good': 331,
#  'reason': 332,
#  'farmers': 333,
#  'around': 334,
#  'twice': 335,
#  'well': 336,
#  'arthur': 337,
#  'amy': 338,
#  'learned': 339,
#  'thats': 340,
#  'odorous': 341,
#  'souls': 342,
#  'ecstatic': 343,
#  'death': 344,
#  'whos': 345,
#  'got': 346,
#  'button': 347,
#  'would': 348,
#  'tried': 349,
#  'improve': 350,
#  'sailing': 351,
#  'tile': 352,
#  'hall': 353,
#  'only': 354,
#  'finished': 355,
#  'bedroom': 356,
#  'girl': 357,
#  'halted': 358,
#  'headless': 359,
#  'aftermath': 360,
#  'yet': 361,
#  'object': 362,
#  'hid': 363,
#  'said': 364,
#  'written': 365,
#  'sister': 366,
#  'vulture': 367,
#  'whose': 368,
#  'wings': 369,
#  'are': 370,
#  'dull': 371,
#  'realities': 372,
#  'dim': 373,
#  'couldnt': 374,
#  'climb': 375,
#  'slippery': 376,
#  'slope': 377,
#  'didnt': 378,
#  'relish': 379,
#  'at': 380,
#  'first': 381,
#  'high': 382,
#  'tone': 383,
#  'spirit': 384,
#  'hath': 385,
#  'striven': 386,
#  'softmurmured': 387,
#  'words': 388,
#  'fulfilled': 389,
#  'fancied': 390,
#  'looked': 391,
#  'six': 392,
#  'oclock': 393,
#  'content': 394,
#  'budinspecting': 395,
#  'presume': 396,
#  'marked': 397,
#  'then': 398,
#  'cane': 399,
#  'knock': 400,
#  'struck': 401,
#  'hard': 402,
#  'bottom': 403,
#  'filled': 404,
#  'purse': 405,
#  'say': 406,
#  'buds': 407,
#  'leaf': 408,
#  'bloom': 409,
#  'though': 410,
#  'slight': 411,
#  'demand': 412,
#  'felt': 413,
#  'tug': 414,
#  'worst': 415,
#  'best': 416,
#  'stood': 417,
#  'over': 418,
#  'resurrected': 419,
#  'tree': 420,
#  'hopes': 421,
#  'thee': 422,
#  'thine': 423,
#  'im': 424,
#  'waiting': 425,
#  'gives': 426,
#  'harness': 427,
#  'bells': 428,
#  'shake': 429,
#  'beside': 430,
#  'wall': 431,
#  'stands': 432,
#  'bare': 433,
#  'angel': 434,
#  'trod': 435,
#  'hourly': 436,
#  'hope': 437,
#  'life': 438,
#  'ah': 439,
#  'seen': 440,
#  'stone': 441,
#  'baptismal': 442,
#  'font': 443,
#  'science': 444,
#  'true': 445,
#  'daughter': 446,
#  'old': 447,
#  'thou': 448,
#  'luminary': 449,
#  'clock': 450,
#  'against': 451,
#  'sky': 452,
#  'even': 453,
#  'seraph': 454,
#  'harper': 455,
#  'libation': 456,
#  'tyrannys': 457,
#  'blood': 458,
#  'needed': 459,
#  'whom': 460,
#  'sun': 461,
#  'dew': 462,
#  'half': 463,
#  'outdoor': 464,
#  'work': 465,
#  'passing': 466,
#  'uttered': 467,
#  'alone': 468,
#  'level': 469,
#  'higher': 470,
#  'below': 471,
#  'about': 472,
#  'sitting': 473,
#  'somewhere': 474,
#  'ages': 475,
#  'hence': 476,
#  'likely': 477,
#  'regard': 478,
#  'sacred': 479,
#  'streams': 480,
#  'turrets': 481,
#  'silently': 482,
#  'want': 483,
#  'spend': 484,
#  'outdoors': 485,
#  'impulse': 486,
#  'care': 487,
#  'town': 488,
#  'take': 489,
#  'replied': 490,
#  'dreaming': 491,
#  'albeit': 492,
#  'soared': 493,
#  'undaunted': 494,
#  'wing': 495,
#  'dignity': 496,
#  'mien': 497,
#  'daylight': 498,
#  'beauty': 499,
#  'birth': 500,
#  'waves': 501,
#  'remember': 502,
#  'cared': 503,
#  'mother': 504,
#  'ive': 505,
#  'done': 506,
#  'money': 507,
#  'goes': 508,
#  'fast': 509,
#  'spoke': 510,
#  'suddenly': 511,
#  'without': 512,
#  'jerk': 513,
#  'twitch': 514,
#  'lying': 515,
#  'die': 516,
#  'arisen': 517,
#  'strapping': 518,
#  'twenty': 519,
#  'giddy': 520,
#  'stars': 521,
#  'legends': 522,
#  'tell': 523,
#  'doesnt': 524,
#  'seem': 525,
#  'near': 526,
#  'paradise': 527,
#  'can': 528,
#  'look': 529,
#  'here': 530,
#  'rain': 531,
#  'heartstrings': 532,
#  'lute': 533,
#  'ill': 534,
#  'show': 535,
#  'few': 536,
#  'peckerfretted': 537,
#  'apple': 538,
#  'trees': 539,
#  'neednt': 540,
#  'think': 541,
#  'get': 542,
#  'skulls': 543,
#  'rogers': 544,
#  'rangers': 545,
#  'throats': 546,
#  'exist': 547,
#  'roared': 548,
#  'hidden': 549,
#  'johns': 550,
#  'being': 551,
#  'safe': 552,
#  'stay': 553,
#  'full': 554,
#  'chases': 555,
#  'lowes': 556,
#  'baileys': 557,
#  't': 558,
#  'awake': 559,
#  'tis': 560,
#  'symbol': 561,
#  'token': 562,
#  'truly': 563,
#  'men': 564,
#  'noted': 565,
#  'hands': 566,
#  'gold': 567,
#  'conies': 568,
#  'romp': 569,
#  'more': 570,
#  'brought': 571,
#  'into': 572,
#  'name': 573,
#  'turn': 574,
#  'doll': 575,
#  'pasture': 576,
#  'rig': 577,
#  'hurry': 578,
#  'hell': 579,
#  'unhitch': 580,
#  'folk': 581,
#  'held': 582,
#  'each': 583,
#  'other': 584,
#  'crew': 585,
#  'left': 586,
#  'failed': 587,
#  'trade': 588,
#  'mark': 589,
#  'himself': 590,
#  'wont': 591,
#  'imagine': 592,
#  'son': 593,
#  'told': 594,
#  'timber': 595,
#  'headboard': 596,
#  'mothers': 597,
#  'bed': 598,
#  'pushed': 599,
#  'ministers': 600,
#  'slave': 601,
#  'believe': 602,
#  'fraught': 603,
#  'hate': 604,
#  'place': 605,
#  'settled': 606,
#  'wrong': 607,
#  'prove': 608,
#  'put': 609,
#  'foot': 610,
#  'avail': 611,
#  'communing': 612,
#  'angels': 613,
#  'upon': 614,
#  'children': 615,
#  'bathe': 616,
#  'crystalline': 617,
#  'whether': 618,
#  'came': 619,
#  'cellarstairs': 620,
#  'owe': 621,
#  'gratitude': 622,
#  'help': 623,
#  'beadwork': 624,
#  'spare': 625,
#  'any': 626,
#  'trouble': 627,
#  'double': 628,
#  'troubles': 629,
#  'deeptoned': 630,
#  'feel': 631,
#  'easier': 632,
#  'could': 633,
#  'starlight': 634,
#  'pall': 635,
#  'takes': 636,
#  'summer': 637,
#  'muffled': 638,
#  'kind': 639,
#  'eternal': 640,
#  'rest': 641,
#  'ready': 642,
#  'thought': 643,
#  'almost': 644,
#  'anything': 645,
#  'never': 646,
#  'late': 647,
#  'wouldnt': 648,
#  'luminous': 649,
#  'shall': 650,
#  'dawn': 651,
#  'desolate': 652,
#  'hour': 653,
#  'winter': 654,
#  'sometimes': 655,
#  'something': 656,
#  'seemed': 657,
#  'yield': 658,
#  'watched': 659,
#  'forty': 660,
#  'holes': 661,
#  'disappeared': 662,
#  'ended': 663,
#  'far': 664,
#  'stock': 665,
#  'counts': 666,
#  'ideals': 667,
#  'listened': 668,
#  'among': 669,
#  'sounds': 670,
#  'planets': 671,
#  'trance': 672,
#  'withdrawing': 673,
#  'myself': 674,
#  'upstairs': 675,
#  'neighbour': 676,
#  'after': 677,
#  'porphyrogene': 678,
#  'untidy': 679,
#  'sing': 680,
#  'blushes': 681,
#  'dust': 682,
#  'followed': 683,
#  'mile': 684,
#  'many': 685,
#  'visions': 686,
#  'maiden': 687,
#  'sound': 688,
#  'silence': 689,
#  'introduce': 690,
#  'people': 691,
#  'flight': 692,
#  'woods': 693,
#  'winds': 694,
#  'mountains': 695,
#  'intense': 696,
#  'pauses': 697,
#  'heaven': 698,
#  'evening': 699,
#  'walk': 700,
#  'origin': 701,
#  'family': 702,
#  'rolls': 703,
#  'ether': 704,
#  'sighs': 705,
#  'within': 706,
#  'ago': 707,
#  'married': 708,
#  'leaves': 709,
#  'withering': 710,
#  'sere': 711,
#  'greatly': 712,
#  'afraid': 713,
#  'fire': 714,
#  'fist': 715,
#  'buried': 716,
#  'bushy': 717,
#  'hide': 718,
#  'windows': 719,
#  'ought': 720,
#  'protection': 721,
#  'realms': 722,
#  'boreal': 723,
#  'steeple': 724,
#  'tower': 725,
#  'resemble': 726,
#  'ours': 727,
#  'alias': 728,
#  'daring': 729,
#  'ambition': 730,
#  'deep': 731,
#  'conquered': 732,
#  'scruples': 733,
#  'thinks': 734,
#  'wind': 735,
#  'clad': 736,
#  'white': 737,
#  'violet': 738,
#  'bank': 739,
#  'wants': 740,
#  'news': 741,
#  'dreadful': 742,
#  'fool': 743,
#  'tempt': 744,
#  'such': 745,
#  'yes': 746,
#  'oho': 747,
#  'always': 748,
#  'papered': 749,
#  'walls': 750,
#  'eden': 751,
#  'bland': 752,
#  'repose': 753,
#  'staying': 754,
#  'destination': 755,
#  'destinys': 756,
#  'enchanted': 757,
#  'faroff': 758,
#  'isle': 759,
#  'sit': 760,
#  'hold': 761,
#  'hed': 762,
#  'tall': 763,
#  'maybe': 764,
#  'isnt': 765,
#  'cut': 766,
#  'wasps': 767,
#  'went': 768,
#  'missing': 769,
#  'bullets': 770,
#  'killed': 771,
#  'instead': 772,
#  'burned': 773,
#  'stake': 774,
#  'god': 775,
#  'made': 776,
#  'gather': 777,
#  'wet': 778,
#  'snow': 779,
#  'berries': 780,
#  'owing': 781,
#  'lyre': 782,
#  'haunt': 783,
#  'panther': 784,
#  'mountain': 785,
#  'shouldnt': 786,
#  'judged': 787,
#  'crystal': 788,
#  'chill': 789,
#  'smart': 790,
#  'pair': 791,
#  'pumps': 792,
#  'beading': 793,
#  'fête': 794,
#  'today': 795,
#  'aint': 796,
#  'kiting': 797,
#  'heat': 798,
#  'slowly': 799,
#  'hazes': 800,
#  'shudder': 801,
#  'notes': 802,
#  'hens': 803,
#  'gets': 804,
#  'possessed': 805,
#  'keep': 806,
#  'accounts': 807,
#  'future': 808,
#  'radiant': 809,
#  'shine': 810,
#  'lupine': 811,
#  'living': 812,
#  'sand': 813,
#  'drouth': 814,
#  'creases': 815,
#  'common': 816,
#  'doth': 817,
#  'lie': 818,
#  'henry': 819,
#  'hudsons': 820,
#  'sends': 821,
#  'signify': 822,
#  'donkeys': 823,
#  'cars': 824,
#  'bottle': 825,
#  'whod': 826,
#  'marry': 827,
#  'straight': 828,
#  'mess': 829,
#  'tangle': 830,
#  'withered': 831,
#  'weeds': 832,
#  'hole': 833,
#  'byroad': 834,
#  'theres': 835,
#  'childrens': 836,
#  'makebelieve': 837,
#  'ten': 838,
#  'million': 839,
#  'silver': 840,
#  'lizards': 841,
#  'shelfs': 842,
#  'vase': 843,
#  'picture': 844,
#  'knob': 845,
#  'having': 846,
#  'better': 847,
#  'claim': 848,
#  'present': 849,
#  'pathway': 850,
#  'part': 851,
#  'entombed': 852,
#  'burning': 853,
#  'measures': 854,
#  'suit': 855,
#  'writer': 856,
#  'these': 857,
#  'lines': 858,
#  'built': 859,
#  'rare': 860,
#  'did': 861,
#  'blow': 862,
#  'carry—if': 863,
#  'save': 864,
#  'paused': 865,
#  'found': 866,
#  'id': 867,
#  'names': 868,
#  'manner': 869,
#  'farmer': 870,
#  'blaming': 871,
#  'pens': 872,
#  'thrills': 873,
#  'spread': 874,
#  'pinion': 875,
#  'heard': 876,
#  'throve': 877,
#  'has': 878,
#  'difference': 879,
#  'asked': 880,
#  'tonight': 881,
#  'front': 882,
#  'hitched': 883,
#  'card': 884,
#  'things': 885,
#  'lonely': 886,
#  'rose': 887,
#  'used': 888,
#  'live': 889,
#  'robinsons': 890,
#  'swollen': 891,
#  'tight': 892,
#  'under': 893,
#  'roar': 894,
#  'often': 895,
#  'forget': 896,
#  'lone': 897,
#  'spoiled': 898,
#  'began': 899,
#  'uncertain': 900,
#  'shes': 901,
#  'harm': 902,
#  'herself': 903,
#  'hot': 904,
#  'may': 905,
#  'nor': 906,
#  'grannys': 907,
#  'surely': 908,
#  'soul': 909,
#  'strangely': 910,
#  'wish': 911,
#  'havent': 912,
#  'farm': 913,
#  'according': 914,
#  'feared': 915,
#  'risk': 916,
#  'gailyjewelld': 917,
#  'dead': 918,
#  'hand': 919,
#  'buttonbox': 920,
#  'stampede': 921,
#  'descended': 922,
#  'particular': 923,
#  'journeyed': 924,
#  'fervid': 925,
#  'flickering': 926,
#  'torch': 927,
#  'lit': 928,
#  'loveless': 929,
#  'birds': 930,
#  'flock': 931,
#  'everyone': 932,
#  'miles': 933,
#  'nova': 934,
#  'warn': 935,
#  'lightning': 936,
#  'scribble': 937,
#  'goodlooking': 938,
#  'picked': 939,
#  'fresh': 940,
#  'breath': 941,
#  'air': 942,
#  'died': 943,
#  'cold': 944,
#  'gnaw': 945,
#  'fences': 946,
#  'talkedof': 947,
#  'mystery': 948,
#  'helpless': 949,
#  'dared': 950,
#  'stir': 951,
#  'unless': 952,
#  'tiptoe': 953,
#  'alas': 954,
#  'magical': 955,
#  'sad': 956,
#  'glimpses': 957,
#  'those': 958,
#  'passed': 959,
#  'watchman': 960,
#  'beat': 961,
#  'inscription': 962,
#  'garden': 963,
#  'right': 964,
#  'uplifted': 965,
#  'surest': 966,
#  'thing': 967,
#  'riders': 968,
#  'feet': 969,
#  'smiled': 970,
#  'parterre': 971,
#  'staid': 972,
#  'shelter': 973,
#  'bowed': 974,
#  'grace': 975,
#  'natural': 976,
#  'nose': 977,
#  'same': 978,
#  'sos': 979,
#  'chin': 980,
#  'tended': 981,
#  'bless': 982,
#  'grandsir': 983,
#  'stark': 984,
#  'granny': 985,
#  'closes': 986,
#  'path': 987,
#  'moon': 988,
#  'witch': 989,
#  'i—': 990,
#  'because': 991,
#  'grassy': 992,
#  'wear': 993,
#  'past': 994,
#  'strangeness': 995,
#  'wonder': 996,
#  'melancholy': 997,
#  'waters': 998,
#  'turned': 999,
#  ...}

# %%
len(word2idx)
# Out:
# 2512

# %% [markdown]
# * Loop through data, tokenize each line(string split should suffice)

# %%
#tokenize each line
import numpy as np
X_train = np.empty(len(train), dtype = object)
Y_train = np.empty(len(train), dtype = object)
for i in range(len(train)):
    X_train[i] = train[i][0].split(" ")
    Y_train[i] = train[i][1]
    
X_test = np.empty(len(test), dtype = object)    
Y_test = np.empty(len(test), dtype = object)
for i in range(len(test)):  
    X_test[i] = test[i][0].split(" ")
    Y_test[i] = test[i][1]

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
#integer formar
train_text_int = []
test_text_int = []

for text in train_text:
    tokens = text.split()
    line_as_int = [word2idx[token] for token in tokens]
    train_text_int.append(line_as_int)
    
for text in test_text:
    tokens = text.split()
    line_as_int = [word2idx.get(token, 0) for token in tokens]
    test_text_int.append(line_as_int)

# %%
train_text_int[100:105]
# Out:
# [[131, 374, 375, 130, 376, 377],
#  [6, 378, 379, 9, 52, 380, 381],
#  [130, 382, 383, 3, 14, 384, 228, 385, 386],
#  [380, 14, 387, 388, 130, 89, 389],
#  [6, 390, 196, 6, 391, 380, 392, 393]]

# %% [markdown]
# * Assign each unique word a unique integer index ("mapping" == "dict)

# %% [markdown]
# * Create a special index for unknown words (words in the test set but not in the training set)

# %%
#unknown words
unknown_words = set()
for sentence, _ in (train + test):
    for word in sentence.split(" "):
        if word not in word2idx:
            unknown_words.add(word)

unknown_words
# Out:
# {'',
#  'sap',
#  "'Company?'",
#  'life?',
#  'clear',
#  'remained;',
#  '(Who',
#  'spectre.',
#  "'How",
#  'snows.',
#  'Somewhere',
#  'purport',
#  'yield,',
#  'broken.',
#  "safely.'",
#  'glances',
#  'Calypso."',
#  'Flattered',
#  'important,',
#  'Lowes,',
#  'What',
#  'ledges',
#  'Fell',
#  'skies,',
#  'lady,',
#  'Uttered',
#  'astride,',
#  'vista,',
#  'sere,',
#  'birth:',
#  'cruel',
#  'round,',
#  'track.',
#  "He's",
#  "Ulalume!'",
#  'forever,',
#  'thinking.',
#  "'You've",
#  'loved?-',
#  'throne;',
#  'decently',
#  'mistake.',
#  'technical.-',
#  'enkindle-',
#  'slight,',
#  'worse.',
#  'muffled.',
#  'dormant',
#  'walk.',
#  'midnight-',
#  'Mars',
#  'Winds',
#  "stand.'",
#  'bliss!',
#  'wilder,',
#  'legs.',
#  'October',
#  'Time',
#  'love,',
#  'Among',
#  'farming',
#  'As',
#  'sport.',
#  "Granny's,",
#  'Smith,',
#  'awful!',
#  'ridiculous.',
#  'attic.',
#  'dim-remembered',
#  'orchard.',
#  'fervour',
#  'dust.',
#  'terminates-',
#  'lately?',
#  'bare,',
#  'Until',
#  '(With',
#  'outsiders.',
#  'respect',
#  'twelvemonth',
#  'hands,',
#  "piano's",
#  'Faith-',
#  'avalanches,',
#  'clothes,',
#  '"Ulalume',
#  'light.',
#  'Pole.',
#  'plane',
#  'her,',
#  "one,'",
#  'Alias',
#  "'Toffile,",
#  'tongue:',
#  'along,',
#  'Tried',
#  "'I'm",
#  "'Take",
#  'talk,',
#  'replied-',
#  'feet,',
#  'grass.',
#  'vines-',
#  '(And',
#  'one,',
#  'One,',
#  'North',
#  "worse.'",
#  "'Ulalume-",
#  'settle',
#  "to-day,'",
#  '(I',
#  'try.',
#  'godliness-',
#  'Do',
#  'ashes,',
#  'courting',
#  'words!)',
#  "wasn't",
#  'sorrow!',
#  'close.',
#  'temples',
#  'Seven',
#  'mouth-',
#  'Mark',
#  'color',
#  'flatness',
#  'through.',
#  'pocket.',
#  'Gave',
#  'Albeit',
#  'Davis',
#  'Heman',
#  'She',
#  'Future',
#  'sun!',
#  'parterre,',
#  'gun',
#  "can't.'",
#  'Granny,',
#  'heart-strings',
#  'bobbed,',
#  'long-forgotten',
#  "'Aren't",
#  'Another',
#  'cedar.',
#  'reclining;',
#  "shelf's",
#  "It's",
#  'unafraid,',
#  'door,',
#  'song),',
#  "God's",
#  'wealth,',
#  'door:',
#  'scene',
#  'Hourly',
#  'Levante!"',
#  'This',
#  'Inscription',
#  'Lion',
#  'surely.',
#  'furs',
#  'mother,',
#  "go?'",
#  "books.'",
#  'short,',
#  'Wild',
#  'common-',
#  'sovereignty',
#  'outdoors.',
#  'yard,',
#  'year;',
#  'reason.',
#  "idea.'",
#  "first's",
#  'Choked',
#  'though;',
#  'may.',
#  'this.',
#  'far.',
#  'graves',
#  'spheres!',
#  'awake!',
#  'undergrowth;',
#  "didn't",
#  'wave',
#  "favour.'",
#  'morning-',
#  "'Huh,",
#  'London.',
#  'flowers.',
#  'faintest',
#  'white,',
#  "heard!'",
#  'lettered,',
#  'Struck',
#  'about.',
#  "destiny's",
#  "she'll",
#  "'Tell",
#  'wait.',
#  'bewitched',
#  'Stark,',
#  'Streams',
#  'See,',
#  'coast;',
#  'think,',
#  'However',
#  'lots,',
#  'not,',
#  "won't",
#  'be,',
#  'same,',
#  'chimney:',
#  'I,',
#  'ice.',
#  'Halting',
#  'Enough',
#  'wrongs!',
#  'champions',
#  "heart's",
#  'library-',
#  'While',
#  "me.'",
#  'outrage?',
#  'are.',
#  'stain',
#  'found.',
#  "upturn'd",
#  'over-heated,',
#  "tree's",
#  'Legitimately.',
#  'must,',
#  'leaves,',
#  'WALKED',
#  'Into',
#  'girl;',
#  'pole-',
#  'It',
#  'myrtle,',
#  "Roger's",
#  'button-box-',
#  'novelty,',
#  'done?',
#  'serial',
#  'misted.',
#  'that-',
#  'few:',
#  'woe,',
#  'eyes-',
#  'path.',
#  "'Under",
#  'rests',
#  'sky,',
#  'tell),',
#  'many,',
#  'Stark',
#  'knees,',
#  'MOTHER:',
#  'realities?',
#  'emotion,',
#  "'Nor",
#  'talking.',
#  "upturn'd-",
#  'oh!',
#  'Present',
#  'outspread',
#  'thunder-cloud;',
#  'desire',
#  'harp-string',
#  'say.',
#  'spells',
#  'airs.',
#  'strange,',
#  'to!',
#  'said.',
#  'deserted.',
#  'buy-',
#  'friends.',
#  "Here's",
#  'fair.',
#  "sunshine.'",
#  'this:',
#  "So's",
#  'glad.',
#  'aside,',
#  'timber-',
#  'weather,',
#  'chanced,',
#  'No',
#  'band-music',
#  '--but',
#  "they'd",
#  'deathless',
#  'town.',
#  'bottle,',
#  'size,',
#  "I'm",
#  'ghoul-haunted',
#  'fond,',
#  'care-',
#  'Each',
#  'Sometimes',
#  'Said-',
#  "sun's",
#  'money.',
#  'Fair',
#  'tended:',
#  'French',
#  'ourselves',
#  'motto',
#  'Nor',
#  'aglitter,',
#  'Titanic,',
#  "own?'",
#  'garden-gate,',
#  "'No",
#  "must.'",
#  'either.',
#  'Venuses,',
#  "T'",
#  'blood.',
#  'Perfumed',
#  'harder',
#  'hung',
#  '"dew',
#  'tail,',
#  'seen.',
#  "'What",
#  'mistrust:-',
#  'left,',
#  'sultriness,',
#  'roam',
#  "angel's.",
#  'instep',
#  'another,',
#  'well.',
#  '(Oh,',
#  '"You',
#  'cliff',
#  'in?',
#  'boy,',
#  'See',
#  'West',
#  'broken,',
#  'listen,',
#  "gaily-jewell'd",
#  'repose.',
#  "hear.'",
#  'praise,',
#  'ancient',
#  'diviner',
#  'mark.',
#  'done.',
#  'Mind,',
#  'bells,',
#  'windowsill,',
#  "know.'",
#  'into?',
#  'Beyond',
#  'truth,',
#  'object)',
#  'downstairs.',
#  'though.',
#  'nation',
#  'shouted,',
#  'Perhaps,',
#  'Birch',
#  'tree,',
#  'lie-',
#  "Thought's",
#  'him?',
#  'Describing',
#  "oracle.'",
#  'pine,',
#  'walk-',
#  'long!',
#  '>From',
#  'gigantically',
#  'lonesome',
#  "you.'",
#  "isn't.",
#  "Tyranny's",
#  'Ye',
#  'dust-',
#  'Beauty',
#  'more-',
#  'Gnaws',
#  'salted.',
#  'Hast',
#  'preyest',
#  'other,',
#  "'In",
#  'sister,',
#  'sailed.',
#  'sprout-lands',
#  'riding',
#  'do:',
#  'bet',
#  'cider,',
#  'talk.',
#  'double-doors',
#  'visions-',
#  "unhitch.'",
#  'side,',
#  'Lion,',
#  'violin;',
#  'Unless',
#  'chalky',
#  "what's",
#  "ain't",
#  'Grandsir',
#  'Ten',
#  'ago,',
#  'over-',
#  'golden,',
#  'nowadays',
#  'cards,',
#  'Chicamoztoc,',
#  'half-past',
#  "that's",
#  'cellar.',
#  'strengths,',
#  'her?',
#  'said,',
#  'good.',
#  'eye,',
#  'And,',
#  'reply:',
#  'before.',
#  'Sybilic',
#  'sight,',
#  "give.'",
#  'Behind',
#  "fountain.'",
#  'sigmas',
#  'Give',
#  'always.',
#  'gone?',
#  'Have',
#  'thither,',
#  'Gazing,',
#  "'Hesperides'",
#  'Imbued',
#  'complain:',
#  'cut-',
#  'again—',
#  "attic.'",
#  'splendor',
#  'infant',
#  'fallen',
#  'courage',
#  'quietude,',
#  'flood,',
#  'neighbour?',
#  '(Ah,',
#  'path,',
#  "witch's",
#  'glass:',
#  'not.',
#  'dwelt,',
#  'everything.',
#  'dunnow!',
#  'Pleiads,',
#  "Who's",
#  'Besides',
#  "'going",
#  "'Cross",
#  'meridian',
#  'gloom!',
#  'John.',
#  'Builder,',
#  'thou:',
#  'palsied',
#  'ah,',
#  "vines?'",
#  'Marshall,',
#  'agreed',
#  "then?'",
#  'once,',
#  'mile,',
#  'a-known',
#  'shutter,',
#  'Granny',
#  'Hill.',
#  'entranced,',
#  'keep,',
#  'foe,',
#  'Well,',
#  'Humanity-',
#  'braced',
#  "time?'",
#  'O!',
#  'Round',
#  "won't,",
#  'Tempt',
#  'tenanted,',
#  'stirred:',
#  'guide,',
#  "'Estelle's",
#  'chalk-pile',
#  "'Shut",
#  'vacuum',
#  'even,',
#  'eyes.)',
#  'bad,',
#  'up.-',
#  'look,',
#  'hall.',
#  'had,',
#  'day,',
#  "ain't'),",
#  'Banners',
#  'stamped',
#  'About',
#  "she's",
#  'since;',
#  'said-',
#  'sobbed,',
#  'mine,',
#  'minute:',
#  "again?'",
#  'frenzies',
#  'lenses.',
#  'year-',
#  'yet.',
#  'cried-',
#  "Estelle's",
#  'name,',
#  'you-',
#  'vapors,',
#  "sure's",
#  'nature.',
#  'With',
#  'trouble?',
#  'hasten!',
#  "'He'd",
#  'now.',
#  'cock-',
#  "Tho'",
#  "am.'",
#  'Hamadryad',
#  'defied,',
#  'Smoke',
#  'Shall',
#  'everywhere!—',
#  'evening,',
#  'raining.',
#  'mother?',
#  'Quenching',
#  'scuttled',
#  'by,',
#  'allowance,',
#  'plants,',
#  'repented,',
#  'Stark.',
#  "'I",
#  'Forgive',
#  'face;',
#  'hew',
#  'favor',
#  "!'",
#  'cheering',
#  'nailed.',
#  'entablatures',
#  'gloom-',
#  'enchanted!)',
#  'mosses',
#  'Vast',
#  'Best',
#  'paths,',
#  'night-',
#  "there,'",
#  "you,'",
#  'judgment.',
#  'essence,',
#  'loudly',
#  'isle!',
#  'Caves',
#  'riddle',
#  'Cold',
#  'get.',
#  'Weir-',
#  "'No,",
#  "it's",
#  'look-',
#  "'If",
#  "'Yes,",
#  'what-',
#  'Mebbe',
#  'noise',
#  'comfort.',
#  'Wall',
#  "herself?'",
#  'heavens,',
#  'strove',
#  'wilds-',
#  'Serenest',
#  'youthful',
#  'enough,',
#  "'Too",
#  'vigor.',
#  'Toffile.',
#  'Son',
#  'Disturbed',
#  "time's",
#  'live,',
#  'stir,',
#  'journeyed-',
#  'Sweet',
#  'Hope),',
#  "You've",
#  'Stood',
#  'Maintained',
#  'wisest!',
#  'ordeal',
#  'then,',
#  "you're",
#  'birth.',
#  "there.'",
#  'so-',
#  'spray;',
#  'hide,--',
#  'bent',
#  "you'd",
#  "all!'",
#  "protection.'",
#  'Tottering',
#  'Meeting',
#  'intelligence!',
#  'off,',
#  'sincere',
#  "'Two",
#  'place,',
#  'alas,',
#  'thrill',
#  'most-',
#  'Hope',
#  'Endless',
#  "'Oh,",
#  'Comes',
#  'mother-',
#  'coasting',
#  "three?'",
#  "'Better",
#  'feather-hammer',
#  '"Where',
#  "go.'",
#  'spot.',
#  'turret-tops',
#  'like:',
#  'mistrust-',
#  'Between',
#  'Starks,',
#  'whined.',
#  'skeleton.',
#  'by-road',
#  'fabric',
#  'kind,',
#  'family.',
#  'grass?',
#  "'Let",
#  'floor,',
#  'Where',
#  'waterfall.',
#  "daylight.'",
#  'romp,',
#  'Sought',
#  'Sioux',
#  "grave.'",
#  'times;',
#  'heard?',
#  "married,'",
#  'help;',
#  'worry',
#  'fortune.',
#  '"Let',
#  'Because',
#  'Soul-',
#  'subdued,',
#  'thee-',
#  'light!"',
#  "I've",
#  'reascend.',
#  'New',
#  'seated,',
#  'Should',
#  'see-',
#  'boss.',
#  "be.'",
#  'star.',
#  "her?'",
#  'passport',
#  'art!',
#  'lizard.',
#  'Ah,',
#  'merry',
#  'Arctic',
#  "'Hadn't",
#  "me?'",
#  'cheeks,',
#  'Cross-legged,',
#  'Moosilauke,',
#  'hand.',
#  '2o3',
#  'traveler,',
#  'Kinsman,',
#  'shoulders,',
#  'do,',
#  'river,',
#  'tote-road.',
#  'farmhouse',
#  'Estelle?',
#  'perhaps.',
#  'Something',
#  "others'",
#  'Now',
#  "let's",
#  'strong',
#  'Will',
#  'floors.',
#  'lo!',
#  'interlock.',
#  'night.',
#  'legs',
#  'year!)',
#  'valleys,',
#  'handrail',
#  'foothold,',
#  'beaming',
#  'skull',
#  "Hell,'",
#  'furniture.',
#  'But,',
#  'luck.',
#  'heat!',
#  'Looked',
#  'noon,',
#  'Death',
#  'life-',
#  'Transfixed',
#  "light!'",
#  'words,',
#  'truth.',
#  'Radiant',
#  "'Just",
#  'grain.',
#  'bullets.',
#  "'Strangely,",
#  'Father',
#  'Half',
#  "'Excuse",
#  "'It's",
#  'why,',
#  'sparkling',
#  'flake.',
#  'By',
#  'exist,',
#  'stove.',
#  'make-believe,',
#  'entwine,',
#  'Charge',
#  'up,',
#  'Virtue-',
#  'mess?',
#  "'Button,",
#  'shook',
#  '(Nine',
#  'sell.',
#  "'stride",
#  'mistrust:',
#  'too.',
#  'letter-box',
#  'device.',
#  "You'll",
#  'slopes!',
#  "years.'",
#  'stable',
#  'repeatedly',
#  '"Ile\'s',
#  'rustling',
#  "they?'",
#  'perfect',
#  'Ceasing',
#  "'He's",
#  'sign,',
#  'headed',
#  "rear'd",
#  'daylight,',
#  'intertwine',
#  'blue;',
#  "'For",
#  "everything.'",
#  'besides.',
#  'deep-buried',
#  'arm,',
#  'slides,',
#  "aren't",
#  'out,',
#  'object-',
#  'duty-',
#  'news.',
#  'Sorrow,)',
#  "appears.'",
#  'heart,',
#  'off.',
#  'gentlest',
#  'wriggling',
#  'gone!',
#  'neighbours,',
#  'font.',
#  'Soul.',
#  'screen:',
#  'Trembled',
#  'only,',
#  'here!',
#  "'As",
#  'swamp,',
#  'at.',
#  'me:',
#  'kitchen,',
#  'God!',
#  'kiss',
#  'written,',
#  'aright-',
#  'celestial',
#  'end,',
#  'weeping,',
#  'Being',
#  "'Do",
#  'ominous',
#  'roll-',
#  'Would',
#  'LO!',
#  'range.',
#  'Whatever',
#  "'tis",
#  'nine:',
#  'book,',
#  "needn't",
#  "'Nonsense!",
#  "could!'",
#  'covers,',
#  'night,',
#  'dew,',
#  'Last',
#  'garden,',
#  'sober,',
#  'air,',
#  'Died',
#  '(so',
#  '(The',
#  'grass-',
#  'ever.',
#  'poems.',
#  'thee;',
#  'presence.',
#  'Was',
#  'odor',
#  '(now',
#  "Astarte's",
#  'paused-',
#  'one:',
#  'more,',
#  '(silent',
#  'again.',
#  'Toffile:',
#  "one's",
#  'walls,',
#  'pairs',
#  'ambition;',
#  "haven't",
#  'cock,',
#  'See!',
#  'shelf.',
#  'thrive)',
#  'belong,',
#  'Yaanek',
#  "'Tis",
#  'alas!',
#  'Beloved!',
#  'we,',
#  'Wreathed',
#  'When',
#  'wings,',
#  'here?',
#  "job.'",
#  'Boy,',
#  'gushing-',
#  'songs!',
#  'flower-enameled',
#  'go;',
#  'outwalked',
#  'Awake',
#  'prefer',
#  'presented,',
#  'Soul',
#  'Look',
#  'being.',
#  'storm?',
#  'both,',
#  'away.',
#  "property.'",
#  'lantern,',
#  'Oh',
#  'teased.',
#  "'Is",
#  'Psyche,',
#  'shadow',
#  "couldn't",
#  'hole,',
#  "we'd",
#  "'You",
#  'well-tuned',
#  'grace,',
#  "this?'",
#  "two?'",
#  'anyway.',
#  'window,',
#  'creatures,")',
#  'together,',
#  'passion,',
#  "you'll",
#  'Since',
#  'things-',
#  'now,',
#  'Upon',
#  'box!',
#  'herself.',
#  "'This",
#  "mustn't",
#  'Wentworth',
#  'himself,',
#  'Weir."',
#  'Echoes',
#  '!',
#  'Your',
#  'evermore,',
#  'Why',
#  'know.',
#  'here,',
#  'blest;',
#  'run.',
#  'to-morrow,',
#  'rule,',
#  'army',
#  "leaf's",
#  'more:',
#  'with.',
#  'mad.',
#  'tone,',
#  'Were',
#  'is,',
#  'mother.',
#  'shelf,',
#  'here:',
#  'see.',
#  '(which',
#  'Maria!',
#  'pairing',
#  'blue,',
#  'Thus',
#  "bill.'",
#  'they?',
#  'Jupiter.',
#  'farm.',
#  'Clara',
#  'Past,',
#  'twitter,',
#  "'Don't",
#  'sighed,',
#  'told!',
#  'course,',
#  "shouting.'",
#  'once.',
#  'Sunday',
#  'church',
#  'July',
#  'seeking',
#  'imported.',
#  '(the',
#  'trembling',
#  'child.',
#  'best,',
#  'sacrifice,',
#  "will.'",
#  'earnest.',
#  'yours.',
#  'lost.',
#  'trouble.',
#  'moon,',
#  "'She",
#  'chicken-time.',
#  'earth,',
#  'affairs.',
#  'tree?',
#  'do.',
#  'MOTHER',
#  'hen!',
#  ...}

# %% [markdown]
# * Train a Markov Model for each class (Edgar Allen Poe / Rober Frost)

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
#initialize A and pi matrices - for both classes
V = len(word2idx)

A0 = np.ones((V, V))
A1 = np.ones((V, V))

pi0 = np.zeros(V)
pi1 = np.zeros(V)

#initial fake counts

# %% [markdown]
# * Write a function to compute the posterior for each class, given an input

# %%
def compute_p_y_given_x(x, eap_markov, rf_markov):
    p_eap = 1
    p_rf = 1
    for i in range(len(x)-1):
        p_eap *= eap_markov[x[i], x[i+1]]
        p_rf *= rf_markov[x[i], x[i+1]]
    return p_eap, p_rf

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
#compute counts for A and pi
def compute_counts(text_as_int, A, pi):
    for tokens in text_as_int:
        last_idx = None
        for idx in tokens:
            if last_idx is None:
                #it's the first word in the sentence
                pi[idx] += 1
            else:
                #the last word exists, so count a transition
                A[last_idx, idx] += 1
            #Update the last index
            last_idx = idx

# %%
compute_counts([t for t in zip(train_text_int, Ytrain) if y == 0], A0, pi0) 
compute_counts([t for t in zip(train_text_int, Ytrain) if y == 1], A1, pi1)

# %%
#normalize A and pi so they are valid probability matrices
A0 /= A0.sum(axis = 1, keepdims = True)
pi0 /= pi0.sum()

A1 /= A1.sum(axis = 1, keepdims = True)
pi1 /= pi1.sum()
# Out:
# C:\Users\basak\AppData\Local\Temp\ipykernel_22076\473258018.py:3: RuntimeWarning: invalid value encountered in divide
#   pi0 /= pi0.sum()

# %%
#compute log probabilities. we don't need the actaul probabilities, just the log probabilities
logA0 = np.log(A0)
logA1 = np.log(A1)

logpi0 = np.log(pi0)

#divide by zero encountered in log
if np.isnan(logpi0).any():
    logpi0[np.isnan(logpi0)] = 0
    
logpi1 = np.log(pi1)
# Out:
# C:\Users\basak\AppData\Local\Temp\ipykernel_22076\3329868469.py:11: RuntimeWarning: divide by zero encountered in log
#   logpi1 = np.log(pi1)

# %%
#compute priors
count0 = sum(y==0 for y in Ytrain)
count1 = sum(y==1 for y in Ytrain)

total = len(Ytrain)

p0 = count0 / total
p1 = count1 / total

logp0 = np.log(p0)
logp1 = np.log(p1)

p0, p1

#posterior probability - map method
# Out:
# (0.3368355995055624, 0.6631644004944376)

# %% [markdown]
# * Take the argmax over the posteriors to get the predicted class

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
#build a classifier
class Classifier:
    def __init__(self, logAs, logpis, logpriors):
        self.logAs = logAs
        self.logpis = logpis
        self.logpriors = logpriors
        self.K = len(logpriors) #number of classes
        
  
        
    def _compute_log_likelihood(self, input_, class_):
        logA = self.logAs[class_]
        logpi = self.logpis[class_]
        
        last_idx = None
        logprob = 0
        for idx in input_:
            if last_idx is None:
                #it's the first token
                logprob += logpi[idx]
            else:
                logprob += logA[last_idx, idx]
                
            #update the last index
            last_idx = idx
            
        return logprob
    
    def predict(self, inputs):
        predictions = np.zeros(len(inputs))
        for i, input_ in enumerate(inputs):
            #compute the log likelihood for each class
            posteriors = [self._compute_log_likelihood(input_, c) + self.logpriors[c] 
                          for c in range(self.K)]
            pred = np.argmax(posteriors)
            predictions[i] = pred
            
        return predictions

# %% [markdown]
# * Make predictions for both train and test sets

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
#each array must be in order since classes are assumed to index these lists
clf = Classifier([logA0, logA1], [logpi0, logpi1], [logp0, logp1])

# %% [markdown]
# * Compute the accuracy for train/test sets

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
Ptrain = clf.predict(train_text_int)
Ptest = clf.predict(test_text_int)

#print the accuracy
print("Train accuracy:", np.mean(Ptrain == Ytrain))
print("Test accuracy:", np.mean(Ptest == Ytest))
# Out:
# Train accuracy: 0.33498145859085293
# Test accuracy: 0.4166666666666667

# %% [markdown]
# * Check for class imbalance

# %% [markdown]
# * If there is class imbalance, check confusion matrix and F1-score

# %% [markdown]
# <small><b> Solution: </b></small>

# %%
from sklearn.metrics import confusion_matrix, f1_score

# %%
cm_train = confusion_matrix(Ytrain, Ptrain)
cm_train
# Out:
# array([[ 542,    3],
#        [1073,    0]], dtype=int64)

# %%
cm_test = confusion_matrix(Ytest, Ptest)
cm_test
# Out:
# array([[143,  34],
#        [281,  82]], dtype=int64)

# %%
f1_score(Ytrain, Ptrain)
# Out:
# 0.0

# %%
f1_score(Ytest, Ptest)
# Out:
# 0.34237995824634654
